# %%
# !pip install datasets tqdm pandas
# !sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh

# Kaggle doesn't allow & so use subprocess instead
import subprocess, time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)

# !ollama pull aya:8b
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.8.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.24.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.3.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
#
#
#
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 133 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (1,585 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package zstd.
# (Reading database ... 124626 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling 495401f864a6:   0% ▕                  ▏ 499 KB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   1% ▕                  ▏  32 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   1% ▕                  ▏  60 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   3% ▕                  ▏ 133 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   4% ▕                  ▏ 212 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   5% ▕                  ▏ 258 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   7% ▕█                 ▏ 353 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   9% ▕█                 ▏ 446 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  10% ▕█                 ▏ 499 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  12% ▕██                ▏ 580 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  14% ▕██                ▏ 656 MB/4.8 GB  655 MB/s      6spulling manifest
# pulling 495401f864a6:  15% ▕██                ▏ 697 MB/4.8 GB  655 MB/s      6spulling manifest
# pulling 495401f864a6:  16% ▕██                ▏ 787 MB/4.8 GB  655 MB/s      6spulling manifest
# pulling 495401f864a6:  18% ▕███               ▏ 881 MB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  19% ▕███               ▏ 924 MB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  21% ▕███               ▏ 1.0 GB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  23% ▕████              ▏ 1.1 GB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  24% ▕████              ▏ 1.1 GB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  26% ▕████              ▏ 1.2 GB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  28% ▕████              ▏ 1.3 GB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  29% ▕█████             ▏ 1.4 GB/4.8 GB  655 MB/s      5spulling manifest
# pulling 495401f864a6:  30% ▕█████             ▏ 1.5 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  31% ▕█████             ▏ 1.5 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  33% ▕█████             ▏ 1.6 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  35% ▕██████            ▏ 1.7 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  37% ▕██████            ▏ 1.8 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  38% ▕██████            ▏ 1.8 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  40% ▕███████           ▏ 1.9 GB/4.8 GB  706 MB/s      4spulling manifest
# pulling 495401f864a6:  42% ▕███████           ▏ 2.0 GB/4.8 GB  706 MB/s      3spulling manifest
# pulling 495401f864a6:  43% ▕███████           ▏ 2.0 GB/4.8 GB  706 MB/s      3spulling manifest
# pulling 495401f864a6:  45% ▕████████          ▏ 2.1 GB/4.8 GB  706 MB/s      3spulling manifest
# pulling 495401f864a6:  47% ▕████████          ▏ 2.2 GB/4.8 GB  729 MB/s      3spulling manifest
# pulling 495401f864a6:  47% ▕████████          ▏ 2.3 GB/4.8 GB  729 MB/s      3spulling manifest
# pulling 495401f864a6:  49% ▕████████          ▏ 2.4 GB/4.8 GB  729 MB/s      3spulling manifest
# pulling 495401f864a6:  51% ▕█████████         ▏ 2.4 GB/4.8 GB  729 MB/s      3spulling manifest
# pulling 495401f864a6:  51% ▕█████████         ▏ 2.5 GB/4.8 GB  729 MB/s      3spulling manifest
# pulling 495401f864a6:  53% ▕█████████         ▏ 2.6 GB/4.8 GB  729 MB/s      3spulling manifest
# pulling 495401f864a6:  55% ▕█████████         ▏ 2.6 GB/4.8 GB  729 MB/s      2spulling manifest
# pulling 495401f864a6:  56% ▕██████████        ▏ 2.7 GB/4.8 GB  729 MB/s      2spulling manifest
# pulling 495401f864a6:  58% ▕██████████        ▏ 2.8 GB/4.8 GB  729 MB/s      2spulling manifest
# pulling 495401f864a6:  60% ▕██████████        ▏ 2.9 GB/4.8 GB  729 MB/s      2spulling manifest
# pulling 495401f864a6:  60% ▕██████████        ▏ 2.9 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  62% ▕███████████       ▏ 3.0 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  63% ▕███████████       ▏ 3.0 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  64% ▕███████████       ▏ 3.1 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  66% ▕███████████       ▏ 3.1 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  67% ▕████████████      ▏ 3.2 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  68% ▕████████████      ▏ 3.3 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  69% ▕████████████      ▏ 3.3 GB/4.8 GB  723 MB/s      2spulling manifest
# pulling 495401f864a6:  71% ▕████████████      ▏ 3.4 GB/4.8 GB  723 MB/s      1spulling manifest
# pulling 495401f864a6:  72% ▕████████████      ▏ 3.4 GB/4.8 GB  723 MB/s      1spulling manifest
# pulling 495401f864a6:  73% ▕█████████████     ▏ 3.5 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  75% ▕█████████████     ▏ 3.6 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  76% ▕█████████████     ▏ 3.6 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  77% ▕█████████████     ▏ 3.7 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  79% ▕██████████████    ▏ 3.8 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  79% ▕██████████████    ▏ 3.8 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  81% ▕██████████████    ▏ 3.9 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  82% ▕██████████████    ▏ 4.0 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  83% ▕██████████████    ▏ 4.0 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  85% ▕███████████████   ▏ 4.1 GB/4.8 GB  703 MB/s      1spulling manifest
# pulling 495401f864a6:  86% ▕███████████████   ▏ 4.1 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  87% ▕███████████████   ▏ 4.2 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  89% ▕███████████████   ▏ 4.3 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  90% ▕████████████████  ▏ 4.3 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  91% ▕████████████████  ▏ 4.4 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  92% ▕████████████████  ▏ 4.4 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  93% ▕████████████████  ▏ 4.5 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  94% ▕████████████████  ▏ 4.5 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  94% ▕████████████████  ▏ 4.5 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  95% ▕█████████████████ ▏ 4.6 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  95% ▕█████████████████ ▏ 4.6 GB/4.8 GB  691 MB/s      0spulling manifest
# pulling 495401f864a6:  96% ▕█████████████████ ▏ 4.6 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  96% ▕█████████████████ ▏ 4.6 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  97% ▕█████████████████ ▏ 4.6 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  97% ▕█████████████████ ▏ 4.7 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  97% ▕█████████████████ ▏ 4.7 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  98% ▕█████████████████ ▏ 4.7 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  98% ▕█████████████████ ▏ 4.7 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.7 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.8 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.8 GB/4.8 GB  654 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  597 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  597 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  597 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  597 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# ...
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest
# writing manifest
# success

# %%
from datasets import load_dataset
from tqdm.notebook import tqdm
import pandas as pd
import requests

# %%
path = "/kaggle/input/datasets/feryaljadallah/fullbayyin/full_bayyin_dataset.csv"
OLLAMA_URL = "http://localhost:11434/api/generate"

# %%
import pandas as pd
from datasets import Dataset

df_raw = pd.read_csv(path, dtype=str)  # force everything to string, no inference
dataset = Dataset.from_pandas(df_raw)
print(f"Loaded {len(dataset)} rows")
print(f"Columns: {dataset.column_names}")
# Out:
# Loaded 71044 rows
# Columns: ['ID', 'Sentence', 'Word_Count', 'Word', 'Lex', 'D3Tok', 'D3Lex', 'Readability_Level', 'Document', 'Source', 'Book', 'Author', 'Domain', 'Text_Class', 'Dataset_Source']

# %%
from collections import Counter
level_counts = Counter(int(row.get("Readability_Level", 0) or 0) for row in dataset)
for lvl in sorted(level_counts):
    print(f"Level {lvl}: {level_counts[lvl]} sentences")
# Out:
# Level 1: 9027 sentences
# Level 2: 7735 sentences
# Level 3: 14369 sentences
# Level 4: 17973 sentences
# Level 5: 13109 sentences
# Level 6: 8831 sentences

# %%
sentences = dataset["Sentence"]

# %%
def simplify_with_llm(sentence, target_level):
    level_instructions = {
        1: "بشكل بسيط جداً مناسب للأطفال، باستخدام كلمات قصيرة وشائعة فقط",
        2: "بشكل بسيط وواضح، مناسب للقراء المبتدئين",
        3: "بشكل مبسط قليلاً، مع الحفاظ على الأسلوب العربي الفصيح"
    }

    prompt = f"""أنت متخصص في تبسيط النصوص العربية. مهمتك تبسيط الجملة التالية {level_instructions[target_level]}.

قواعد مهمة:
- أعد كتابة الجملة فقط، بدون أي مقدمة أو شرح
- حافظ على المعنى الأصلي
- لا تضف معلومات جديدة
- اكتب جملة واحدة فقط

الجملة الأصلية: {sentence}

الجملة المبسّطة:"""

    response = requests.post(OLLAMA_URL, json={
        "model": "aya:8b",
        "prompt": prompt,
        "stream": False,
        "options": {"temperature": 0.3, "num_predict": 256}
    })
    return response.json()["response"].strip()

print("Ollama client ready.")
# Out:
# Ollama client ready.

# %%
def is_hard_level(level):
    return level in [5, 6]

# %%
def simplify_sentence_levels(sentence):
    results = {}
    for lvl in [1, 2, 3]:
        try:
            simplified = simplify_with_llm(sentence, lvl)
            results[lvl] = simplified
        except Exception as e:
            print(f"  Level {lvl} failed: {e}")
    return results if results else None

# %%
def is_valid(original, simplified):
    if not simplified or len(simplified.strip()) < 3:
        return False

    # Strip any residual prefixes
    prefixes_to_clean = ["الجملة المبسّطة:", "إليك", "أعد كتابة", "الترجمة:", "ببساطة:"]
    for p in prefixes_to_clean:
        simplified = simplified.replace(p, "").strip()

    if len(simplified) > len(original) * 2.5:
        return False

    if simplified.strip() == original.strip():
        return False

    return True

# %%
def save_checkpoint(data, batch_num):
    pd.DataFrame(data).to_csv(f"simplified_checkpoint_{batch_num}.csv", index=False)
    print(f"  Checkpoint saved: {len(data)} rows")

# %%
PART = "B"

# Remove Quran sentences, then split
hard_rows = [
    (i, row) for i, row in enumerate(dataset)
    if is_hard_level(int(row.get("Readability_Level", 0) or 0))
    and row.get("Source") != "Quran"
]

print(f"Total hard non-Quran sentences: {len(hard_rows)}")

mid = len(hard_rows) // 2
hard_rows = hard_rows[:mid] if PART == "A" else hard_rows[mid:]

# Resume from last checkpoint
import os
checkpoint_file = "/kaggle/input/datasets/feryaljadallah/bayyinpartbcheckpoint/bayyin_simplified_partB_checkpoint_7700.csv"

if os.path.exists(checkpoint_file):
    simplified_data = pd.read_csv(checkpoint_file, dtype=str).to_dict("records")
    already_done = len(simplified_data) // 3
    hard_rows = hard_rows[already_done:]
    print(f"Resuming from {already_done} sentences, {len(hard_rows)} remaining")
else:
    simplified_data = []
    print("No checkpoint found, starting fresh")

simplified_data_grouped = []
SAVE_EVERY = 100

for count, (orig_idx, row) in enumerate(tqdm(hard_rows)):
    sentence = row["Sentence"]

    simplified_versions = simplify_sentence_levels(sentence)
    if not simplified_versions:
        continue

    entry = {"Original_Sentence": sentence, "Simplified": {}}

    for lvl, simp in simplified_versions.items():
        clean = simp.strip()
        if is_valid(sentence, clean):
            entry["Simplified"][lvl] = clean
            new_row = dict(row)
            new_row["Original_Sentence"] = sentence
            new_row["Sentence"] = clean
            new_row["Readability_Level"] = str(lvl)
            simplified_data.append(new_row)

    if entry["Simplified"]:
        simplified_data_grouped.append(entry)

    if (count + 1) % SAVE_EVERY == 0:
        pd.DataFrame(simplified_data).to_csv(
            f"bayyin_simplified_part{PART}_checkpoint_latest.csv", index=False
        )
        print(f"  Checkpoint saved: {len(simplified_data)} rows")

print(f"Done. Generated {len(simplified_data)} rows from {len(simplified_data_grouped)} sentences.")
# Out:
# Total hard non-Quran sentences: 21739
# Resuming from 7677 sentences, 3193 remaining
#   0%|          | 0/3193 [00:00<?, ?it/s]
#   Checkpoint saved: 23333 rows
#   Checkpoint saved: 23633 rows
#   Checkpoint saved: 23933 rows
#   Checkpoint saved: 24232 rows
#   Checkpoint saved: 24532 rows
#   Checkpoint saved: 24829 rows
#   Checkpoint saved: 25129 rows
#   Checkpoint saved: 25428 rows
#   Checkpoint saved: 25728 rows
#   Checkpoint saved: 26028 rows
#   Checkpoint saved: 26328 rows
#   Checkpoint saved: 26628 rows
#   Checkpoint saved: 26927 rows
#   Checkpoint saved: 27226 rows
#   Checkpoint saved: 27526 rows
#   Checkpoint saved: 27825 rows
#   Checkpoint saved: 28125 rows
#   Checkpoint saved: 28425 rows
#   Checkpoint saved: 28725 rows
#   Checkpoint saved: 29025 rows
#   Checkpoint saved: 29325 rows
#   Checkpoint saved: 29624 rows
#   Checkpoint saved: 29924 rows
#   Checkpoint saved: 30224 rows
#   Checkpoint saved: 30523 rows
#   Checkpoint saved: 30822 rows
#   Checkpoint saved: 31121 rows
#   Checkpoint saved: 31420 rows
#   Checkpoint saved: 31716 rows
#   Checkpoint saved: 32016 rows
#   Checkpoint saved: 32316 rows
# Done. Generated 32595 rows from 3193 sentences.

# %%
df = pd.DataFrame(simplified_data)
df.to_csv(f"bayyin_simplified_part{PART}_final.csv", index=False)
print(f"Saved {len(df)} rows to bayyin_simplified_part{PART}_final.csv")
print(df.head())
# Out:
# Saved 32595 rows to bayyin_simplified_partB_final.csv
#             ID                                           Sentence Word_Count  \
# 0  30500240082  قال القرآن عن الذين تحدثوا سيّئاً عن عائشة: هم...         23
# 1  30500240082  وقد أكدت الآيات الكريمة أن من تحدث عن عائشة هم...         23
# 2  30500240082  وقد أكدت الآيات الكريمة أن من تحدث في عائشة هم...         23
# 3  30500240083  اللّه وعد هذه الشرذمة أنهم سيحصلون على الكثير ...         35
# 4  30500240083  توعد الله هذه الشرذمة بأن لهم من الإثم قدر ذنب...         35
#
#                                                 Word  \
# 0  وقد أكدت الآيات الكريمة أن من تحدث في عائشة هم...
# 1  وقد أكدت الآيات الكريمة أن من تحدث في عائشة هم...
# 2  وقد أكدت الآيات الكريمة أن من تحدث في عائشة هم...
# 3  وتوعد الله هذه الشرذمة بأن لهم من الإثم بمقدار...
# 4  وتوعد الله هذه الشرذمة بأن لهم من الإثم بمقدار...
#
#                                                  Lex  \
# 0  قد أكد آية كريم أن من تحدث في عائشه هم شرذمة م...
# 1  قد أكد آية كريم أن من تحدث في عائشه هم شرذمة م...
# 2  قد أكد آية كريم أن من تحدث في عائشه هم شرذمة م...
# 3  توعد الله هذا شرذمة أن ل من إثم مقدار ذنب , أن...
# 4  توعد الله هذا شرذمة أن ل من إثم مقدار ذنب , أن...
#
#                                                D3Tok  \
# 0  و+ قد أكدت ال+ آيات ال+ كريمة أن من تحدث في عا...
# 1  و+ قد أكدت ال+ آيات ال+ كريمة أن من تحدث في عا...
# 2  و+ قد أكدت ال+ آيات ال+ كريمة أن من تحدث في عا...
# 3  و+ توعد الله هذه ال+ شرذمة ب+ أن ل +هم من ال+ ...
# 4  و+ توعد الله هذه ال+ شرذمة ب+ أن ل +هم من ال+ ...
#
#                                                D3Lex Readability_Level  \
# 0  و+ قد أكد ال+ آية ال+ كريم أن من تحدث في عائشه...                 1
# 1  و+ قد أكد ال+ آية ال+ كريم أن من تحدث في عائشه...                 2
# 2  و+ قد أكد ال+ آية ال+ كريم أن من تحدث في عائشه...                 3
# 3  و+ توعد الله هذا ال+ شرذمة ب+ أن ل +هم من ال+ ...                 1
# 4  و+ توعد الله هذا ال+ شرذمة ب+ أن ل +هم من ال+ ...                 2
#
#                                  Document              Source  \
# 0  BAREC_Curriculum_12_slm_t1_u02_001.txt  Emarati Curriculum
# 1  BAREC_Curriculum_12_slm_t1_u02_001.txt  Emarati Curriculum
# 2  BAREC_Curriculum_12_slm_t1_u02_001.txt  Emarati Curriculum
# 3  BAREC_Curriculum_12_slm_t1_u02_001.txt  Emarati Curriculum
# 4  BAREC_Curriculum_12_slm_t1_u02_001.txt  Emarati Curriculum
#
#                        Book Author             Domain   Text_Class  \
# 0  Grade 12 Islamic Studies      #  Arts & Humanities  Specialized
# 1  Grade 12 Islamic Studies      #  Arts & Humanities  Specialized
# 2  Grade 12 Islamic Studies      #  Arts & Humanities  Specialized
# 3  Grade 12 Islamic Studies      #  Arts & Humanities  Specialized
# 4  Grade 12 Islamic Studies      #  Arts & Humanities  Specialized
#
#   Dataset_Source                                  Original_Sentence
# 0          BAREC  وقد أكّدتِ الآياتُ الكريمةُ أنّ مَنْ تحدّثَ في...
# 1          BAREC  وقد أكّدتِ الآياتُ الكريمةُ أنّ مَنْ تحدّثَ في...
# 2          BAREC  وقد أكّدتِ الآياتُ الكريمةُ أنّ مَنْ تحدّثَ في...
# 3          BAREC  وتوّعدَ اللّهُ هذه الشّرذمةَ بأنّ لهم منَ الإث...
# 4          BAREC  وتوّعدَ اللّهُ هذه الشّرذمةَ بأنّ لهم منَ الإث...

# %%
for entry in simplified_data_grouped[:5]:
    print("Original:  ", entry["Original_Sentence"])
    for lvl in sorted(entry["Simplified"]):
        label = {1: "Level 1 (simplest)", 2: "Level 2", 3: "Level 3"}[lvl]
        print(f"  {label}: {entry['Simplified'][lvl]}")
    print("-" * 60)
# Out:
# Original:   وهنالك ما هو أفظع من ذلك؛ فإنَّ بعض النساء لا يعرفن عن أزواجهن شيئًا كأنهم غرباء عنهنَّ، وكذلك الأزواج تراهم على جهل بنسائهم كأنهن في غير عصمة الرجال.
#   Level 1 (simplest): بعض النساء لا يعرفن أزواجهن جيدًا، وكذا الأزواج لا يعرفون زوجاتهم جيدًا.
#   Level 2: بعض النساء جهلات عن أزواجهن وكأنهم غرباء وعن الأزواج جهلاء عن نسائهم وكأنهم غير متزوجين.
#   Level 3: وهناك ما هو أسوأ من ذلك؛ فبعض النساء لا يعرفن أزواجهن كما لو كانوا غريبين عنهن، والعكس صحيح أيضًا.
# ------------------------------------------------------------
# Original:   ومع أن ضخامة الأليتين لا تعد من الجمال إلا عند البدائيين أو المتوحشين، فإن هناك ما يرجح القول بأنهما ستزيدان ضخامة في المستقبل؛ لأن الدماغ سيكبر في حجمه، وسيحتاج الجنين إلى حوض واسع عند المرأة حتى تسهل ولادته، واتساع الحوض يعني في النهاية تضخم الأليتين.
#   Level 1 (simplest): ستزداد أليتان جنباً إلى جنب مع نمو دماغ الطفل داخل الرحم، مما يتطلب مساحة أكبر للولادة بأمان.
#   Level 2: مع أن ضخامة المؤخرة لا تعد من الجمال إلا عند المبتدئين أو الذين لا يعرفون عن الجنس البشري الكثير، فإن هناك ما يشير إلى أنها ستزداد ضخامة في المستقبل؛ لأن الدماغ سيتوسع، مما سيحتاج إلى حوض واسع عند المرأة لتسهيل ولادة الجنين، واتساع الحوض يعني في النهاية تضخم المؤخرة.
#   Level 3: مع أن ضخامة الأليتين لا تعد من الجمال إلا عند البدائيين أو المتوحشين، هناك ما يرجح أن الدماغ سيكبر في حجمه، وسيحتاج الجنين إلى حوض واسع عند المرأة حتى تسهل ولادته، واتساع الحوض يعني تضخم الأليتين.
# ------------------------------------------------------------
# Original:   إذا كان العقل تاج الحياة، فالعقل الاجتماعي هو قمة هذا التاج.
#   Level 1 (simplest): العقل الحكيم يجعل الحياة أفضل.
#   Level 2: العقل الاجتماعي هو أعلى مستويات العقل البشري.
#   Level 3: إنّ العقل الاجتماعي هو أرفع مستويات العقل البشري.
# ------------------------------------------------------------
# Original:   وقد وقَع مثل هذا فيما لا يُحصى من الكتب، ومنها «صحيح البخاري»، كما ذكره الحافظ ابن حجر في مقدمة شرحه.
#   Level 1 (simplest): وقد حدث هذا كثيرًا في كتب عديدة، ومنها كتاب "صحيح البخاري"، كما قال عالم يسمى "ابن حجر".
#   Level 2: وقد حدث هذا كثيرًا في كتب عديدة، بما في ذلك كتاب "صحيح البخاري"، كما ذكر الحافظ ابن حجر في مقدمته.
#   Level 3: وقد حدث مثل ذلك في العديد من الكتب، بما في ذلك "صحيح البخاري"، كما أشار الحافظ ابن حجر في مقدمته.
# ------------------------------------------------------------
# Original:   س: فهمتُ أن لك حبيبًا، أو أنه كان لك حبيب من هذا النوع؛ ولذا أُسَلِّم بذلك.
#   Level 1 (simplest): فهمت أن لديك صديقًا خاصًا.
#   Level 2: فهمت أن لك حبيبًا، ولهذا أستسلم.
#   Level 3: فهمت أن لك حبيبًا، أو كان لك حبيب من هذا النوع، فأسلمت بذلك.
# ------------------------------------------------------------
