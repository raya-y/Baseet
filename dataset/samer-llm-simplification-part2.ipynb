# %%
# !pip install datasets tqdm pandas
# !sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh

# Kaggle doesn't allow & so use subprocess instead
import subprocess, time
subprocess.Popen(["ollama", "serve"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
time.sleep(5)

# !ollama pull aya:8b
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.8.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.24.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.3.0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
#
#
#
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 133 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (1,628 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package zstd.
# (Reading database ... 124626 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 495401f864a6:   0% ▕                  ▏ 5.3 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   1% ▕                  ▏  36 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   3% ▕                  ▏ 126 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   5% ▕                  ▏ 219 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   5% ▕                  ▏ 260 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   7% ▕█                 ▏ 350 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:   9% ▕█                 ▏ 446 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  10% ▕█                 ▏ 492 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  12% ▕██                ▏ 582 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  14% ▕██                ▏ 677 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  15% ▕██                ▏ 717 MB/4.8 GB                  pulling manifest
# pulling 495401f864a6:  17% ▕███               ▏ 812 MB/4.8 GB  760 MB/s      5spulling manifest
# pulling 495401f864a6:  19% ▕███               ▏ 906 MB/4.8 GB  760 MB/s      5spulling manifest
# pulling 495401f864a6:  20% ▕███               ▏ 956 MB/4.8 GB  760 MB/s      5spulling manifest
# pulling 495401f864a6:  22% ▕███               ▏ 1.0 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  24% ▕████              ▏ 1.1 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  25% ▕████              ▏ 1.2 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  27% ▕████              ▏ 1.3 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  28% ▕█████             ▏ 1.4 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  29% ▕█████             ▏ 1.4 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  32% ▕█████             ▏ 1.5 GB/4.8 GB  760 MB/s      4spulling manifest
# pulling 495401f864a6:  34% ▕██████            ▏ 1.6 GB/4.8 GB  775 MB/s      4spulling manifest
# pulling 495401f864a6:  34% ▕██████            ▏ 1.7 GB/4.8 GB  775 MB/s      4spulling manifest
# pulling 495401f864a6:  36% ▕██████            ▏ 1.7 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  38% ▕██████            ▏ 1.8 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  39% ▕███████           ▏ 1.9 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  41% ▕███████           ▏ 2.0 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  43% ▕███████           ▏ 2.1 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  44% ▕███████           ▏ 2.1 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  46% ▕████████          ▏ 2.2 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  48% ▕████████          ▏ 2.3 GB/4.8 GB  775 MB/s      3spulling manifest
# pulling 495401f864a6:  49% ▕████████          ▏ 2.3 GB/4.8 GB  780 MB/s      3spulling manifest
# pulling 495401f864a6:  51% ▕█████████         ▏ 2.4 GB/4.8 GB  780 MB/s      3spulling manifest
# pulling 495401f864a6:  53% ▕█████████         ▏ 2.5 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  54% ▕█████████         ▏ 2.6 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  56% ▕██████████        ▏ 2.7 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  58% ▕██████████        ▏ 2.8 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  59% ▕██████████        ▏ 2.8 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  61% ▕██████████        ▏ 2.9 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  63% ▕███████████       ▏ 3.0 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  64% ▕███████████       ▏ 3.1 GB/4.8 GB  780 MB/s      2spulling manifest
# pulling 495401f864a6:  66% ▕███████████       ▏ 3.1 GB/4.8 GB  785 MB/s      2spulling manifest
# pulling 495401f864a6:  67% ▕████████████      ▏ 3.2 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  68% ▕████████████      ▏ 3.3 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  70% ▕████████████      ▏ 3.4 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  71% ▕████████████      ▏ 3.4 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  72% ▕████████████      ▏ 3.5 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  74% ▕█████████████     ▏ 3.5 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  75% ▕█████████████     ▏ 3.6 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  76% ▕█████████████     ▏ 3.6 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  78% ▕█████████████     ▏ 3.7 GB/4.8 GB  785 MB/s      1spulling manifest
# pulling 495401f864a6:  79% ▕██████████████    ▏ 3.8 GB/4.8 GB  759 MB/s      1spulling manifest
# pulling 495401f864a6:  80% ▕██████████████    ▏ 3.8 GB/4.8 GB  759 MB/s      1spulling manifest
# pulling 495401f864a6:  82% ▕██████████████    ▏ 3.9 GB/4.8 GB  759 MB/s      1spulling manifest
# pulling 495401f864a6:  83% ▕██████████████    ▏ 4.0 GB/4.8 GB  759 MB/s      1spulling manifest
# pulling 495401f864a6:  84% ▕███████████████   ▏ 4.0 GB/4.8 GB  759 MB/s      0spulling manifest
# pulling 495401f864a6:  86% ▕███████████████   ▏ 4.1 GB/4.8 GB  759 MB/s      0spulling manifest
# pulling 495401f864a6:  88% ▕███████████████   ▏ 4.2 GB/4.8 GB  759 MB/s      0spulling manifest
# pulling 495401f864a6:  89% ▕███████████████   ▏ 4.3 GB/4.8 GB  759 MB/s      0spulling manifest
# pulling 495401f864a6:  90% ▕████████████████  ▏ 4.3 GB/4.8 GB  759 MB/s      0spulling manifest
# pulling 495401f864a6:  92% ▕████████████████  ▏ 4.4 GB/4.8 GB  759 MB/s      0spulling manifest
# pulling 495401f864a6:  94% ▕████████████████  ▏ 4.5 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  94% ▕████████████████  ▏ 4.5 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  96% ▕█████████████████ ▏ 4.6 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  97% ▕█████████████████ ▏ 4.7 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.7 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.7 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.8 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6:  99% ▕█████████████████ ▏ 4.8 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕█████████████████ ▏ 4.8 GB/4.8 GB  747 MB/s      0spulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B                         pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# ...
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 495401f864a6: 100% ▕██████████████████▏ 4.8 GB
# pulling f0624a2393a5: 100% ▕██████████████████▏  13 KB
# pulling 42499e38acdf: 100% ▕██████████████████▏  270 B
# pulling 36b9655abe6a: 100% ▕██████████████████▏   81 B
# pulling e054a6188627: 100% ▕██████████████████▏  492 B
# verifying sha256 digest
# writing manifest
# success

# %%
from tqdm.notebook import tqdm
from pathlib import Path
import pandas as pd
import requests
import os

# %%
base_path = Path("/kaggle/input/datasets/naghamalshbrawi/samer-simplification/samer-simplification-corpus-v1/data")
OLLAMA_URL = "http://localhost:11434/api/generate"

# %%
train_df = pd.read_csv(base_path / "train.tsv", sep="\t", dtype=str)
dev_df   = pd.read_csv(base_path / "dev.tsv",   sep="\t", dtype=str)
test_df  = pd.read_csv(base_path / "test.tsv",  sep="\t", dtype=str)

df_raw = pd.concat([train_df, dev_df, test_df], ignore_index=True)
print(f"Loaded {len(df_raw)} rows")
print(f"Columns: {df_raw.columns.tolist()}")
df_raw.head(3)
# Out:
# Loaded 20603 rows
# Columns: ['Novel', 'Chapter', 'L5', 'L4', 'L3', 'Line']
#   Novel Chapter            L5            L4            L3 Line
# 0     0       2  الفصل الثاني  الفصل الثاني  الفصل الثاني    0
# 1     0       2  «وكان صباح..  «وكان صباح..  «وكان صباح..    1
# 2     0       2   يوما واحدا»   يوما واحدا»   يوما واحدا»    1

# %%
COL_ORIGINAL = "L5"

# Drop rows with missing or empty original fragment
before = len(df_raw)
df_raw = df_raw.dropna(subset=[COL_ORIGINAL])
df_raw = df_raw[df_raw[COL_ORIGINAL].str.strip().str.len() > 0]
df_raw = df_raw.reset_index(drop=True)
print(f"Dropped {before - len(df_raw)} empty rows. Remaining: {len(df_raw)}")
# Out:
# Dropped 0 empty rows. Remaining: 20603

# %%
sentences = df_raw[COL_ORIGINAL]

# %%
def simplify_with_llm(sentence, target_level):
    level_instructions = {
        1: "بشكل بسيط جداً مناسب للأطفال، باستخدام كلمات قصيرة وشائعة فقط",
        2: "بشكل بسيط وواضح، مناسب للقراء المبتدئين",
        3: "بشكل مبسط قليلاً، مع الحفاظ على الأسلوب العربي الفصيح"
    }

    prompt = f"""أنت متخصص في تبسيط النصوص العربية. مهمتك تبسيط الجملة التالية {level_instructions[target_level]}.

قواعد مهمة:
- أعد كتابة الجملة فقط، بدون أي مقدمة أو شرح
- حافظ على المعنى الأصلي
- لا تضف معلومات جديدة
- اكتب جملة واحدة فقط

الجملة الأصلية: {sentence}

الجملة المبسّطة:"""

    response = requests.post(OLLAMA_URL, json={
        "model": "aya:8b",
        "prompt": prompt,
        "stream": False,
        "options": {"temperature": 0.3, "num_predict": 256}
    })
    return response.json()["response"].strip()

print("Ollama client ready.")
# Out:
# Ollama client ready.

# %%
def simplify_sentence_levels(sentence):
    results = {}
    for lvl in [1, 2, 3]:
        try:
            simplified = simplify_with_llm(sentence, lvl)
            results[lvl] = simplified
        except Exception as e:
            print(f"  Level {lvl} failed: {e}")
    return results if results else None

# %%
def is_valid(original, simplified):
    if not simplified or len(simplified.strip()) < 3:
        return False

    # Strip any residual prefixes
    prefixes_to_clean = ["الجملة المبسّطة:", "إليك", "أعد كتابة", "الترجمة:", "ببساطة:"]
    for p in prefixes_to_clean:
        simplified = simplified.replace(p, "").strip()

    if len(simplified) > len(original) * 2.5:
        return False

    if simplified.strip() == original.strip():
        return False

    return True

# %%
PART = "B"

all_rows = df_raw.to_dict("records")
print(f"Total SAMER fragments: {len(all_rows)}")

mid = len(all_rows) // 2
all_rows = all_rows[:mid] if PART == "A" else all_rows[mid:]
print(f"Part {PART}: {len(all_rows)} fragments")

# Resume from last checkpoint
checkpoint_file = f"/kaggle/input/datasets/naghamalshbrawi/samercheckpoint/samer_simplified_part{PART}_checkpoint_latest.csv"

if os.path.exists(checkpoint_file):
    simplified_data_grouped = pd.read_csv(checkpoint_file, dtype=str).to_dict("records")
    already_done = len(simplified_data_grouped)
    all_rows = all_rows[already_done:]
    print(f"Resuming from {already_done} fragments, {len(all_rows)} remaining")
else:
    simplified_data_grouped = []
    print("No checkpoint found, starting fresh")

SAVE_EVERY = 100
# Out:
# Total SAMER fragments: 20603
# Part B: 10302 fragments
# No checkpoint found, starting fresh

# %%
for count, row in enumerate(tqdm(all_rows)):
    sentence = row[COL_ORIGINAL]

    simplified_versions = simplify_sentence_levels(sentence)
    if not simplified_versions:
        continue

    # Wide row — original + all 3 levels + all metadata kept together
    entry = {"Original_Sentence": sentence}

    for lvl, simp in simplified_versions.items():
        clean = simp.strip()
        entry[f"Sentence_Level{lvl}"] = clean if is_valid(sentence, clean) else None

    # Carry over all SAMER metadata columns (book, para, split, existing levels, etc.)
    for col in row:
        if col != COL_ORIGINAL and col not in entry:
            entry[col] = row[col]

    entry["Source"] = "SAMER"

    simplified_data_grouped.append(entry)

    if (count + 1) % SAVE_EVERY == 0:
        pd.DataFrame(simplified_data_grouped).to_csv(
            f"samer_simplified_part{PART}_checkpoint_latest.csv", index=False
        )
        print(f"  Checkpoint saved: {len(simplified_data_grouped)} rows")

# Final save — catches the last <100 rows
pd.DataFrame(simplified_data_grouped).to_csv(
    f"samer_simplified_part{PART}_checkpoint_latest.csv", index=False
)
print(f"Done. Generated {len(simplified_data_grouped)} rows.")
# Out:
#   0%|          | 0/10302 [00:00<?, ?it/s]
#   Checkpoint saved: 100 rows
#   Checkpoint saved: 200 rows
#   Checkpoint saved: 300 rows
#   Checkpoint saved: 400 rows
#   Checkpoint saved: 500 rows
#   Checkpoint saved: 600 rows
#   Checkpoint saved: 700 rows
#   Checkpoint saved: 800 rows
#   Checkpoint saved: 900 rows
#   Checkpoint saved: 1000 rows
#   Checkpoint saved: 1100 rows
#   Checkpoint saved: 1200 rows
#   Checkpoint saved: 1300 rows
#   Checkpoint saved: 1400 rows
#   Checkpoint saved: 1500 rows
#   Checkpoint saved: 1600 rows
#   Checkpoint saved: 1700 rows
#   Checkpoint saved: 1800 rows
#   Checkpoint saved: 1900 rows
#   Checkpoint saved: 2000 rows
#   Checkpoint saved: 2100 rows
#   Checkpoint saved: 2200 rows
#   Checkpoint saved: 2300 rows
#   Checkpoint saved: 2400 rows
#   Checkpoint saved: 2500 rows
#   Checkpoint saved: 2600 rows
#   Checkpoint saved: 2700 rows
#   Checkpoint saved: 2800 rows
#   Checkpoint saved: 2900 rows
#   Checkpoint saved: 3000 rows
#   Checkpoint saved: 3100 rows
#   Checkpoint saved: 3200 rows
#   Checkpoint saved: 3300 rows
#   Checkpoint saved: 3400 rows
#   Checkpoint saved: 3500 rows
#   Checkpoint saved: 3600 rows
#   Checkpoint saved: 3700 rows
#   Checkpoint saved: 3800 rows
#   Checkpoint saved: 3900 rows
#   Checkpoint saved: 4000 rows
#   Checkpoint saved: 4100 rows
#   Checkpoint saved: 4200 rows
#   Checkpoint saved: 4300 rows
#   Checkpoint saved: 4400 rows
#   Checkpoint saved: 4500 rows
#   Checkpoint saved: 4600 rows
#   Checkpoint saved: 4700 rows
#   Checkpoint saved: 4800 rows
#   Checkpoint saved: 4900 rows
#   Checkpoint saved: 5000 rows
#   Checkpoint saved: 5100 rows
#   Checkpoint saved: 5200 rows
#   Checkpoint saved: 5300 rows
#   Checkpoint saved: 5400 rows
#   Checkpoint saved: 5500 rows
#   Checkpoint saved: 5600 rows
#   Checkpoint saved: 5700 rows
#   Checkpoint saved: 5800 rows
#   Checkpoint saved: 5900 rows
#   Checkpoint saved: 6000 rows
#   Checkpoint saved: 6100 rows
#   Checkpoint saved: 6200 rows
#   Checkpoint saved: 6300 rows
#   Checkpoint saved: 6400 rows
#   Checkpoint saved: 6500 rows
#   Checkpoint saved: 6600 rows
#   Checkpoint saved: 6700 rows
#   Checkpoint saved: 6800 rows
#   Checkpoint saved: 6900 rows
#   Checkpoint saved: 7000 rows
#   Checkpoint saved: 7100 rows
#   Checkpoint saved: 7200 rows
#   Checkpoint saved: 7300 rows
#   Checkpoint saved: 7400 rows
#   Checkpoint saved: 7500 rows
#   Checkpoint saved: 7600 rows
#   Checkpoint saved: 7700 rows
#   Checkpoint saved: 7800 rows
#   Checkpoint saved: 7900 rows
#   Checkpoint saved: 8000 rows
#   Checkpoint saved: 8100 rows
#   Checkpoint saved: 8200 rows
#   Checkpoint saved: 8300 rows
#   Checkpoint saved: 8400 rows
#   Checkpoint saved: 8500 rows
#   Checkpoint saved: 8600 rows
#   Checkpoint saved: 8700 rows
#   Checkpoint saved: 8800 rows
#   Checkpoint saved: 8900 rows
#   Checkpoint saved: 9000 rows
#   Checkpoint saved: 9100 rows
#   Checkpoint saved: 9200 rows
#   Checkpoint saved: 9300 rows
#   Checkpoint saved: 9400 rows
#   Checkpoint saved: 9500 rows
#   Checkpoint saved: 9600 rows
#   Checkpoint saved: 9700 rows
#   Checkpoint saved: 9800 rows
#   Checkpoint saved: 9900 rows
#   Checkpoint saved: 10000 rows
#   Checkpoint saved: 10100 rows
#   Checkpoint saved: 10200 rows
#   Checkpoint saved: 10300 rows
# Done. Generated 10302 rows.

# %%
df = pd.DataFrame(simplified_data_grouped)
df.to_csv(f"samer_simplified_part{PART}_final.csv", index=False)
print(f"Saved {len(df)} rows to samer_simplified_part{PART}_final.csv")
print(df.head())
# Out:
# Saved 10302 rows to samer_simplified_partB_final.csv
#                                    Original_Sentence  \
# 0  وكان في غدوهما ورواحهما قد زلفهما زبزب يسرح وي...
# 1             فما زال الطفل مع الظباء على تلك الحال،
# 2         يحكي نغمتها بصوته حتى لا يكاد يفرق بينهما.
# 3  وكذلك كان يحكي جميع ما يسمعه من أصوات الطير وأ...
# 4  وأكثر ما كانت محاكاته لأصوات الظباء في الاستصر...
#
#                                      Sentence_Level1  \
# 0  كانا يسيران معاً ذهاباً وإياباً، وكان زبزب يرا...
# 1                       الطفل ما زال يرعى مع الظباء.
# 2             يحاكي نغمة صوتها حتى يختلط عليه الأمر.
# 3      كان يحكي ما يسمعه من أصوات الطيور والحيوانات.
# 4                           كانت تحاكي أصوات الظباء.
#
#                                      Sentence_Level2  \
# 0            كان زبزباً يسرح معهما ويبيت حيث يبيتان.
# 1           ما زال الطفل مع الظباء في حالة من اللعب.
# 2             يحاكي نغمتها بصوته حتى يختلط صوته بها.
# 3  كان يحكي ما يسمعه من أصوات الطيور وأنواع الحيو...
# 4  كانت محاكاة أصوات الظباء جزءًا من استصراخها وا...
#
#                                      Sentence_Level3 Novel Chapter  \
# 0  وكان في غدوهما ورواحهما قد زلفهما ساعيًا يسرح ...     5     1.2
# 1                   ما زال الطفل مع الظباء على حاله.     5     1.2
# 2          يحاكي نغمتها في حديثه حتى يختلط صوته بها.     5     1.2
# 3  وكذلك كان يحكي جميع ما يسمعه من أصوات الطيور و...     5     1.2
# 4  كانت محاكاة أصوات الظباء في الاستصراخ، والاستئ...     5     1.2
#
#                                                   L4  \
# 0  وكان في إيابهما وذهابهما قد تبعهما حيوان يسرح ...
# 1             فما زال الطفل مع الظباء على تلك الحال،
# 2         يحكي نغمتها بصوته حتى لا يكاد يفرق بينهما.
# 3  وكذلك كان يحكي جميع ما يسمعه من أصوات الطير وأ...
# 4  وأكثر ما كان تقليده لأصوات الظباء في الاستغاثة...
#
#                                                   L3 Line Source
# 0  وكان في مجيئهما وذهابهما قد تبعهما حيوان يسرح ...    7  SAMER
# 1             فما زال الطفل مع الظباء على تلك الحال،    8  SAMER
# 2         يحكي نغمتها بصوته حتى يصعب أن يفرق بينهما.    8  SAMER
# 3  وكذلك كان يحكي جميع ما يسمعه من أصوات الطير وأ...    8  SAMER
# 4  وأكثر ما كان تقليده لأصوات الظباء في الاستغاثة...    8  SAMER

# %%
for entry in simplified_data_grouped[:5]:
    print("Original:  ", entry["Original_Sentence"])
    for lvl in [1, 2, 3]:
        label = {1: "Level 1 (simplest)", 2: "Level 2", 3: "Level 3"}[lvl]
        val = entry.get(f"Sentence_Level{lvl}")
        print(f"  {label}: {val if val else '[invalid]'}")
    print("-" * 60)
# Out:
# Original:   وكان في غدوهما ورواحهما قد زلفهما زبزب يسرح ويبيت معهما حيث مبيتهما.
#   Level 1 (simplest): كانا يسيران معاً ذهاباً وإياباً، وكان زبزب يرافقهما، يلعب معهما ويمرح.
#   Level 2: كان زبزباً يسرح معهما ويبيت حيث يبيتان.
#   Level 3: وكان في غدوهما ورواحهما قد زلفهما ساعيًا يسرح ويبيت معهما حيث مبيتهما.
# ------------------------------------------------------------
# Original:   فما زال الطفل مع الظباء على تلك الحال،
#   Level 1 (simplest): الطفل ما زال يرعى مع الظباء.
#   Level 2: ما زال الطفل مع الظباء في حالة من اللعب.
#   Level 3: ما زال الطفل مع الظباء على حاله.
# ------------------------------------------------------------
# Original:   يحكي نغمتها بصوته حتى لا يكاد يفرق بينهما.
#   Level 1 (simplest): يحاكي نغمة صوتها حتى يختلط عليه الأمر.
#   Level 2: يحاكي نغمتها بصوته حتى يختلط صوته بها.
#   Level 3: يحاكي نغمتها في حديثه حتى يختلط صوته بها.
# ------------------------------------------------------------
# Original:   وكذلك كان يحكي جميع ما يسمعه من أصوات الطير وأنواع سائر الحيوان محاكاة شديدة لقوة انفعاله لما يريده.
#   Level 1 (simplest): كان يحكي ما يسمعه من أصوات الطيور والحيوانات.
#   Level 2: كان يحكي ما يسمعه من أصوات الطيور وأنواع الحيوانات المختلفة، وكان يحاكيهم أيضاً بسبب انفعاله الشديد لما يريده.
#   Level 3: وكذلك كان يحكي جميع ما يسمعه من أصوات الطيور وأنواع سائر الحيوانات، محاكاة لقوة انفعاله الشديدة تجاه رغبته.
# ------------------------------------------------------------
# Original:   وأكثر ما كانت محاكاته لأصوات الظباء في الاستصراخ والاستئلاف والاستدعاء والاستدفاع؛
#   Level 1 (simplest): كانت تحاكي أصوات الظباء.
#   Level 2: كانت محاكاة أصوات الظباء جزءًا من استصراخها واستئلافها واستدعائها واستدفاعها.
#   Level 3: كانت محاكاة أصوات الظباء في الاستصراخ، والاستئلاف، والاستدعاء، والاستدفاع.
# ------------------------------------------------------------
