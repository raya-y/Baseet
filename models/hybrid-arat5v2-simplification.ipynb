# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/naghamalshbrawi/9302-w/9203_arabic_words.csv
# /kaggle/input/datasets/naghamalshbrawi/arat5-predicition/final_df_with_AraT5_simplifications.csv

# %%
# !pip install camel-tools
# Out:
# Collecting camel-tools
#   Downloading camel_tools-1.5.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.17.0)
# Collecting docopt (from camel-tools)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cachetools<=6.0.0 (from camel-tools)
#   Downloading cachetools-6.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy<2 (from camel-tools)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.3.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.6.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from camel-tools) (0.4.1)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.10.0+cu128)
# Collecting transformers<4.44.0,>=4.0 (from camel-tools)
#   Downloading transformers-4.43.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: editdistance in /usr/local/lib/python3.12/dist-packages (from camel-tools) (0.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.32.4)
# Requirement already satisfied: emoji in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.15.0)
# Collecting pyrsistent (from camel-tools)
#   Downloading pyrsistent-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from camel-tools) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from camel-tools) (4.67.3)
# Collecting muddler (from camel-tools)
#   Downloading muddler-0.1.3-py3-none-any.whl.metadata (7.5 kB)
# Collecting camel-kenlm<=2025.09.16 (from camel-tools)
#   Downloading camel_kenlm-2025.9.16-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (251 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0->camel-tools) (1.3.5)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers<4.44.0,>=4.0->camel-tools)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (0.7.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers<4.44.0,>=4.0->camel-tools)
#   Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->camel-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->camel-tools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->camel-tools) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->camel-tools) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->camel-tools) (3.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers<4.44.0,>=4.0->camel-tools) (1.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->camel-tools) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->camel-tools) (3.0.3)
# Downloading camel_tools-1.5.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 4.9 MB/s eta 0:00:00
# Downloading cachetools-6.0.0-py3-none-any.whl (10 kB)
# Downloading camel_kenlm-2025.9.16-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 46.0 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 80.6 MB/s eta 0:00:00:00:0100:01
# Downloading transformers-4.43.4-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 80.8 MB/s eta 0:00:00:00:0100:01
# Downloading muddler-0.1.3-py3-none-any.whl (16 kB)
# Downloading pyrsistent-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 9.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 36.6 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 100.7 MB/s eta 0:00:0000:01
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=983102e83111b8661e7ca27c54416acf57cef7eb5f34b7fe329039b4445d5fdf
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, camel-kenlm, pyrsistent, numpy, muddler, cachetools, huggingface-hub, tokenizers, transformers, camel-tools
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.6
#     Uninstalling cachetools-6.2.6:
#       Successfully uninstalled cachetools-6.2.6
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# kaggle-environments 1.27.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed cachetools-6.0.0 camel-kenlm-2025.9.16 camel-tools-1.5.7 docopt-0.6.2 huggingface-hub-0.36.2 muddler-0.1.3 numpy-1.26.4 pyrsistent-0.20.0 tokenizers-0.19.1 transformers-4.43.4

# %%
import pandas as pd
import re
from camel_tools.tokenizers.word import simple_word_tokenize
from camel_tools.disambig.mle import MLEDisambiguator

# %%
# !pip install --upgrade --force-reinstall numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 91.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# camel-tools 1.5.7 requires numpy<2, but you have numpy 2.4.4 which is incompatible.
# ydata-profiling 4.18.1 requires numpy<2.4,>=1.22, but you have numpy 2.4.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.4 which is incompatible.
# Successfully installed numpy-2.4.4

# %%
file_path = "/kaggle/input/datasets/naghamalshbrawi/arat5-predicition/final_df_with_AraT5_simplifications.csv"
final_df = pd.read_csv(file_path)
final_df = final_df.reset_index(drop=True)
print(final_df.shape)
# Out:
# (34294, 7)

# %%
final_df.head(1)
# Out:
#                               Original_Sentence  \
# 0  •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
#
#                                       ref_level_3  \
# 0  "عدم الانحياز" هو مصطلح سياسي يشير إلى الحياد.
#
#                                          ref_level_2  \
# 0  "عدم الانحياز" هو مصطلح سياسي يعني أن تكون محا...
#
#                                          ref_level_1  \
# 0  "عدم الانحياز" يعني أن تكون محايداً ولا تفضل أ...
#
#                               pred_level_3  \
# 0  "عدم الانحياز" مصطلح سياسي يعني الحياد.
#
#                               pred_level_2  \
# 0  "عدم الانحياز" مصطلح سياسي يعني الحياد.
#
#                                         pred_level_1
# 0  عدم الانحياز هو الحياد في الأمور السياسية، وهو...

# %%
list_path = "/kaggle/input/datasets/naghamalshbrawi/9302-w/9203_arabic_words.csv"
list_df = pd.read_csv(list_path)

# %%
ARABIC_DIACRITICS = re.compile(r"""
    [\u0617-\u061A]
  | [\u064B-\u0652]
  | [\u0657-\u065F]
  | [\u0670]
  | [\u06D6-\u06ED]
  | [\u0640]
""", re.VERBOSE)

ARABIC_LETTERS_PATTERN = re.compile(r'[\u0600-\u06FF]')
ARABIC_DIGITS_PATTERN = re.compile(r'^[0-9\u0660-\u0669]+$')

def remove_diacritics(text):
    if pd.isna(text):
        return ""
    return re.sub(ARABIC_DIACRITICS, "", str(text))

def normalize_arabic(text):
    if pd.isna(text):
        return ""
    text = str(text)
    text = remove_diacritics(text)
    text = re.sub(r"[إأآٱ]", "ا", text)
    text = text.replace("ؤ", "و")
    text = text.replace("ئ", "ي")
    text = text.replace("ى", "ي")
    text = re.sub(r"\s+", " ", text).strip()
    return text

def strip_punct(token):
    """Remove punctuation around token."""
    token = str(token)
    token = re.sub(r"^[^\u0600-\u06FF0-9]+|[^\u0600-\u06FF0-9]+$", "", token)
    return token.strip()

def is_arabic_word(token):
    """Keep only tokens that contain Arabic letters."""
    return bool(ARABIC_LETTERS_PATTERN.search(str(token)))

# %%
freq_raw_set = set(
    list_df["Arabic"].dropna().astype(str).str.strip()
)

freq_no_diac_set = set(
    list_df["arabic_no_diacritics"].dropna().astype(str).str.strip()
)

freq_norm_set = set(
    list_df["arabic_normalized"].dropna().astype(str).str.strip()
)

# %%
# !camel_data -i all
# Out:
# The following packages will be installed: 'disambig-ranking-cache-calima-msa-r13', 'dialectid-model26', 'morphology-db-msa-s31', 'disambig-ranking-cache-calima-glf-01', 'sentiment-analysis-mbert', 'disambig-bert-unfactored-lev', 'disambig-ranking-cache-calima-lev-01', 'morphology-db-msa-r13', 'disambig-mle-calima-msa-r13', 'morphology-db-egy-r13', 'disambig-mle-calima-egy-r13', 'disambig-bert-unfactored-glf', 'dialectid-model6', 'morphology-db-glf-01', 'disambig-ranking-cache-calima-egy-r13', 'disambig-bert-unfactored-egy', 'disambig-bert-unfactored-msa', 'morphology-db-lev-01', 'ner-arabert', 'sentiment-analysis-arabert'
# Downloading package 'disambig-ranking-cache-calima-msa-r13': 100%|█| 556M/556M [
# Extracting package 'disambig-ranking-cache-calima-msa-r13': 100%|█| 556M/556M [0
# Downloading package 'dialectid-model26': 100%|█| 371M/371M [00:02<00:00, 181MB/s
# Extracting package 'dialectid-model26': 100%|█| 371M/371M [00:00<00:00, 581MB/s]
# Downloading package 'morphology-db-msa-s31': 100%|█| 44.8M/44.8M [00:00<00:00, 1
# Extracting package 'morphology-db-msa-s31': 100%|█| 44.8M/44.8M [00:00<00:00, 59
# Downloading package 'disambig-ranking-cache-calima-glf-01': 100%|█| 28.7M/28.7M
# Extracting package 'disambig-ranking-cache-calima-glf-01': 100%|█| 28.7M/28.7M [
# Downloading package 'sentiment-analysis-mbert': 100%|█| 712M/712M [00:03<00:00,
# Extracting package 'sentiment-analysis-mbert': 100%|█| 712M/712M [00:01<00:00, 5
# Downloading package 'disambig-bert-unfactored-lev': 100%|█| 441M/441M [00:01<00:
# Extracting package 'disambig-bert-unfactored-lev': 100%|█| 441M/441M [00:00<00:0
# Downloading package 'disambig-ranking-cache-calima-lev-01': 100%|█| 23.2M/23.2M
# Extracting package 'disambig-ranking-cache-calima-lev-01': 100%|█| 23.2M/23.2M [
# Downloading package 'morphology-db-msa-r13': 100%|█| 40.5M/40.5M [00:00<00:00, 1
# Extracting package 'morphology-db-msa-r13': 100%|█| 40.5M/40.5M [00:00<00:00, 58
# Downloading package 'disambig-mle-calima-msa-r13': 100%|█| 88.7M/88.7M [00:00<00
# Extracting package 'disambig-mle-calima-msa-r13': 100%|█| 88.7M/88.7M [00:00<00:
# Downloading package 'morphology-db-egy-r13': 100%|█| 67.3M/67.3M [00:00<00:00, 1
# Extracting package 'morphology-db-egy-r13': 100%|█| 67.3M/67.3M [00:00<00:00, 56
# Downloading package 'disambig-mle-calima-egy-r13': 100%|█| 27.2M/27.2M [00:00<00
# Extracting package 'disambig-mle-calima-egy-r13': 100%|█| 27.2M/27.2M [00:00<00:
# Downloading package 'disambig-bert-unfactored-glf': 100%|█| 442M/442M [00:01<00:
# Extracting package 'disambig-bert-unfactored-glf': 100%|█| 442M/442M [00:00<00:0
# Downloading package 'dialectid-model6': 100%|█| 153M/153M [00:00<00:00, 223MB/s]
# Extracting package 'dialectid-model6': 100%|██| 153M/153M [00:00<00:00, 574MB/s]
# Downloading package 'morphology-db-glf-01': 100%|█| 7.98M/7.98M [00:00<00:00, 84
# Extracting package 'morphology-db-glf-01': 100%|█| 7.98M/7.98M [00:00<00:00, 572
# Downloading package 'disambig-ranking-cache-calima-egy-r13': 100%|█| 320M/320M [
# Extracting package 'disambig-ranking-cache-calima-egy-r13': 100%|█| 320M/320M [0
# Downloading package 'disambig-bert-unfactored-egy': 100%|█| 446M/446M [00:03<00:
# Extracting package 'disambig-bert-unfactored-egy': 100%|█| 446M/446M [00:00<00:0
# Downloading package 'disambig-bert-unfactored-msa': 100%|█| 445M/445M [00:02<00:
# Extracting package 'disambig-bert-unfactored-msa': 100%|█| 445M/445M [00:00<00:0
# Downloading package 'morphology-db-lev-01': 100%|█| 10.6M/10.6M [00:00<00:00, 10
# Extracting package 'morphology-db-lev-01': 100%|█| 10.6M/10.6M [00:00<00:00, 485
# Downloading package 'ner-arabert': 100%|██████| 542M/542M [00:02<00:00, 204MB/s]
# Extracting package 'ner-arabert': 100%|███████| 542M/542M [00:00<00:00, 584MB/s]
# Downloading package 'sentiment-analysis-arabert': 100%|█| 542M/542M [00:02<00:00
# Extracting package 'sentiment-analysis-arabert': 100%|█| 542M/542M [00:00<00:00,

# %%
mle = MLEDisambiguator.pretrained()

def get_best_analysis(token):
    """
    Return best CAMeL analysis dictionary for a token.
    If it fails, return empty dict.
    """
    try:
        disambig = mle.disambiguate([token])
        if not disambig or not disambig[0].analyses:
            return {}
        return disambig[0].analyses[0].analysis
    except:
        return {}

def get_pos(token):
    analysis = get_best_analysis(token)
    return analysis.get("pos", "")

def get_lemma(token):
    """
    Use CAMeL lemma as a fallback lemma signal.
    In your full replication, Farasa can replace/confirm this later.
    """
    analysis = get_best_analysis(token)
    lemma = analysis.get("lex", "") or analysis.get("lemma", "")
    return str(lemma).strip()

# %%
# The paper excludes prepositions before checking complexity.
# Since automatic POS tagging is not always perfect for function words,
# we also keep a manual Arabic preposition list as a safety layer.

PREPOSITIONS = {
    "في", "من", "الى", "إلى", "عن", "على", "ب", "ل", "ك", "حتى",
    "منذ", "مذ", "خلال", "دون", "عند", "بين", "نحو", "حول", "مع",
    "لدى", "تحت", "فوق", "وراء", "أمام", "داخل", "خارج", "بعد", "قبل"
}

# We also normalize them once so comparison is consistent
PREPOSITIONS_NORM = {normalize_arabic(p) for p in PREPOSITIONS}

# %%
def is_number_token(token, pos_tag=""):
    token = str(token).strip()
    pos_tag = str(pos_tag).lower()
    return ARABIC_DIGITS_PATTERN.match(token) is not None or pos_tag.startswith("num")

def is_proper_noun(pos_tag=""):
    pos_tag = str(pos_tag).lower()
    return pos_tag.startswith("noun_prop")

def is_preposition(token, pos_tag=""):
    pos_tag = str(pos_tag).lower()
    if normalize_arabic(token) in PREPOSITIONS_NORM:
        return True
    if pos_tag.startswith("prep"):
        return True
    return False

# %%
import re
import pandas as pd

def split_variants_enhanced(text):
    """
    Splits a cell into individual words to ensure every single word
    is captured in the lookup set.
    """
    if pd.isna(text):
        return []

    text = str(text).strip()
    if not text:
        return []

    # 1. Split by common separators (Arabic comma, English comma, semicolon, slash)
    parts = re.split(r'[،,;/]+', text)

    final_words = []
    for part in parts:
        # 2. Split each part by spaces to extract individual words
        words = part.split()
        final_words.extend(words)

    # 3. Clean words from punctuation (like parentheses or periods)
    clean_words = [re.sub(r'[^\w\s]', '', w).strip() for w in final_words if w.strip()]

    return clean_words

def build_variant_set(series):
    """
    Iterates through a column and builds a unique set of all
    individual words found in those cells.
    """
    values = set()
    for cell in series.dropna():
        # Get the list of individual words from the enhanced splitter
        for item in split_variants_enhanced(cell):
            values.add(item)
    return values


freq_raw_set = build_variant_set(list_df["Arabic"])

# Example check:
# Even if the Excel cell says "سباق السيارات", this will now return True
print("السيارات" in freq_raw_set)
# Out:
# True

# %%
def exists_in_frequency_list(token, lemma=""):
    """
    A word is considered found if ANY of these match the list:
    - raw token
    - token without diacritics
    - normalized token
    - raw lemma
    - lemma without diacritics
    - normalized lemma
    """
    candidates = set()

    token = strip_punct(token)
    lemma = strip_punct(lemma)

    if token:
        candidates.add(str(token).strip())
        candidates.add(remove_diacritics(token).strip())
        candidates.add(normalize_arabic(token).strip())

    if lemma:
        candidates.add(str(lemma).strip())
        candidates.add(remove_diacritics(lemma).strip())
        candidates.add(normalize_arabic(lemma).strip())

    # remove empty items
    candidates = {c for c in candidates if c}

    for c in candidates:
        if c in freq_raw_set or c in freq_no_diac_set or c in freq_norm_set:
            return True, sorted(candidates)

    return False, sorted(candidates)

# %%
def identify_complex_words(sentence):
    """
    For one sentence:
    - tokenize
    - clean punctuation
    - exclude proper nouns, prepositions, and numbers
    - check token and lemma against frequency list
    - if found in the frequency list -> exclude from complexity candidates
    - if not found -> treat as complex
    """
    if pd.isna(sentence):
        return []

    tokens = simple_word_tokenize(str(sentence))
    results = []

    for token in tokens:
        cleaned_token = strip_punct(token)

        # Skip empty or punctuation-only tokens
        if not cleaned_token:
            continue

        # Skip non-Arabic tokens
        if not is_arabic_word(cleaned_token):
            continue

        analysis = get_best_analysis(cleaned_token)
        pos_tag = analysis.get("pos", "")
        lemma = analysis.get("lex", "") or analysis.get("lemma", "")

        # Exclude proper nouns
        if is_proper_noun(pos_tag):
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "proper_noun",
                "lookup_candidates": [],
                "in_frequency_list": None,
                "is_complex": False
            })
            continue

        # Exclude prepositions
        if is_preposition(cleaned_token, pos_tag):
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "preposition",
                "lookup_candidates": [],
                "in_frequency_list": None,
                "is_complex": False
            })
            continue

        # Exclude numbers
        if is_number_token(cleaned_token, pos_tag):
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "number",
                "lookup_candidates": [],
                "in_frequency_list": None,
                "is_complex": False
            })
            continue

        # Check whether the word exists in the frequency list
        in_freq, lookup_candidates = exists_in_frequency_list(cleaned_token, lemma)

        # If found in the list, exclude it from complex-word candidates
        if in_freq:
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "in_frequency_list",
                "lookup_candidates": lookup_candidates,
                "in_frequency_list": True,
                "is_complex": False
            })
            continue

        # Otherwise, the word is treated as complex
        results.append({
            "token": cleaned_token,
            "lemma": lemma,
            "pos": pos_tag,
            "excluded": False,
            "exclude_reason": "",
            "lookup_candidates": lookup_candidates,
            "in_frequency_list": False,
            "is_complex": True
        })

    return results

# %%
# This creates:
# - cwi_details: full token-level analysis
# - complex_words: only the tokens marked as complex
final_df["l3_cwi_details"] = final_df["pred_level_3"].apply(identify_complex_words)
final_df["l3_complex_words"] = final_df["l3_cwi_details"].apply(
    lambda rows: [r["token"] for r in rows if r["is_complex"]]
)

final_df["l2_cwi_details"] = final_df["pred_level_2"].apply(identify_complex_words)
final_df["l2_complex_words"] = final_df["l2_cwi_details"].apply(
    lambda rows: [r["token"] for r in rows if r["is_complex"]]
)

final_df["l1_cwi_details"] = final_df["pred_level_1"].apply(identify_complex_words)
final_df["l1_complex_words"] = final_df["l1_cwi_details"].apply(
    lambda rows: [r["token"] for r in rows if r["is_complex"]]
)

# %%
# quick preview for all hybrid levels
for i in range(min(5, len(final_df))):
    print("=" * 100)
    print("Original_Text:", final_df.loc[i, "Original_Sentence"])

    for level in ["3", "2", "1"]:
        print("-" * 80)
        print(f"AraBART Pred L{level}:", final_df.loc[i, f"pred_level_{level}"])
        print(f"Complex words L{level}:", final_df.loc[i, f"l{level}_complex_words"])
        print(f"Details L{level}:")
        for row in final_df.loc[i, f"l{level}_cwi_details"]:
            print(row)
# Out:
# ====================================================================================================
# Original_Text: •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
# --------------------------------------------------------------------------------
# AraBART Pred L3: "عدم الانحياز" مصطلح سياسي يعني الحياد.
# Complex words L3: ['الانحياز', 'سياسي', 'الحياد']
# Details L3:
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'مصطلح', 'lemma': 'مُصْطَلَح', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سياسي', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'يعني', 'lemma': 'عَنَى', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عنى', 'عني', 'عَنَى', 'يعني'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الحياد', 'lemma': 'حِياد', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الحياد', 'حياد', 'حِياد'], 'in_frequency_list': False, 'is_complex': True}
# --------------------------------------------------------------------------------
# AraBART Pred L2: "عدم الانحياز" مصطلح سياسي يعني الحياد.
# Complex words L2: ['الانحياز', 'سياسي', 'الحياد']
# Details L2:
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'مصطلح', 'lemma': 'مُصْطَلَح', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سياسي', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'يعني', 'lemma': 'عَنَى', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عنى', 'عني', 'عَنَى', 'يعني'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الحياد', 'lemma': 'حِياد', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الحياد', 'حياد', 'حِياد'], 'in_frequency_list': False, 'is_complex': True}
# --------------------------------------------------------------------------------
# AraBART Pred L1: عدم الانحياز هو الحياد في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# Complex words L1: ['الانحياز', 'الحياد', 'السياسية', '،', 'الانحياز']
# Details L1:
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'هو', 'lemma': 'هُوَ', 'pos': 'pron', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هو', 'هُوَ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الحياد', 'lemma': 'حِياد', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الحياد', 'حياد', 'حِياد'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الأمور', 'lemma': 'أَمْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أمر', 'أَمْر', 'الأمور', 'الامور', 'امر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'السياسية', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['السياسية', 'سياسي', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'وهو', 'lemma': 'هُوَ', 'pos': 'pron', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هو', 'هُوَ', 'وهو'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مصطلح', 'lemma': 'مُصْطَلَح', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يعني', 'lemma': 'عَنَى', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عنى', 'عني', 'عَنَى', 'يعني'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# ====================================================================================================
# Original_Text: حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# --------------------------------------------------------------------------------
# AraBART Pred L3: تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# Complex words L3: ['المنحازة']
# Details L3:
# {'token': 'تلتزم', 'lemma': 'ٱِلْتَزَم', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التزم', 'تلتزم', 'ٱلتزم', 'ٱِلْتَزَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'بعدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بعدم', 'عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الارتباط', 'lemma': 'ٱِرْتِباط', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['ارتباط', 'الارتباط', 'ٱرتباط', 'ٱِرْتِباط'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الشرق', 'lemma': 'شَرْق', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'أو', 'lemma': 'أَو', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أو', 'أَو', 'او'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الغرب', 'lemma': 'غَرْب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الغرب', 'غرب', 'غَرْب'], 'in_frequency_list': True, 'is_complex': False}
# --------------------------------------------------------------------------------
# AraBART Pred L2: تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# Complex words L2: ['المنحازة']
# Details L2:
# {'token': 'تلتزم', 'lemma': 'ٱِلْتَزَم', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التزم', 'تلتزم', 'ٱلتزم', 'ٱِلْتَزَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'بعدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بعدم', 'عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الارتباط', 'lemma': 'ٱِرْتِباط', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['ارتباط', 'الارتباط', 'ٱرتباط', 'ٱِرْتِباط'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الشرق', 'lemma': 'شَرْق', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'أو', 'lemma': 'أَو', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أو', 'أَو', 'او'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الغرب', 'lemma': 'غَرْب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الغرب', 'غرب', 'غَرْب'], 'in_frequency_list': True, 'is_complex': False}
# --------------------------------------------------------------------------------
# AraBART Pred L1: الدول غير المنحازة لا تتعامل مع دول الشرق أو الغرب.
# Complex words L1: ['المنحازة']
# Details L1:
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'لا', 'lemma': 'لا', 'pos': 'part_neg', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تتعامل', 'lemma': 'تَعامَل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تتعامل', 'تعامل', 'تَعامَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مع', 'lemma': 'مَع', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'دول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الشرق', 'lemma': 'شَرْق', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'أو', 'lemma': 'أَو', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أو', 'أَو', 'او'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الغرب', 'lemma': 'غَرْب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الغرب', 'غرب', 'غَرْب'], 'in_frequency_list': True, 'is_complex': False}
# ====================================================================================================
# Original_Text: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# --------------------------------------------------------------------------------
# AraBART Pred L3: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Complex words L3: ['المنحازة', 'المتفرج', 'العالمية', '،', '،']
# Details L3:
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'لا', 'lemma': 'لا', 'pos': 'part_neg', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تقف', 'lemma': 'وَقَف', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تقف', 'وقف', 'وَقَف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'موقف', 'lemma': 'مَوْقِف', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['موقف', 'مَوْقِف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتفرج', 'lemma': 'مُتَفَرِّج', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المتفرج', 'متفرج', 'مُتَفَرِّج'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أمام', 'lemma': 'أَمام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'المشاكل', 'lemma': 'مُشْكِلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المشاكل', 'مشكلة', 'مُشْكِلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'والأحداث', 'lemma': 'حَدَث', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حدث', 'حَدَث', 'والأحداث', 'والاحداث'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'العالمية', 'lemma': 'عالَمِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العالمية', 'عالمي', 'عالَمِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'بل', 'lemma': 'بَل', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بل', 'بَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لها', 'lemma': 'لِ', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'دور', 'lemma': 'دَوْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دور', 'دَوْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يسير', 'lemma': 'سار', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سار', 'يسير'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مع', 'lemma': 'مَع', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مصالحها', 'lemma': 'مَصْلَحَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصالحها', 'مصلحة', 'مَصْلَحَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'وليس', 'lemma': 'أَلْيَس', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أليس', 'أَلْيَس', 'اليس', 'وليس'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مع', 'lemma': 'مَع', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مصالح', 'lemma': 'مَصْلَحَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصالح', 'مصلحة', 'مَصْلَحَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتصارعة', 'lemma': 'متصارعه', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# --------------------------------------------------------------------------------
# AraBART Pred L2: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Complex words L2: ['المنحازة', 'المتفرج', 'العالمية', '،', '،']
# Details L2:
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'لا', 'lemma': 'لا', 'pos': 'part_neg', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تقف', 'lemma': 'وَقَف', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تقف', 'وقف', 'وَقَف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'موقف', 'lemma': 'مَوْقِف', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['موقف', 'مَوْقِف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتفرج', 'lemma': 'مُتَفَرِّج', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المتفرج', 'متفرج', 'مُتَفَرِّج'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أمام', 'lemma': 'أَمام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'المشاكل', 'lemma': 'مُشْكِلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المشاكل', 'مشكلة', 'مُشْكِلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'والأحداث', 'lemma': 'حَدَث', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حدث', 'حَدَث', 'والأحداث', 'والاحداث'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'العالمية', 'lemma': 'عالَمِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العالمية', 'عالمي', 'عالَمِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'بل', 'lemma': 'بَل', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بل', 'بَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لها', 'lemma': 'لِ', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'دور', 'lemma': 'دَوْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دور', 'دَوْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يسير', 'lemma': 'سار', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سار', 'يسير'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مع', 'lemma': 'مَع', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مصالحها', 'lemma': 'مَصْلَحَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصالحها', 'مصلحة', 'مَصْلَحَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'وليس', 'lemma': 'أَلْيَس', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أليس', 'أَلْيَس', 'اليس', 'وليس'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مع', 'lemma': 'مَع', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مصالح', 'lemma': 'مَصْلَحَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصالح', 'مصلحة', 'مَصْلَحَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتصارعة', 'lemma': 'متصارعه', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# --------------------------------------------------------------------------------
# AraBART Pred L1: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.
# Complex words L1: ['المنحازة', 'المتفرج', 'العالمية']
# Details L1:
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'لا', 'lemma': 'لا', 'pos': 'part_neg', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تقف', 'lemma': 'وَقَف', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تقف', 'وقف', 'وَقَف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'موقف', 'lemma': 'مَوْقِف', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['موقف', 'مَوْقِف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتفرج', 'lemma': 'مُتَفَرِّج', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المتفرج', 'متفرج', 'مُتَفَرِّج'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أمام', 'lemma': 'أَمام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'المشاكل', 'lemma': 'مُشْكِلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المشاكل', 'مشكلة', 'مُشْكِلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'والأحداث', 'lemma': 'حَدَث', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حدث', 'حَدَث', 'والأحداث', 'والاحداث'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'العالمية', 'lemma': 'عالَمِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العالمية', 'عالمي', 'عالَمِيّ'], 'in_frequency_list': False, 'is_complex': True}
# ====================================================================================================
# Original_Text: وقد بدأ استعمال اصطلاح (عدم الانحياز) في مؤتمر بلغراد عام 1961، والذي اشتركت فيه 21 دولة غير منحازة
# --------------------------------------------------------------------------------
# AraBART Pred L3: وقد بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير منحازة.
# Complex words L3: ['الانحياز', '،', 'منحازة']
# Details L3:
# {'token': 'وقد', 'lemma': 'قَدْ', 'pos': 'part_verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قد', 'قَدْ', 'وقد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بدأ', 'lemma': 'بَدَأ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بدأ', 'بدا', 'بَدَأ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'استخدام', 'lemma': 'ٱِسْتِخْدام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استخدام', 'ٱستخدام', 'ٱِسْتِخْدام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مصطلح', 'lemma': 'مُصْطَلَح', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مؤتمر', 'lemma': 'مُؤْتَمَر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مؤتمر', 'موتمر', 'مُؤْتَمَر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بلغراد', 'lemma': 'بَلْغراد', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'عام', 'lemma': 'عام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'حيث', 'lemma': 'حَيْثُ', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حيث', 'حَيْثُ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'شاركت', 'lemma': 'شارَك', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['شارك', 'شاركت', 'شارَك'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'دولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'منحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['منحاز', 'منحازة', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# --------------------------------------------------------------------------------
# AraBART Pred L2: بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير منحازة.
# Complex words L2: ['الانحياز', '،', 'منحازة']
# Details L2:
# {'token': 'بدأ', 'lemma': 'بَدَأ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بدأ', 'بدا', 'بَدَأ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'استخدام', 'lemma': 'ٱِسْتِخْدام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استخدام', 'ٱستخدام', 'ٱِسْتِخْدام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مصطلح', 'lemma': 'مُصْطَلَح', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مؤتمر', 'lemma': 'مُؤْتَمَر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مؤتمر', 'موتمر', 'مُؤْتَمَر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بلغراد', 'lemma': 'بَلْغراد', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'عام', 'lemma': 'عام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'حيث', 'lemma': 'حَيْثُ', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حيث', 'حَيْثُ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'شاركت', 'lemma': 'شارَك', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['شارك', 'شاركت', 'شارَك'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'دولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'منحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['منحاز', 'منحازة', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# --------------------------------------------------------------------------------
# AraBART Pred L1: بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير منحازة.
# Complex words L1: ['الانحياز', '،', 'منحازة']
# Details L1:
# {'token': 'بدأ', 'lemma': 'بَدَأ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بدأ', 'بدا', 'بَدَأ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'استخدام', 'lemma': 'ٱِسْتِخْدام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استخدام', 'ٱستخدام', 'ٱِسْتِخْدام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مصطلح', 'lemma': 'مُصْطَلَح', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مؤتمر', 'lemma': 'مُؤْتَمَر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مؤتمر', 'موتمر', 'مُؤْتَمَر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بلغراد', 'lemma': 'بَلْغراد', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'عام', 'lemma': 'عام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'حيث', 'lemma': 'حَيْثُ', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حيث', 'حَيْثُ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'شاركت', 'lemma': 'شارَك', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['شارك', 'شاركت', 'شارَك'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'دولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'منحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['منحاز', 'منحازة', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# ====================================================================================================
# Original_Text: ••السيارات التي يستعملها الدبلوماسيون.. أي رجال السفارات المعتمدون لدى الدولة تحمل هذه الجملة (هيئة سياسية).
# --------------------------------------------------------------------------------
# AraBART Pred L3: السيارات التي يستخدمها الدبلوماسيون، أي رجال السفارات المعتمدون لدى الدولة، تحمل هذه الجملة (هيئة سياسية).
# Complex words L3: ['،', '،', 'سياسية']
# Details L3:
# {'token': 'السيارات', 'lemma': 'سَيّارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السيارات', 'سيارة', 'سَيّارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'التي', 'lemma': 'الَّذِي', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التي', 'الذي', 'الَّذِي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يستخدمها', 'lemma': 'ٱِسْتَخْدَم', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استخدم', 'يستخدمها', 'ٱستخدم', 'ٱِسْتَخْدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدبلوماسيون', 'lemma': 'دِبلُوماسِيّ', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدبلوماسيون', 'دبلوماسي', 'دِبلُوماسِيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أي', 'lemma': 'أَيّ', 'pos': 'pron_interrog', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أي', 'أَيّ', 'اي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'رجال', 'lemma': 'رَجُل', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['رجال', 'رجل', 'رَجُل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'السفارات', 'lemma': 'سِفارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السفارات', 'سفارة', 'سِفارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المعتمدون', 'lemma': 'مُعْتَمَد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المعتمدون', 'معتمد', 'مُعْتَمَد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لدى', 'lemma': 'لَدَى', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الدولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدولة', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'تحمل', 'lemma': 'حَمَل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تحمل', 'حمل', 'حَمَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هذه', 'lemma': 'هٰذا', 'pos': 'pron_dem', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هذا', 'هذه', 'هٰذا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الجملة', 'lemma': 'جُمْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الجملة', 'جملة', 'جُمْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هيئة', 'lemma': 'هَيْئَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هيئة', 'هيية', 'هَيْئَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سياسية', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سياسية', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# --------------------------------------------------------------------------------
# AraBART Pred L2: السيارات التي يستخدمها الدبلوماسيون، أي رجال السفارات المعتمدة لدى الدولة، تحمل هذه الجملة (هيئة سياسية).
# Complex words L2: ['،', '،', 'سياسية']
# Details L2:
# {'token': 'السيارات', 'lemma': 'سَيّارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السيارات', 'سيارة', 'سَيّارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'التي', 'lemma': 'الَّذِي', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التي', 'الذي', 'الَّذِي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يستخدمها', 'lemma': 'ٱِسْتَخْدَم', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استخدم', 'يستخدمها', 'ٱستخدم', 'ٱِسْتَخْدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدبلوماسيون', 'lemma': 'دِبلُوماسِيّ', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدبلوماسيون', 'دبلوماسي', 'دِبلُوماسِيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أي', 'lemma': 'أَيّ', 'pos': 'pron_interrog', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أي', 'أَيّ', 'اي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'رجال', 'lemma': 'رَجُل', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['رجال', 'رجل', 'رَجُل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'السفارات', 'lemma': 'سِفارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السفارات', 'سفارة', 'سِفارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المعتمدة', 'lemma': 'مُعْتَمَد', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المعتمدة', 'معتمد', 'مُعْتَمَد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لدى', 'lemma': 'لَدَى', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الدولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدولة', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'تحمل', 'lemma': 'حَمَل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تحمل', 'حمل', 'حَمَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هذه', 'lemma': 'هٰذا', 'pos': 'pron_dem', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هذا', 'هذه', 'هٰذا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الجملة', 'lemma': 'جُمْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الجملة', 'جملة', 'جُمْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هيئة', 'lemma': 'هَيْئَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هيئة', 'هيية', 'هَيْئَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سياسية', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سياسية', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# --------------------------------------------------------------------------------
# AraBART Pred L1: الدبلوماسيون يستخدمون سيارات تحمل كلمة "هيئة سياسية".
# Complex words L1: ['سياسية']
# Details L1:
# {'token': 'الدبلوماسيون', 'lemma': 'دِبلُوماسِيّ', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدبلوماسيون', 'دبلوماسي', 'دِبلُوماسِيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يستخدمون', 'lemma': 'ٱِسْتَخْدَم', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استخدم', 'يستخدمون', 'ٱستخدم', 'ٱِسْتَخْدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سيارات', 'lemma': 'سَيّارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سيارات', 'سيارة', 'سَيّارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تحمل', 'lemma': 'حَمَل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تحمل', 'حمل', 'حَمَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'كلمة', 'lemma': 'كَلِمَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['كلمة', 'كَلِمَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هيئة', 'lemma': 'هَيْئَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هيئة', 'هيية', 'هَيْئَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سياسية', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سياسية', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}

# %%
# Stage 2: Generate substitution candidates with Arabic-BERT MLM

# %%
import re
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
# 1) Load Arabic-BERT masked language model
# ------------------------------------------------------------
# Practical Arabic-BERT choice from the asafaya family.
# This is used here as a masked language model to generate
# substitution candidates for a masked complex word.

MODEL_NAME = "asafaya/bert-base-arabic"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForMaskedLM.from_pretrained(MODEL_NAME)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()

print("Loaded model on:", device)
print("Mask token:", tokenizer.mask_token)
# Out:
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at asafaya/bert-base-arabic were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loaded model on: cuda
# Mask token: [MASK]

# %%
def mask_first_occurrence(sentence, target_word, mask_token):
    """
    Replace only the first exact occurrence of target_word in sentence
    with [MASK]. This avoids replacing every occurrence.
    """
    if not sentence or not target_word:
        return sentence, False

    # Escape target for regex safety
    pattern = re.escape(target_word)

    # Replace only first match
    masked_sentence, n = re.subn(pattern, mask_token, sentence, count=1)
    return masked_sentence, (n > 0)

# %%
def is_valid_candidate(token):
    """
    Keep only clean substitution candidates.
    We filter out:
    - special tokens
    - subword pieces like ##...
    - empty tokens
    - punctuation-only tokens
    - obvious non-Arabic fragments
    """
    if token is None:
        return False

    token = str(token).strip()

    if not token:
        return False

    # Skip special tokens and wordpieces
    if token in tokenizer.all_special_tokens:
        return False
    if token.startswith("##"):
        return False

    # Skip punctuation-only
    if re.fullmatch(r"[^\w\u0600-\u06FF]+", token):
        return False

    # Keep tokens that contain at least one Arabic character
    if not re.search(r"[\u0600-\u06FF]", token):
        return False

    return True

# %%
def generate_top5_substitutions(sentence, complex_word, top_k=5, search_k=50):
    """
    For one sentence + one complex word:
    - replace the word with [MASK]
    - run Arabic-BERT MLM
    - return top 5 candidate substitutions with probabilities

    Notes:
    - This works best when the complex word is represented as one mask.
    - If the target word is not found in the sentence, returns empty list.
    """
    masked_sentence, replaced = mask_first_occurrence(
        sentence=sentence,
        target_word=complex_word,
        mask_token=tokenizer.mask_token
    )

    if not replaced:
        return {
            "original_sentence": sentence,
            "complex_word": complex_word,
            "masked_sentence": sentence,
            "found_and_masked": False,
            "substitutions": []
        }

    # Tokenize
    inputs = tokenizer(masked_sentence, return_tensors="pt").to(device)

    # Find [MASK] position
    mask_positions = (inputs["input_ids"][0] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0]

    if len(mask_positions) == 0:
        return {
            "original_sentence": sentence,
            "complex_word": complex_word,
            "masked_sentence": masked_sentence,
            "found_and_masked": False,
            "substitutions": []
        }

    mask_index = mask_positions[0].item()

    # Run model
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits[0, mask_index]

    # Convert logits to probabilities
    probs = torch.softmax(logits, dim=-1)

    # Take a larger pool first, then filter to valid Arabic candidates
    top_ids = torch.topk(probs, k=search_k).indices.tolist()

    candidates = []
    seen = set()

    for token_id in top_ids:
        token = tokenizer.convert_ids_to_tokens(token_id)
        prob = probs[token_id].item()

        if not is_valid_candidate(token):
            continue

        # Avoid duplicates
        if token in seen:
            continue

        seen.add(token)

        candidates.append({
            "candidate": token,
            "probability": prob
        })

        if len(candidates) == top_k:
            break

    return {
        "original_sentence": sentence,
        "complex_word": complex_word,
        "masked_sentence": masked_sentence,
        "found_and_masked": True,
        "substitutions": candidates
    }

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"GPU Compute Capability: {torch.cuda.get_device_capability(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU: Tesla T4
# GPU Compute Capability: (7, 5)

# %%
from tqdm.auto import tqdm

def generate_mlm_for_level(df, sentence_col, complex_col, output_col):
    all_results = []

    for _, row in tqdm(df.iterrows(), total=len(df), desc=f"Processing {sentence_col}"):
        sentence = row[sentence_col]
        complex_words = row[complex_col]

        if not isinstance(complex_words, list) or len(complex_words) == 0:
            all_results.append([])
            continue

        row_results = []
        for cw in complex_words:
            result = generate_top5_substitutions(sentence, cw, top_k=5, search_k=50)
            row_results.append(result)

        all_results.append(row_results)

    df[output_col] = all_results
    return df

# %%
final_df = generate_mlm_for_level(
    final_df,
    sentence_col="pred_level_3",
    complex_col="l3_complex_words",
    output_col="l3_mlm_substitutions"
)

final_df = generate_mlm_for_level(
    final_df,
    sentence_col="pred_level_2",
    complex_col="l2_complex_words",
    output_col="l2_mlm_substitutions"
)

final_df = generate_mlm_for_level(
    final_df,
    sentence_col="pred_level_1",
    complex_col="l1_complex_words",
    output_col="l1_mlm_substitutions"
)
# Out:
# Processing pred_level_3:   0%|          | 0/34294 [00:00<?, ?it/s]
# Processing pred_level_2:   0%|          | 0/34294 [00:00<?, ?it/s]
# Processing pred_level_1:   0%|          | 0/34294 [00:00<?, ?it/s]

# %%
# Preview a few rows for all levels
for i in range(min(3, len(final_df))):
    print("=" * 100)
    print("Original_Text:", final_df.loc[i, "Original_Sentence"])

    for level in ["3", "2", "1"]:
        print("\n" + "-" * 80)
        print(f"LEVEL {level}")
        print(f"AraBART prediction:", final_df.loc[i, f"pred_level_{level}"])
        print(f"Complex words:", final_df.loc[i, f"l{level}_complex_words"])
        print("MLM substitutions:")

        for item in final_df.loc[i, f"l{level}_mlm_substitutions"]:
            print("-" * 60)
            print("Complex word:", item["complex_word"])
            print("Masked sentence:", item["masked_sentence"])
            print("Candidates:")
            for cand in item["substitutions"]:
                print(cand)
# Out:
# ====================================================================================================
# Original_Text: •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
#
# --------------------------------------------------------------------------------
# LEVEL 3
# AraBART prediction: "عدم الانحياز" مصطلح سياسي يعني الحياد.
# Complex words: ['الانحياز', 'سياسي', 'الحياد']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: الانحياز
# Masked sentence: "عدم [MASK]" مصطلح سياسي يعني الحياد.
# Candidates:
# {'candidate': 'الرضا', 'probability': 0.08295463770627975}
# {'candidate': 'الاحترام', 'probability': 0.056602850556373596}
# {'candidate': 'الاستقرار', 'probability': 0.05178386718034744}
# {'candidate': 'التدخل', 'probability': 0.03991968557238579}
# {'candidate': 'التمييز', 'probability': 0.03694647550582886}
# ------------------------------------------------------------
# Complex word: سياسي
# Masked sentence: "عدم الانحياز" مصطلح [MASK] يعني الحياد.
# Candidates:
# {'candidate': 'لا', 'probability': 0.3801755905151367}
# {'candidate': 'عام', 'probability': 0.08438023924827576}
# {'candidate': 'عربي', 'probability': 0.03371218591928482}
# {'candidate': 'سياسي', 'probability': 0.025519581511616707}
# {'candidate': 'جديد', 'probability': 0.016293833032250404}
# ------------------------------------------------------------
# Complex word: الحياد
# Masked sentence: "عدم الانحياز" مصطلح سياسي يعني [MASK].
# Candidates:
# {'candidate': 'الاستقلال', 'probability': 0.04772601276636124}
# {'candidate': 'الانفصال', 'probability': 0.03544853255152702}
# {'candidate': 'الحرية', 'probability': 0.02239886485040188}
# {'candidate': 'المقاومة', 'probability': 0.020247308537364006}
# {'candidate': 'الخيانة', 'probability': 0.015693172812461853}
#
# --------------------------------------------------------------------------------
# LEVEL 2
# AraBART prediction: "عدم الانحياز" مصطلح سياسي يعني الحياد.
# Complex words: ['الانحياز', 'سياسي', 'الحياد']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: الانحياز
# Masked sentence: "عدم [MASK]" مصطلح سياسي يعني الحياد.
# Candidates:
# {'candidate': 'الرضا', 'probability': 0.08295463770627975}
# {'candidate': 'الاحترام', 'probability': 0.056602850556373596}
# {'candidate': 'الاستقرار', 'probability': 0.05178386718034744}
# {'candidate': 'التدخل', 'probability': 0.03991968557238579}
# {'candidate': 'التمييز', 'probability': 0.03694647550582886}
# ------------------------------------------------------------
# Complex word: سياسي
# Masked sentence: "عدم الانحياز" مصطلح [MASK] يعني الحياد.
# Candidates:
# {'candidate': 'لا', 'probability': 0.3801755905151367}
# {'candidate': 'عام', 'probability': 0.08438023924827576}
# {'candidate': 'عربي', 'probability': 0.03371218591928482}
# {'candidate': 'سياسي', 'probability': 0.025519581511616707}
# {'candidate': 'جديد', 'probability': 0.016293833032250404}
# ------------------------------------------------------------
# Complex word: الحياد
# Masked sentence: "عدم الانحياز" مصطلح سياسي يعني [MASK].
# Candidates:
# {'candidate': 'الاستقلال', 'probability': 0.04772601276636124}
# {'candidate': 'الانفصال', 'probability': 0.03544853255152702}
# {'candidate': 'الحرية', 'probability': 0.02239886485040188}
# {'candidate': 'المقاومة', 'probability': 0.020247308537364006}
# {'candidate': 'الخيانة', 'probability': 0.015693172812461853}
#
# --------------------------------------------------------------------------------
# LEVEL 1
# AraBART prediction: عدم الانحياز هو الحياد في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# Complex words: ['الانحياز', 'الحياد', 'السياسية', '،', 'الانحياز']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: الانحياز
# Masked sentence: عدم [MASK] هو الحياد في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# Candidates:
# {'candidate': 'الاستقرار', 'probability': 0.05465862154960632}
# {'candidate': 'الثقة', 'probability': 0.053434256464242935}
# {'candidate': 'الوضوح', 'probability': 0.049310941249132156}
# {'candidate': 'الاحترام', 'probability': 0.039133694022893906}
# {'candidate': 'الالتزام', 'probability': 0.027874596416950226}
# ------------------------------------------------------------
# Complex word: الحياد
# Masked sentence: عدم الانحياز هو [MASK] في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# Candidates:
# {'candidate': 'التدخل', 'probability': 0.175388365983963}
# {'candidate': 'المشاركة', 'probability': 0.05750000476837158}
# {'candidate': 'التفكير', 'probability': 0.021766183897852898}
# {'candidate': 'الحكم', 'probability': 0.019939439371228218}
# {'candidate': 'التمييز', 'probability': 0.015004078857600689}
# ------------------------------------------------------------
# Complex word: السياسية
# Masked sentence: عدم الانحياز هو الحياد في الأمور [MASK]، وهو مصطلح يعني عدم الانحياز.
# Candidates:
# {'candidate': 'العامة', 'probability': 0.09246233105659485}
# {'candidate': 'المختلفة', 'probability': 0.045625608414411545}
# {'candidate': 'الانسانية', 'probability': 0.039044711738824844}
# {'candidate': 'الداخلية', 'probability': 0.03881482407450676}
# {'candidate': 'السياسية', 'probability': 0.03407330438494682}
# ------------------------------------------------------------
# Complex word: ،
# Masked sentence: عدم الانحياز هو الحياد في الأمور السياسية[MASK] وهو مصطلح يعني عدم الانحياز.
# Candidates:
# {'candidate': '،', 'probability': 0.48477575182914734}
# {'candidate': 'والاقتصادية', 'probability': 0.039680905640125275}
# {'candidate': 'والاجتماعية', 'probability': 0.03623011335730553}
# {'candidate': 'والثقافية', 'probability': 0.017723295837640762}
# {'candidate': 'والفكرية', 'probability': 0.014419042505323887}
# ------------------------------------------------------------
# Complex word: الانحياز
# Masked sentence: عدم [MASK] هو الحياد في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# Candidates:
# {'candidate': 'الاستقرار', 'probability': 0.05465862154960632}
# {'candidate': 'الثقة', 'probability': 0.053434256464242935}
# {'candidate': 'الوضوح', 'probability': 0.049310941249132156}
# {'candidate': 'الاحترام', 'probability': 0.039133694022893906}
# {'candidate': 'الالتزام', 'probability': 0.027874596416950226}
# ====================================================================================================
# Original_Text: حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
#
# --------------------------------------------------------------------------------
# LEVEL 3
# AraBART prediction: تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# Complex words: ['المنحازة']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: تلتزم الدول غير [MASK] بعدم الارتباط بدول الشرق أو الغرب.
# Candidates:
# {'candidate': 'العربية', 'probability': 0.08343984931707382}
# {'candidate': 'المذكورة', 'probability': 0.05910894647240639}
# {'candidate': 'الغربية', 'probability': 0.04012604057788849}
# {'candidate': 'المتحدة', 'probability': 0.022408099845051765}
# {'candidate': 'المستقلة', 'probability': 0.02022300846874714}
#
# --------------------------------------------------------------------------------
# LEVEL 2
# AraBART prediction: تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# Complex words: ['المنحازة']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: تلتزم الدول غير [MASK] بعدم الارتباط بدول الشرق أو الغرب.
# Candidates:
# {'candidate': 'العربية', 'probability': 0.08343984931707382}
# {'candidate': 'المذكورة', 'probability': 0.05910894647240639}
# {'candidate': 'الغربية', 'probability': 0.04012604057788849}
# {'candidate': 'المتحدة', 'probability': 0.022408099845051765}
# {'candidate': 'المستقلة', 'probability': 0.02022300846874714}
#
# --------------------------------------------------------------------------------
# LEVEL 1
# AraBART prediction: الدول غير المنحازة لا تتعامل مع دول الشرق أو الغرب.
# Complex words: ['المنحازة']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: الدول غير [MASK] لا تتعامل مع دول الشرق أو الغرب.
# Candidates:
# {'candidate': 'العربية', 'probability': 0.41358694434165955}
# {'candidate': 'المنظمة', 'probability': 0.06527478247880936}
# {'candidate': 'الشيوعية', 'probability': 0.02471788041293621}
# {'candidate': 'الرسمية', 'probability': 0.02443496510386467}
# {'candidate': 'الحكومية', 'probability': 0.01769942417740822}
# ====================================================================================================
# Original_Text: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
#
# --------------------------------------------------------------------------------
# LEVEL 3
# AraBART prediction: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Complex words: ['المنحازة', 'المتفرج', 'العالمية', '،', '،']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: الدول غير [MASK] لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': 'العربية', 'probability': 0.12026838213205338}
# {'candidate': 'النفطية', 'probability': 0.07857265323400497}
# {'candidate': 'الديمقراطية', 'probability': 0.0405869223177433}
# {'candidate': 'المنتجة', 'probability': 0.030775951221585274}
# {'candidate': 'المستقلة', 'probability': 0.028817707672715187}
# ------------------------------------------------------------
# Complex word: المتفرج
# Masked sentence: الدول غير المنحازة لا تقف موقف [MASK] أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': 'واحد', 'probability': 0.27404531836509705}
# {'candidate': 'ثابت', 'probability': 0.03304758667945862}
# {'candidate': 'واضح', 'probability': 0.021636242046952248}
# {'candidate': 'المعارضة', 'probability': 0.021272938698530197}
# {'candidate': 'ضعيف', 'probability': 0.015930810943245888}
# ------------------------------------------------------------
# Complex word: العالمية
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث [MASK]، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': 'الخارجية', 'probability': 0.0918578952550888}
# {'candidate': 'الراهنة', 'probability': 0.052088260650634766}
# {'candidate': 'الجارية', 'probability': 0.050451528280973434}
# {'candidate': 'الدولية', 'probability': 0.04279344528913498}
# {'candidate': 'الداخلية', 'probability': 0.039918094873428345}
# ------------------------------------------------------------
# Complex word: ،
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية[MASK] بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': '،', 'probability': 0.9615251421928406}
# {'candidate': '؛', 'probability': 0.009651411324739456}
# {'candidate': 'فحسب', 'probability': 0.0014261576579883695}
# {'candidate': 'فقط', 'probability': 0.0011786043178290129}
# {'candidate': 'الراهنة', 'probability': 0.0009106345241889358}
# ------------------------------------------------------------
# Complex word: ،
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية[MASK] بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': '،', 'probability': 0.9615251421928406}
# {'candidate': '؛', 'probability': 0.009651411324739456}
# {'candidate': 'فحسب', 'probability': 0.0014261576579883695}
# {'candidate': 'فقط', 'probability': 0.0011786043178290129}
# {'candidate': 'الراهنة', 'probability': 0.0009106345241889358}
#
# --------------------------------------------------------------------------------
# LEVEL 2
# AraBART prediction: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Complex words: ['المنحازة', 'المتفرج', 'العالمية', '،', '،']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: الدول غير [MASK] لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': 'العربية', 'probability': 0.12026838213205338}
# {'candidate': 'النفطية', 'probability': 0.07857265323400497}
# {'candidate': 'الديمقراطية', 'probability': 0.0405869223177433}
# {'candidate': 'المنتجة', 'probability': 0.030775951221585274}
# {'candidate': 'المستقلة', 'probability': 0.028817707672715187}
# ------------------------------------------------------------
# Complex word: المتفرج
# Masked sentence: الدول غير المنحازة لا تقف موقف [MASK] أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': 'واحد', 'probability': 0.27404531836509705}
# {'candidate': 'ثابت', 'probability': 0.03304758667945862}
# {'candidate': 'واضح', 'probability': 0.021636242046952248}
# {'candidate': 'المعارضة', 'probability': 0.021272938698530197}
# {'candidate': 'ضعيف', 'probability': 0.015930810943245888}
# ------------------------------------------------------------
# Complex word: العالمية
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث [MASK]، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': 'الخارجية', 'probability': 0.0918578952550888}
# {'candidate': 'الراهنة', 'probability': 0.052088260650634766}
# {'candidate': 'الجارية', 'probability': 0.050451528280973434}
# {'candidate': 'الدولية', 'probability': 0.04279344528913498}
# {'candidate': 'الداخلية', 'probability': 0.039918094873428345}
# ------------------------------------------------------------
# Complex word: ،
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية[MASK] بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': '،', 'probability': 0.9615251421928406}
# {'candidate': '؛', 'probability': 0.009651411324739456}
# {'candidate': 'فحسب', 'probability': 0.0014261576579883695}
# {'candidate': 'فقط', 'probability': 0.0011786043178290129}
# {'candidate': 'الراهنة', 'probability': 0.0009106345241889358}
# ------------------------------------------------------------
# Complex word: ،
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية[MASK] بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Candidates:
# {'candidate': '،', 'probability': 0.9615251421928406}
# {'candidate': '؛', 'probability': 0.009651411324739456}
# {'candidate': 'فحسب', 'probability': 0.0014261576579883695}
# {'candidate': 'فقط', 'probability': 0.0011786043178290129}
# {'candidate': 'الراهنة', 'probability': 0.0009106345241889358}
#
# --------------------------------------------------------------------------------
# LEVEL 1
# AraBART prediction: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.
# Complex words: ['المنحازة', 'المتفرج', 'العالمية']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: الدول غير [MASK] لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.
# Candidates:
# {'candidate': 'العربية', 'probability': 0.272619366645813}
# {'candidate': 'المنظمة', 'probability': 0.040734194219112396}
# {'candidate': 'المنتجة', 'probability': 0.037443630397319794}
# {'candidate': 'الصديقة', 'probability': 0.025884132832288742}
# {'candidate': 'النامية', 'probability': 0.024921268224716187}
# ------------------------------------------------------------
# Complex word: المتفرج
# Masked sentence: الدول غير المنحازة لا تقف موقف [MASK] أمام المشاكل والأحداث العالمية.
# Candidates:
# {'candidate': 'واحد', 'probability': 0.1625337302684784}
# {'candidate': 'التحدي', 'probability': 0.031971003860235214}
# {'candidate': 'الرفض', 'probability': 0.027382414788007736}
# {'candidate': 'المعارضة', 'probability': 0.021638741716742516}
# {'candidate': 'الحي', 'probability': 0.019449856132268906}
# ------------------------------------------------------------
# Complex word: العالمية
# Masked sentence: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث [MASK].
# Candidates:
# {'candidate': 'القادمة', 'probability': 0.12714767456054688}
# {'candidate': 'المستقبلية', 'probability': 0.04008074104785919}
# {'candidate': 'الدولية', 'probability': 0.03128891438245773}
# {'candidate': 'الخارجية', 'probability': 0.030399981886148453}
# {'candidate': 'الجديدة', 'probability': 0.02855280227959156}

# %%
model.save_pretrained("/kaggle/working/substitution_model")
tokenizer.save_pretrained("/kaggle/working/substitution_model")
# Out:
# ('/kaggle/working/substitution_model/tokenizer_config.json',
#  '/kaggle/working/substitution_model/special_tokens_map.json',
#  '/kaggle/working/substitution_model/vocab.txt',
#  '/kaggle/working/substitution_model/added_tokens.json',
#  '/kaggle/working/substitution_model/tokenizer.json')

# %%
import shutil
shutil.make_archive("/kaggle/working/substitution_model", 'zip', "/kaggle/working/substitution_model")
# Out:
# '/kaggle/working/substitution_model.zip'

# %%
# Stage 3: Rule-based filtering + final candidate selection
# Based on the paper:
# 1) candidate lemma must be different from target lemma
# 2) candidate POS must be the same as target POS
# 3) candidate must exist in the frequency list
# 4) choose highest-probability surviving candidate

# %%
# safely get POS and lemma for a word
def get_token_pos_and_lemma(token):
    """
    Return (pos, lemma) using the same analysis function you already use.
    """
    analysis = get_best_analysis(token)
    pos_tag = analysis.get("pos", "")
    lemma = analysis.get("lex", "") or analysis.get("lemma", "")
    return pos_tag, lemma

# %%
def normalize_for_comparison(text):
    """
    Light normalization for comparing target lemma vs candidate lemma.
    """
    if pd.isna(text):
        return ""
    text = str(text).strip()
    text = remove_diacritics(text)
    text = normalize_arabic(text)
    return text

# %%
def filter_and_select_substitution(one_result):
    """
    Input:
      one_result = one item from mlm_substitutions
      Example:
      {
        'original_sentence': ...,
        'complex_word': ...,
        'masked_sentence': ...,
        'found_and_masked': True,
        'substitutions': [{'candidate': ..., 'probability': ...}, ...]
      }

    Output:
      dictionary containing:
      - target word info
      - all candidate analyses
      - valid candidates only
      - selected best substitution
    """
    complex_word = one_result.get("complex_word", "")
    substitutions = one_result.get("substitutions", [])


    # Analyze target word
    target_pos, target_lemma = get_token_pos_and_lemma(complex_word)
    target_lemma_norm = normalize_for_comparison(target_lemma)
    target_word_norm = normalize_for_comparison(complex_word)

    all_candidates = []
    valid_candidates = []


    for cand in substitutions:
        candidate_word = cand.get("candidate", "")
        probability = cand.get("probability", 0.0)

        cand_pos, cand_lemma = get_token_pos_and_lemma(candidate_word)
        cand_lemma_norm = normalize_for_comparison(cand_lemma)
        cand_word_norm = normalize_for_comparison(candidate_word)

        # Rule 1: lemma must be different from target lemma
        lemma_is_different = (
            cand_lemma_norm != target_lemma_norm
            and cand_word_norm != target_word_norm
        )
        # Rule 2: POS must match target POS
        same_pos = (cand_pos == target_pos)

        # Rule 3: candidate must exist in frequency list
        in_freq, lookup_candidates = exists_in_frequency_list(candidate_word, cand_lemma)

        candidate_info = {
            "candidate": candidate_word,
            "probability": probability,
            "candidate_pos": cand_pos,
            "candidate_lemma": cand_lemma,
            "candidate_lookup_candidates": lookup_candidates,
            "lemma_is_different": lemma_is_different,
            "same_pos": same_pos,
            "in_frequency_list": in_freq,
            "is_valid": lemma_is_different and same_pos and in_freq
        }
        all_candidates.append(candidate_info)

        if candidate_info["is_valid"]:
            valid_candidates.append(candidate_info)

    # Select highest-probability valid candidate
    selected = None
    if valid_candidates:
        selected = max(valid_candidates, key=lambda x: x["probability"])

    return {
        "complex_word": complex_word,
        "target_pos": target_pos,
        "target_lemma": target_lemma,
        "all_candidates": all_candidates,
        "valid_candidates": valid_candidates,
        "selected_substitution": selected
    }

# %%
def filter_substitutions_list(mlm_results):
    if not isinstance(mlm_results, list) or len(mlm_results) == 0:
        return []

    filtered_results = []
    for one_result in mlm_results:
        filtered_results.append(filter_and_select_substitution(one_result))

    return filtered_results


final_df["l3_filtered_substitutions"] = final_df["l3_mlm_substitutions"].apply(filter_substitutions_list)
final_df["l2_filtered_substitutions"] = final_df["l2_mlm_substitutions"].apply(filter_substitutions_list)
final_df["l1_filtered_substitutions"] = final_df["l1_mlm_substitutions"].apply(filter_substitutions_list)

# %%
# Extract only final chosen substitutions
def extract_final_substitutions(filtered_results):
    """
    Return a compact list of final chosen substitutions per row.
    """
    if not isinstance(filtered_results, list):
        return []

    finals = []
    for item in filtered_results:
        selected = item.get("selected_substitution", None)
        if selected is not None:
            finals.append({
                "complex_word": item["complex_word"],
                "replacement": selected["candidate"],
                "probability": selected["probability"],
                "target_pos": item["target_pos"],
                "target_lemma": item["target_lemma"],
                "candidate_pos": selected["candidate_pos"],
                "candidate_lemma": selected["candidate_lemma"]
            })
    return finals


final_df["l3_final_substitutions"] = final_df["l3_filtered_substitutions"].apply(extract_final_substitutions)
final_df["l2_final_substitutions"] = final_df["l2_filtered_substitutions"].apply(extract_final_substitutions)
final_df["l1_final_substitutions"] = final_df["l1_filtered_substitutions"].apply(extract_final_substitutions)

# %%
# Preview final substitutions for all hybrid levels
for i in range(min(3, len(final_df))):
    print("=" * 100)
    print("Original:", final_df.loc[i, "Original_Sentence"])

    for level in ["3", "2", "1"]:
        print("\n" + "-" * 80)
        print(f"LEVEL {level}")
        print(f"AraBART Pred L{level}:", final_df.loc[i, f"pred_level_{level}"])
        print(f"Complex words L{level}:", final_df.loc[i, f"l{level}_complex_words"])

        print("\nFinal substitutions:")
        for item in final_df.loc[i, f"l{level}_final_substitutions"]:
            print(item)

        print("\nFiltered details:")
        for item in final_df.loc[i, f"l{level}_filtered_substitutions"]:
            print("-" * 60)
            print("Complex word:", item["complex_word"])
            print("Target POS:", item["target_pos"])
            print("Target lemma:", item["target_lemma"])
            print("Selected substitution:", item["selected_substitution"])
# Out:
# ====================================================================================================
# Original: •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
#
# --------------------------------------------------------------------------------
# LEVEL 3
# AraBART Pred L3: "عدم الانحياز" مصطلح سياسي يعني الحياد.
# Complex words L3: ['الانحياز', 'سياسي', 'الحياد']
#
# Final substitutions:
# {'complex_word': 'الانحياز', 'replacement': 'الرضا', 'probability': 0.08295463770627975, 'target_pos': 'noun', 'target_lemma': 'ٱِنْحِياز', 'candidate_pos': 'noun', 'candidate_lemma': 'رِضَى'}
# {'complex_word': 'سياسي', 'replacement': 'عربي', 'probability': 0.03371218591928482, 'target_pos': 'adj', 'target_lemma': 'سِياسِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'عَرَبِيّ'}
# {'complex_word': 'الحياد', 'replacement': 'الاستقلال', 'probability': 0.04772601276636124, 'target_pos': 'noun', 'target_lemma': 'حِياد', 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْلال'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: الانحياز
# Target POS: noun
# Target lemma: ٱِنْحِياز
# Selected substitution: {'candidate': 'الرضا', 'probability': 0.08295463770627975, 'candidate_pos': 'noun', 'candidate_lemma': 'رِضَى', 'candidate_lookup_candidates': ['الرضا', 'رضى', 'رضي', 'رِضَى'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: سياسي
# Target POS: adj
# Target lemma: سِياسِيّ
# Selected substitution: {'candidate': 'عربي', 'probability': 0.03371218591928482, 'candidate_pos': 'adj', 'candidate_lemma': 'عَرَبِيّ', 'candidate_lookup_candidates': ['عربي', 'عَرَبِيّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: الحياد
# Target POS: noun
# Target lemma: حِياد
# Selected substitution: {'candidate': 'الاستقلال', 'probability': 0.04772601276636124, 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْلال', 'candidate_lookup_candidates': ['استقلال', 'الاستقلال', 'ٱستقلال', 'ٱِسْتِقْلال'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
#
# --------------------------------------------------------------------------------
# LEVEL 2
# AraBART Pred L2: "عدم الانحياز" مصطلح سياسي يعني الحياد.
# Complex words L2: ['الانحياز', 'سياسي', 'الحياد']
#
# Final substitutions:
# {'complex_word': 'الانحياز', 'replacement': 'الرضا', 'probability': 0.08295463770627975, 'target_pos': 'noun', 'target_lemma': 'ٱِنْحِياز', 'candidate_pos': 'noun', 'candidate_lemma': 'رِضَى'}
# {'complex_word': 'سياسي', 'replacement': 'عربي', 'probability': 0.03371218591928482, 'target_pos': 'adj', 'target_lemma': 'سِياسِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'عَرَبِيّ'}
# {'complex_word': 'الحياد', 'replacement': 'الاستقلال', 'probability': 0.04772601276636124, 'target_pos': 'noun', 'target_lemma': 'حِياد', 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْلال'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: الانحياز
# Target POS: noun
# Target lemma: ٱِنْحِياز
# Selected substitution: {'candidate': 'الرضا', 'probability': 0.08295463770627975, 'candidate_pos': 'noun', 'candidate_lemma': 'رِضَى', 'candidate_lookup_candidates': ['الرضا', 'رضى', 'رضي', 'رِضَى'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: سياسي
# Target POS: adj
# Target lemma: سِياسِيّ
# Selected substitution: {'candidate': 'عربي', 'probability': 0.03371218591928482, 'candidate_pos': 'adj', 'candidate_lemma': 'عَرَبِيّ', 'candidate_lookup_candidates': ['عربي', 'عَرَبِيّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: الحياد
# Target POS: noun
# Target lemma: حِياد
# Selected substitution: {'candidate': 'الاستقلال', 'probability': 0.04772601276636124, 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْلال', 'candidate_lookup_candidates': ['استقلال', 'الاستقلال', 'ٱستقلال', 'ٱِسْتِقْلال'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
#
# --------------------------------------------------------------------------------
# LEVEL 1
# AraBART Pred L1: عدم الانحياز هو الحياد في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# Complex words L1: ['الانحياز', 'الحياد', 'السياسية', '،', 'الانحياز']
#
# Final substitutions:
# {'complex_word': 'الانحياز', 'replacement': 'الاستقرار', 'probability': 0.05465862154960632, 'target_pos': 'noun', 'target_lemma': 'ٱِنْحِياز', 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْرار'}
# {'complex_word': 'الحياد', 'replacement': 'التدخل', 'probability': 0.175388365983963, 'target_pos': 'noun', 'target_lemma': 'حِياد', 'candidate_pos': 'noun', 'candidate_lemma': 'تَدَخُّل'}
# {'complex_word': 'السياسية', 'replacement': 'العامة', 'probability': 0.09246233105659485, 'target_pos': 'adj', 'target_lemma': 'سِياسِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'عامّ'}
# {'complex_word': 'الانحياز', 'replacement': 'الاستقرار', 'probability': 0.05465862154960632, 'target_pos': 'noun', 'target_lemma': 'ٱِنْحِياز', 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْرار'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: الانحياز
# Target POS: noun
# Target lemma: ٱِنْحِياز
# Selected substitution: {'candidate': 'الاستقرار', 'probability': 0.05465862154960632, 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْرار', 'candidate_lookup_candidates': ['استقرار', 'الاستقرار', 'ٱستقرار', 'ٱِسْتِقْرار'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: الحياد
# Target POS: noun
# Target lemma: حِياد
# Selected substitution: {'candidate': 'التدخل', 'probability': 0.175388365983963, 'candidate_pos': 'noun', 'candidate_lemma': 'تَدَخُّل', 'candidate_lookup_candidates': ['التدخل', 'تدخل', 'تَدَخُّل'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: السياسية
# Target POS: adj
# Target lemma: سِياسِيّ
# Selected substitution: {'candidate': 'العامة', 'probability': 0.09246233105659485, 'candidate_pos': 'adj', 'candidate_lemma': 'عامّ', 'candidate_lookup_candidates': ['العامة', 'عام', 'عامّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: ،
# Target POS: punc
# Target lemma: ،
# Selected substitution: None
# ------------------------------------------------------------
# Complex word: الانحياز
# Target POS: noun
# Target lemma: ٱِنْحِياز
# Selected substitution: {'candidate': 'الاستقرار', 'probability': 0.05465862154960632, 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْرار', 'candidate_lookup_candidates': ['استقرار', 'الاستقرار', 'ٱستقرار', 'ٱِسْتِقْرار'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ====================================================================================================
# Original: حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
#
# --------------------------------------------------------------------------------
# LEVEL 3
# AraBART Pred L3: تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# Complex words L3: ['المنحازة']
#
# Final substitutions:
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: None
#
# --------------------------------------------------------------------------------
# LEVEL 2
# AraBART Pred L2: تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# Complex words L2: ['المنحازة']
#
# Final substitutions:
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: None
#
# --------------------------------------------------------------------------------
# LEVEL 1
# AraBART Pred L1: الدول غير المنحازة لا تتعامل مع دول الشرق أو الغرب.
# Complex words L1: ['المنحازة']
#
# Final substitutions:
# {'complex_word': 'المنحازة', 'replacement': 'المنظمة', 'probability': 0.06527478247880936, 'target_pos': 'noun', 'target_lemma': 'مُنْحاز', 'candidate_pos': 'noun', 'candidate_lemma': 'مُنَظَّمَة'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: {'candidate': 'المنظمة', 'probability': 0.06527478247880936, 'candidate_pos': 'noun', 'candidate_lemma': 'مُنَظَّمَة', 'candidate_lookup_candidates': ['المنظمة', 'منظمة', 'مُنَظَّمَة'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ====================================================================================================
# Original: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
#
# --------------------------------------------------------------------------------
# LEVEL 3
# AraBART Pred L3: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Complex words L3: ['المنحازة', 'المتفرج', 'العالمية', '،', '،']
#
# Final substitutions:
# {'complex_word': 'المتفرج', 'replacement': 'واحد', 'probability': 0.27404531836509705, 'target_pos': 'noun', 'target_lemma': 'مُتَفَرِّج', 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد'}
# {'complex_word': 'العالمية', 'replacement': 'الخارجية', 'probability': 0.0918578952550888, 'target_pos': 'adj', 'target_lemma': 'عالَمِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'خارِجِيّ'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: None
# ------------------------------------------------------------
# Complex word: المتفرج
# Target POS: noun
# Target lemma: مُتَفَرِّج
# Selected substitution: {'candidate': 'واحد', 'probability': 0.27404531836509705, 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد', 'candidate_lookup_candidates': ['واحد', 'واحِد'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: العالمية
# Target POS: adj
# Target lemma: عالَمِيّ
# Selected substitution: {'candidate': 'الخارجية', 'probability': 0.0918578952550888, 'candidate_pos': 'adj', 'candidate_lemma': 'خارِجِيّ', 'candidate_lookup_candidates': ['الخارجية', 'خارجي', 'خارِجِيّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: ،
# Target POS: punc
# Target lemma: ،
# Selected substitution: None
# ------------------------------------------------------------
# Complex word: ،
# Target POS: punc
# Target lemma: ،
# Selected substitution: None
#
# --------------------------------------------------------------------------------
# LEVEL 2
# AraBART Pred L2: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# Complex words L2: ['المنحازة', 'المتفرج', 'العالمية', '،', '،']
#
# Final substitutions:
# {'complex_word': 'المتفرج', 'replacement': 'واحد', 'probability': 0.27404531836509705, 'target_pos': 'noun', 'target_lemma': 'مُتَفَرِّج', 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد'}
# {'complex_word': 'العالمية', 'replacement': 'الخارجية', 'probability': 0.0918578952550888, 'target_pos': 'adj', 'target_lemma': 'عالَمِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'خارِجِيّ'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: None
# ------------------------------------------------------------
# Complex word: المتفرج
# Target POS: noun
# Target lemma: مُتَفَرِّج
# Selected substitution: {'candidate': 'واحد', 'probability': 0.27404531836509705, 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد', 'candidate_lookup_candidates': ['واحد', 'واحِد'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: العالمية
# Target POS: adj
# Target lemma: عالَمِيّ
# Selected substitution: {'candidate': 'الخارجية', 'probability': 0.0918578952550888, 'candidate_pos': 'adj', 'candidate_lemma': 'خارِجِيّ', 'candidate_lookup_candidates': ['الخارجية', 'خارجي', 'خارِجِيّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: ،
# Target POS: punc
# Target lemma: ،
# Selected substitution: None
# ------------------------------------------------------------
# Complex word: ،
# Target POS: punc
# Target lemma: ،
# Selected substitution: None
#
# --------------------------------------------------------------------------------
# LEVEL 1
# AraBART Pred L1: الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.
# Complex words L1: ['المنحازة', 'المتفرج', 'العالمية']
#
# Final substitutions:
# {'complex_word': 'المنحازة', 'replacement': 'المنظمة', 'probability': 0.040734194219112396, 'target_pos': 'noun', 'target_lemma': 'مُنْحاز', 'candidate_pos': 'noun', 'candidate_lemma': 'مُنَظَّمَة'}
# {'complex_word': 'المتفرج', 'replacement': 'واحد', 'probability': 0.1625337302684784, 'target_pos': 'noun', 'target_lemma': 'مُتَفَرِّج', 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد'}
# {'complex_word': 'العالمية', 'replacement': 'القادمة', 'probability': 0.12714767456054688, 'target_pos': 'adj', 'target_lemma': 'عالَمِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'قادِم'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: {'candidate': 'المنظمة', 'probability': 0.040734194219112396, 'candidate_pos': 'noun', 'candidate_lemma': 'مُنَظَّمَة', 'candidate_lookup_candidates': ['المنظمة', 'منظمة', 'مُنَظَّمَة'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: المتفرج
# Target POS: noun
# Target lemma: مُتَفَرِّج
# Selected substitution: {'candidate': 'واحد', 'probability': 0.1625337302684784, 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد', 'candidate_lookup_candidates': ['واحد', 'واحِد'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: العالمية
# Target POS: adj
# Target lemma: عالَمِيّ
# Selected substitution: {'candidate': 'القادمة', 'probability': 0.12714767456054688, 'candidate_pos': 'adj', 'candidate_lemma': 'قادِم', 'candidate_lookup_candidates': ['القادمة', 'قادم', 'قادِم'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}

# %%
import re
import pandas as pd

# %%
# Safe single replacement
def replace_first_exact_occurrence(sentence, old_word, new_word):
    """
    Replace only the first exact occurrence of old_word in sentence.
    Returns:
      new_sentence, replaced_flag
    """
    if pd.isna(sentence):
        return sentence, False

    sentence = str(sentence)
    old_word = str(old_word)
    new_word = str(new_word)

    if not old_word or not new_word:
        return sentence, False

    pattern = re.escape(old_word)
    new_sentence, n = re.subn(pattern, new_word, sentence, count=1)

    return new_sentence, (n > 0)

# %%
def build_hybrid_sentence_from_pred(row, pred_col, subs_col):
    """
    For one row:
    - start from AraBART prediction column
    - apply lexical substitutions
    - return hybrid simplified sentence
    """
    base_sentence = row[pred_col]
    substitutions = row[subs_col]

    if pd.isna(base_sentence):
        return ""

    sentence = str(base_sentence)

    if not isinstance(substitutions, list) or len(substitutions) == 0:
        return sentence

    seen_pairs = set()
    ordered_subs = []

    for item in substitutions:
        complex_word = item.get("complex_word", "")
        replacement = item.get("replacement", "")
        key = (complex_word, replacement)

        if key not in seen_pairs:
            seen_pairs.add(key)
            ordered_subs.append(item)

    for item in ordered_subs:
        complex_word = item.get("complex_word", "")
        replacement = item.get("replacement", "")

        if complex_word and replacement:
            sentence, _ = replace_first_exact_occurrence(
                sentence=sentence,
                old_word=complex_word,
                new_word=replacement
            )

    return sentence

# %%
#Apply to dataframe
final_df["hybrid_level_3"] = final_df.apply(
    lambda row: build_hybrid_sentence_from_pred(row, "pred_level_3", "l3_final_substitutions"),
    axis=1
)

final_df["hybrid_level_2"] = final_df.apply(
    lambda row: build_hybrid_sentence_from_pred(row, "pred_level_2", "l2_final_substitutions"),
    axis=1
)

final_df["hybrid_level_1"] = final_df.apply(
    lambda row: build_hybrid_sentence_from_pred(row, "pred_level_1", "l1_final_substitutions"),
    axis=1
)

# %%
#store a compact replacement map for inspection
def build_replacement_map(substitutions):
    """
    Create a simple readable list of replacements for debugging.
    """
    if not isinstance(substitutions, list):
        return []

    return [
        f"{item.get('complex_word', '')} -> {item.get('replacement', '')}"
        for item in substitutions
    ]

final_df["l3_replacement_map"] = final_df["l3_final_substitutions"].apply(build_replacement_map)
final_df["l2_replacement_map"] = final_df["l2_final_substitutions"].apply(build_replacement_map)
final_df["l1_replacement_map"] = final_df["l1_final_substitutions"].apply(build_replacement_map)

# %%
for i in range(min(10, len(final_df))):
    print(f"\n{'='*80}")
    print("ORIGINAL       :", final_df.loc[i, "Original_Sentence"])
    print("PRED LEVEL 3   :", final_df.loc[i, "pred_level_3"])
    print("HYBRID LEVEL 3 :", final_df.loc[i, "hybrid_level_3"])
    print("REF LEVEL 3    :", final_df.loc[i, "ref_level_3"])
    print("L3 MAP         :", final_df.loc[i, "l3_replacement_map"])

    print("-"*80)
    print("PRED LEVEL 2   :", final_df.loc[i, "pred_level_2"])
    print("HYBRID LEVEL 2 :", final_df.loc[i, "hybrid_level_2"])
    print("REF LEVEL 2    :", final_df.loc[i, "ref_level_2"])
    print("L2 MAP         :", final_df.loc[i, "l2_replacement_map"])

    print("-"*80)
    print("PRED LEVEL 1   :", final_df.loc[i, "pred_level_1"])
    print("HYBRID LEVEL 1 :", final_df.loc[i, "hybrid_level_1"])
    print("REF LEVEL 1    :", final_df.loc[i, "ref_level_1"])
    print("L1 MAP         :", final_df.loc[i, "l1_replacement_map"])
# Out:
# ================================================================================
# ORIGINAL       : •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
# PRED LEVEL 3   : "عدم الانحياز" مصطلح سياسي يعني الحياد.
# HYBRID LEVEL 3 : "عدم الرضا" مصطلح عربي يعني الاستقلال.
# REF LEVEL 3    : "عدم الانحياز" هو مصطلح سياسي يشير إلى الحياد.
# L3 MAP         : ['الانحياز -> الرضا', 'سياسي -> عربي', 'الحياد -> الاستقلال']
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : "عدم الانحياز" مصطلح سياسي يعني الحياد.
# HYBRID LEVEL 2 : "عدم الرضا" مصطلح عربي يعني الاستقلال.
# REF LEVEL 2    : "عدم الانحياز" هو مصطلح سياسي يعني أن تكون محايدًا.
# L2 MAP         : ['الانحياز -> الرضا', 'سياسي -> عربي', 'الحياد -> الاستقلال']
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : عدم الانحياز هو الحياد في الأمور السياسية، وهو مصطلح يعني عدم الانحياز.
# HYBRID LEVEL 1 : عدم الاستقرار هو التدخل في الأمور العامة، وهو مصطلح يعني عدم الانحياز.
# REF LEVEL 1    : "عدم الانحياز" يعني أن تكون محايداً ولا تفضل أحداً.
# L1 MAP         : ['الانحياز -> الاستقرار', 'الحياد -> التدخل', 'السياسية -> العامة', 'الانحياز -> الاستقرار']
#
# ================================================================================
# ORIGINAL       : حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# PRED LEVEL 3   : تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# HYBRID LEVEL 3 : تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# REF LEVEL 3    : تلتزم الدول غير المنحازة بالحياد وعدم التحالف مع دول الشرق أو الغرب.
# L3 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# HYBRID LEVEL 2 : تلتزم الدول غير المنحازة بعدم الارتباط بدول الشرق أو الغرب.
# REF LEVEL 2    : تلتزم الدول غير المنحازة بعدم التحالف مع دول الشرق أو الغرب.
# L2 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : الدول غير المنحازة لا تتعامل مع دول الشرق أو الغرب.
# HYBRID LEVEL 1 : الدول غير المنظمة لا تتعامل مع دول الشرق أو الغرب.
# REF LEVEL 1    : الدول غير المنحازة لا تتعامل مع دول الشرق أو الغرب.
# L1 MAP         : ['المنحازة -> المنظمة']
#
# ================================================================================
# ORIGINAL       : بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# PRED LEVEL 3   : الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# HYBRID LEVEL 3 : الدول غير المنحازة لا تقف موقف واحد أمام المشاكل والأحداث الخارجية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# REF LEVEL 3    : بمعنى أن الدول غير المنحازة ليس موقفها موقف متفرج إزاء المشاكل العالمية، بل لها دور تمضي فيه وفق مصالحها الخاصة، وليس وفق مصالح الدول المتنازعة.
# L3 MAP         : ['المتفرج -> واحد', 'العالمية -> الخارجية']
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# HYBRID LEVEL 2 : الدول غير المنحازة لا تقف موقف واحد أمام المشاكل والأحداث الخارجية، بل لها دور يسير مع مصالحها، وليس مع مصالح الدول المتصارعة.
# REF LEVEL 2    : الدول غير المنحازة ليس لها موقف محايد في القضايا العالمية، بل تسعى لخدمة مصالحها الخاصة بدلاً من الوقوف كمتفرجين.
# L2 MAP         : ['المتفرج -> واحد', 'العالمية -> الخارجية']
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.
# HYBRID LEVEL 1 : الدول غير المنظمة لا تقف موقف واحد أمام المشاكل والأحداث القادمة.
# REF LEVEL 1    : الدول غير المنحازة ليسوا متفرجين، هم يتدخلون ويتحركون مع مصالحهم.
# L1 MAP         : ['المنحازة -> المنظمة', 'المتفرج -> واحد', 'العالمية -> القادمة']
#
# ================================================================================
# ORIGINAL       : وقد بدأ استعمال اصطلاح (عدم الانحياز) في مؤتمر بلغراد عام 1961، والذي اشتركت فيه 21 دولة غير منحازة
# PRED LEVEL 3   : وقد بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير منحازة.
# HYBRID LEVEL 3 : وقد بدأ استخدام مصطلح "عدم الاستقلال" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير مشاركة.
# REF LEVEL 3    : وقد بدأ استعمال اصطلاح "عدم الانحياز" في مؤتمر بلغراد عام 1961، والذي شاركت فيه 21 دولة غير منحازة.
# L3 MAP         : ['الانحياز -> الاستقلال', 'منحازة -> مشاركة']
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير منحازة.
# HYBRID LEVEL 2 : بدأ استخدام مصطلح "عدم الاستقلال" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير عضو.
# REF LEVEL 2    : وقد بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، والذي حضره 21 بلدًا غير متحالفة.
# L2 MAP         : ['الانحياز -> الاستقلال', 'منحازة -> عضو']
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير منحازة.
# HYBRID LEVEL 1 : بدأ استخدام مصطلح "عدم الاستقلال" في مؤتمر بلغراد عام 1961، حيث شاركت 21 دولة غير عضو.
# REF LEVEL 1    : وقد بدأ استخدام مصطلح "عدم الانحياز" في مؤتمر بلغراد عام 1961، حيث شارك 21 بلدًا.
# L1 MAP         : ['الانحياز -> الاستقلال', 'منحازة -> عضو']
#
# ================================================================================
# ORIGINAL       : ••السيارات التي يستعملها الدبلوماسيون.. أي رجال السفارات المعتمدون لدى الدولة تحمل هذه الجملة (هيئة سياسية).
# PRED LEVEL 3   : السيارات التي يستخدمها الدبلوماسيون، أي رجال السفارات المعتمدون لدى الدولة، تحمل هذه الجملة (هيئة سياسية).
# HYBRID LEVEL 3 : السيارات التي يستخدمها الدبلوماسيون، أي رجال السفارات المعتمدون لدى الدولة، تحمل هذه الجملة (هيئة سياسية).
# REF LEVEL 3    : تتحمل السيارات الدبلوماسية، أي تلك التي يستخدمها رجال السفارات المعتمدون لدى الدولة، شعار "هيئة سياسية".
# L3 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : السيارات التي يستخدمها الدبلوماسيون، أي رجال السفارات المعتمدة لدى الدولة، تحمل هذه الجملة (هيئة سياسية).
# HYBRID LEVEL 2 : السيارات التي يستخدمها الدبلوماسيون، أي رجال السفارات المعتمدة لدى الدولة، تحمل هذه الجملة (هيئة سياسية).
# REF LEVEL 2    : تتحمل السيارات التي يستخدمها الدبلوماسيون جملة "هيئة سياسية".
# L2 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : الدبلوماسيون يستخدمون سيارات تحمل كلمة "هيئة سياسية".
# HYBRID LEVEL 1 : الدبلوماسيون يستخدمون سيارات تحمل كلمة "هيئة المتحدة".
# REF LEVEL 1    : السيارات التي يستخدمها الدبلوماسيون تسمى "هيئة سياسية".
# L1 MAP         : ['سياسية -> المتحدة']
#
# ================================================================================
# ORIGINAL       : يقصد بالتنمية.. خطة اقتصادية لزيادة الإنتاج.. ورفع مستوى المعيشة للأفراد.
# PRED LEVEL 3   : يقصد بالتنمية خطة اقتصادية لزيادة الإنتاج ورفع مستوى المعيشة للأفراد.
# HYBRID LEVEL 3 : يقصد بالتنمية خطة اقتصادية لزيادة الإنتاج ورفع مستوى المعيشة للأفراد.
# REF LEVEL 3    : التنمية هي الخطة الاقتصادية التي تهدف إلى زيادة الإنتاج وتحسين مستوى المعيشة للجميع.
# L3 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : التنمية هي خطة اقتصادية لزيادة الإنتاج وتحسين مستوى المعيشة.
# HYBRID LEVEL 2 : التنمية هي خطة اقتصادية لزيادة الإنتاج وتحسين مستوى المعيشة.
# REF LEVEL 2    : التنمية هي الخطة الاقتصادية التي تهدف إلى زيادة الإنتاج وتحسين مستوى المعيشة للجميع.
# L2 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : التنمية هي خطة لزيادة الإنتاج وتحسين مستوى المعيشة.
# HYBRID LEVEL 1 : التنمية هي خطة لزيادة الإنتاج وتحسين مستوى المعيشة.
# REF LEVEL 1    : التنمية هي خطة لتحسين الحياة وزيادة الأشياء الجيدة مثل الطعام والمأوى للجميع.
# L1 MAP         : []
#
# ================================================================================
# ORIGINAL       : حضرموت – اليمن الديمقراطية
# PRED LEVEL 3   : حضرموت – اليمن الديمقراطية.، اليمن الديمقراطية
# HYBRID LEVEL 3 : حضرموت – اليمن الجديد.، اليمن الديمقراطية
# REF LEVEL 3    : حضرموت - اليمن الفيدرالية.
# L3 MAP         : ['الديمقراطية -> الجديد', 'الديمقراطية -> الجديد']
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : حضرموت – اليمن الديمقراطية.، حضرموت.
# HYBRID LEVEL 2 : حضرموت – اليمن الجديد.، حضرموت.
# REF LEVEL 2    : حضرموت - اليمن
# L2 MAP         : ['الديمقراطية -> الجديد']
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : حضرموت – اليمن الديمقراطية.، حضرموت.
# HYBRID LEVEL 1 : حضرموت – اليمن الجديد.، حضرموت.
# REF LEVEL 1    : حضرموت - مكان في اليمن.
# L1 MAP         : ['الديمقراطية -> الجديد']
#
# ================================================================================
# ORIGINAL       : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة
# PRED LEVEL 3   : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة.
# HYBRID LEVEL 3 : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة.
# REF LEVEL 3    : العنقاء رمز للبعث والخلود في الأساطير المصرية.
# L3 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة.
# HYBRID LEVEL 2 : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة.
# REF LEVEL 2    : العنقاء هي رمز البعث والخلود في الأساطير المصرية.
# L2 MAP         : []
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة.
# HYBRID LEVEL 1 : العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة.
# REF LEVEL 1    : العنقاء رمز الخلود.
# L1 MAP         : []
#
# ================================================================================
# ORIGINAL       : ويقال إنها لما بلغت 500 سنة أحرقت نفسها وبرزت من دخانها عنقاء أخرى..
# PRED LEVEL 3   : ويقال إنها لما بلغت 500 سنة أحرقت نفسها وبرزت من دخانها عنقاء أخرى.
# HYBRID LEVEL 3 : ويقال إنها لما بلغت 500 سنة عرفت نفسها وبرزت من دخانها مرة أخرى.
# REF LEVEL 3    : ويقال إنها أحرقت نفسها عندما بلغت خمسمائة عام، وظهرت من الدخان عنقاء أخرى.
# L3 MAP         : ['أحرقت -> عرفت', 'عنقاء -> مرة']
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : أحرقت نفسها عندما بلغت 500 سنة، وبرزت من دخانها عنقاء أخرى.
# HYBRID LEVEL 2 : عرفت نفسها عندما بلغت 500 سنة، وبرزت من دخانها مرة أخرى.
# REF LEVEL 2    : يقال إنها أحرقت نفسها عندما بلغت 500 سنة، وظهرت من الدخان عنقاء أخرى.
# L2 MAP         : ['أحرقت -> عرفت', 'عنقاء -> مرة']
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : أحرقت نفسها عندما بلغت 500 سنة، وبرزت من دخانها عنقاء أخرى.
# HYBRID LEVEL 1 : عرفت نفسها عندما بلغت 500 سنة، وبرزت من دخانها مرة أخرى.
# REF LEVEL 1    : وقيل أنها عندما بلغت 500 سنة أحرقت نفسها وخرج من الدخان عنقاء جديدة.
# L1 MAP         : ['أحرقت -> عرفت', 'عنقاء -> مرة']
#
# ================================================================================
# ORIGINAL       : وقد اعتبرها العرب أحد المستحيلات الثلاثة، العنقاء والغول والخل الوفي.
# PRED LEVEL 3   : وقد اعتبرها العرب أحد المستحيلات الثلاثة، العنقاء والغول والخل الوفي.
# HYBRID LEVEL 3 : وقد اعتبرها العرب أحد المستحيلات الاخرى، الفيل والغول والرجل الوفي.
# REF LEVEL 3    : وقد اعتبرها العرب إحدى المستحيلات الثلاث.
# L3 MAP         : ['الثلاثة -> الاخرى', 'العنقاء -> الفيل', 'والخل -> والرجل']
# --------------------------------------------------------------------------------
# PRED LEVEL 2   : وقد اعتبرها العرب أحد المستحيلات الثلاثة، العنقاء والغول والخل الوفي.
# HYBRID LEVEL 2 : وقد اعتبرها العرب أحد المستحيلات الاخرى، الفيل والغول والرجل الوفي.
# REF LEVEL 2    : وقد اعتبرها العرب إحدى المستحيلات الثلاث.
# L2 MAP         : ['الثلاثة -> الاخرى', 'العنقاء -> الفيل', 'والخل -> والرجل']
# --------------------------------------------------------------------------------
# PRED LEVEL 1   : وقد اعتبرها العرب أحد المستحيلات الثلاثة، العنقاء والغول والخل الوفي.
# HYBRID LEVEL 1 : وقد اعتبرها العرب أحد المستحيلات الاخرى، الفيل والغول والرجل الوفي.
# REF LEVEL 1    : وقد اعتبرها العرب مستحيلة، مثل الطيران مثلًا!
# L1 MAP         : ['الثلاثة -> الاخرى', 'العنقاء -> الفيل', 'والخل -> والرجل']

# %%
final_df.to_csv("/kaggle/working/final_hybrid_df_with_simplifications.csv", index=False)
print("Saved to /kaggle/working/final_hybrid_df_with_simplifications.csv")
# Out:
# Saved to /kaggle/working/final_hybrid_df_with_simplifications.csv

# %%
from google.colab import files

files.download("/kaggle/working/final_hybrid_df_with_simplifications.csv")
