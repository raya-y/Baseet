# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/rayaabualjamal/parrallel-bayyin-cleaned/full_merged_data.csv
# /kaggle/input/datasets/rayaabualjamal/combined-parallel-dataset/full_merged_data (2).csv
# /kaggle/input/datasets/rayaabualjamal/combined-parallel-dataset/full_merged_data.csv
# /kaggle/input/datasets/naghamalshbrawi/9203-arabic-words/9203_arabic_words.csv
# /kaggle/input/datasets/naghamalshbrawi/frequency-list/the_list_cleaned.csv
# /kaggle/input/datasets/naghamalshbrawi/expanded-list/the_list_expanded.csv
# /kaggle/input/datasets/feryaljadallah/parallel-bayyin/parallel_bayyin.csv

# %%
# !pip install camel-tools
# Out:
# Collecting camel-tools
#   Downloading camel_tools-1.5.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.17.0)
# Collecting docopt (from camel-tools)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cachetools<=6.0.0 (from camel-tools)
#   Downloading cachetools-6.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy<2 (from camel-tools)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.16.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.3.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from camel-tools) (1.6.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from camel-tools) (0.4.1)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.10.0+cu128)
# Collecting transformers<4.44.0,>=4.0 (from camel-tools)
#   Downloading transformers-4.43.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: editdistance in /usr/local/lib/python3.12/dist-packages (from camel-tools) (0.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.32.4)
# Requirement already satisfied: emoji in /usr/local/lib/python3.12/dist-packages (from camel-tools) (2.15.0)
# Collecting pyrsistent (from camel-tools)
#   Downloading pyrsistent-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from camel-tools) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from camel-tools) (4.67.3)
# Collecting muddler (from camel-tools)
#   Downloading muddler-0.1.3-py3-none-any.whl.metadata (7.5 kB)
# Collecting camel-kenlm<=2025.09.16 (from camel-tools)
#   Downloading camel_kenlm-2025.9.16-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (251 bytes)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->camel-tools) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0->camel-tools) (1.3.5)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers<4.44.0,>=4.0->camel-tools)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.44.0,>=4.0->camel-tools) (0.7.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers<4.44.0,>=4.0->camel-tools)
#   Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->camel-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->camel-tools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->camel-tools) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->camel-tools) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->camel-tools) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->camel-tools) (3.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers<4.44.0,>=4.0->camel-tools) (1.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->camel-tools) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->camel-tools) (3.0.3)
# Downloading camel_tools-1.5.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 6.1 MB/s eta 0:00:00
# Downloading cachetools-6.0.0-py3-none-any.whl (10 kB)
# Downloading camel_kenlm-2025.9.16-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 53.6 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 74.3 MB/s eta 0:00:00:00:0100:01
# Downloading transformers-4.43.4-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 105.8 MB/s eta 0:00:0000:0100:01
# Downloading muddler-0.1.3-py3-none-any.whl (16 kB)
# Downloading pyrsistent-0.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 8.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 23.9 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 67.0 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=94314e8aa6ef24f9f4fa56d96bb942a54748e59a971ff42d883b1c16bfec884b
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, camel-kenlm, pyrsistent, numpy, muddler, cachetools, huggingface-hub, tokenizers, transformers, camel-tools
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 6.2.6
#     Uninstalling cachetools-6.2.6:
#       Successfully uninstalled cachetools-6.2.6
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# kaggle-environments 1.27.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed cachetools-6.0.0 camel-kenlm-2025.9.16 camel-tools-1.5.7 docopt-0.6.2 huggingface-hub-0.36.2 muddler-0.1.3 numpy-1.26.4 pyrsistent-0.20.0 tokenizers-0.19.1 transformers-4.43.4

# %%
import pandas as pd
import re
from camel_tools.tokenizers.word import simple_word_tokenize
from camel_tools.disambig.mle import MLEDisambiguator

# %%
# !pip install --upgrade --force-reinstall numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 89.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# camel-tools 1.5.7 requires numpy<2, but you have numpy 2.4.4 which is incompatible.
# ydata-profiling 4.18.1 requires numpy<2.4,>=1.22, but you have numpy 2.4.4 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.4 which is incompatible.
# Successfully installed numpy-2.4.4

# %%
list_path = "/kaggle/input/datasets/naghamalshbrawi/9203-arabic-words/9203_arabic_words.csv"
list_df = pd.read_csv(list_path)

# %%
file_path = "/kaggle/input/datasets/rayaabualjamal/combined-parallel-dataset/full_merged_data (2).csv"
final_df = pd.read_csv(file_path)

# Drop rows where evaluation_status == "flag"
final_df = final_df[final_df["evaluation_status"] != "Flag"].copy()
final_df = final_df.reset_index(drop=True)

# %%
final_df.head(1)
# Out:
#                               Original_Sentence  \
# 0  •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
#
#                                              level_1  \
# 0  "عدم الانحياز" يعني أن تكون محايداً ولا تفضل أ...
#
#                                              level_2  \
# 0  "عدم الانحياز" هو مصطلح سياسي يعني أن تكون محا...
#
#                                           level_3 evaluation_status  \
# 0  "عدم الانحياز" هو مصطلح سياسي يشير إلى الحياد.              Pass
#
#   issue_details
# 0           NaN

# %%
ARABIC_DIACRITICS = re.compile(r"""
    [\u0617-\u061A]
  | [\u064B-\u0652]
  | [\u0657-\u065F]
  | [\u0670]
  | [\u06D6-\u06ED]
  | [\u0640]
""", re.VERBOSE)

ARABIC_LETTERS_PATTERN = re.compile(r'[\u0600-\u06FF]')
ARABIC_DIGITS_PATTERN = re.compile(r'^[0-9\u0660-\u0669]+$')

def remove_diacritics(text):
    if pd.isna(text):
        return ""
    return re.sub(ARABIC_DIACRITICS, "", str(text))

def normalize_arabic(text):
    if pd.isna(text):
        return ""
    text = str(text)
    text = remove_diacritics(text)
    text = re.sub(r"[إأآٱ]", "ا", text)
    text = text.replace("ؤ", "و")
    text = text.replace("ئ", "ي")
    text = text.replace("ى", "ي")
    text = re.sub(r"\s+", " ", text).strip()
    return text

def strip_punct(token):
    """Remove punctuation around token."""
    token = str(token)
    token = re.sub(r"^[^\u0600-\u06FF0-9]+|[^\u0600-\u06FF0-9]+$", "", token)
    return token.strip()

def is_arabic_word(token):
    """Keep only tokens that contain Arabic letters."""
    return bool(ARABIC_LETTERS_PATTERN.search(str(token)))

# %%
freq_raw_set = set(
    list_df["Arabic"].dropna().astype(str).str.strip()
)

freq_no_diac_set = set(
    list_df["arabic_no_diacritics"].dropna().astype(str).str.strip()
)

freq_norm_set = set(
    list_df["arabic_normalized"].dropna().astype(str).str.strip()
)

# %%
# !camel_data -i all
# Out:
# The following packages will be installed: 'disambig-ranking-cache-calima-msa-r13', 'disambig-ranking-cache-calima-glf-01', 'dialectid-model6', 'disambig-mle-calima-egy-r13', 'sentiment-analysis-mbert', 'disambig-ranking-cache-calima-lev-01', 'morphology-db-glf-01', 'disambig-bert-unfactored-egy', 'disambig-bert-unfactored-lev', 'morphology-db-msa-s31', 'ner-arabert', 'dialectid-model26', 'disambig-mle-calima-msa-r13', 'sentiment-analysis-arabert', 'disambig-bert-unfactored-glf', 'disambig-bert-unfactored-msa', 'morphology-db-egy-r13', 'morphology-db-msa-r13', 'morphology-db-lev-01', 'disambig-ranking-cache-calima-egy-r13'
# Downloading package 'disambig-ranking-cache-calima-msa-r13': 100%|█| 556M/556M [
# Extracting package 'disambig-ranking-cache-calima-msa-r13': 100%|█| 556M/556M [0
# Downloading package 'disambig-ranking-cache-calima-glf-01': 100%|█| 28.7M/28.7M
# Extracting package 'disambig-ranking-cache-calima-glf-01': 100%|█| 28.7M/28.7M [
# Downloading package 'dialectid-model6': 100%|█| 153M/153M [00:00<00:00, 189MB/s]
# Extracting package 'dialectid-model6': 100%|██| 153M/153M [00:00<00:00, 591MB/s]
# Downloading package 'disambig-mle-calima-egy-r13': 100%|█| 27.2M/27.2M [00:00<00
# Extracting package 'disambig-mle-calima-egy-r13': 100%|█| 27.2M/27.2M [00:00<00:
# Downloading package 'sentiment-analysis-mbert': 100%|█| 712M/712M [00:04<00:00,
# Extracting package 'sentiment-analysis-mbert': 100%|█| 712M/712M [00:01<00:00, 5
# Downloading package 'disambig-ranking-cache-calima-lev-01': 100%|█| 23.2M/23.2M
# Extracting package 'disambig-ranking-cache-calima-lev-01': 100%|█| 23.2M/23.2M [
# Downloading package 'morphology-db-glf-01': 100%|█| 7.98M/7.98M [00:00<00:00, 89
# Extracting package 'morphology-db-glf-01': 100%|█| 7.98M/7.98M [00:00<00:00, 554
# Downloading package 'disambig-bert-unfactored-egy': 100%|█| 446M/446M [00:02<00:
# Extracting package 'disambig-bert-unfactored-egy': 100%|█| 446M/446M [00:00<00:0
# Downloading package 'disambig-bert-unfactored-lev': 100%|█| 441M/441M [00:02<00:
# Extracting package 'disambig-bert-unfactored-lev': 100%|█| 441M/441M [00:00<00:0
# Downloading package 'morphology-db-msa-s31': 100%|█| 44.8M/44.8M [00:00<00:00, 1
# Extracting package 'morphology-db-msa-s31': 100%|█| 44.8M/44.8M [00:00<00:00, 53
# Downloading package 'ner-arabert': 100%|██████| 542M/542M [00:03<00:00, 175MB/s]
# Extracting package 'ner-arabert': 100%|███████| 542M/542M [00:00<00:00, 567MB/s]
# Downloading package 'dialectid-model26': 100%|█| 371M/371M [00:02<00:00, 156MB/s
# Extracting package 'dialectid-model26': 100%|█| 371M/371M [00:00<00:00, 579MB/s]
# Downloading package 'disambig-mle-calima-msa-r13': 100%|█| 88.7M/88.7M [00:00<00
# Extracting package 'disambig-mle-calima-msa-r13': 100%|█| 88.7M/88.7M [00:00<00:
# Downloading package 'sentiment-analysis-arabert': 100%|█| 542M/542M [00:03<00:00
# Extracting package 'sentiment-analysis-arabert': 100%|█| 542M/542M [00:00<00:00,
# Downloading package 'disambig-bert-unfactored-glf': 100%|█| 442M/442M [00:02<00:
# Extracting package 'disambig-bert-unfactored-glf': 100%|█| 442M/442M [00:00<00:0
# Downloading package 'disambig-bert-unfactored-msa': 100%|█| 445M/445M [00:02<00:
# Extracting package 'disambig-bert-unfactored-msa': 100%|█| 445M/445M [00:00<00:0
# Downloading package 'morphology-db-egy-r13': 100%|█| 67.3M/67.3M [00:00<00:00, 1
# Extracting package 'morphology-db-egy-r13': 100%|█| 67.3M/67.3M [00:00<00:00, 58
# Downloading package 'morphology-db-msa-r13': 100%|█| 40.5M/40.5M [00:00<00:00, 1
# Extracting package 'morphology-db-msa-r13': 100%|█| 40.5M/40.5M [00:00<00:00, 57
# Downloading package 'morphology-db-lev-01': 100%|█| 10.6M/10.6M [00:00<00:00, 10
# Extracting package 'morphology-db-lev-01': 100%|█| 10.6M/10.6M [00:00<00:00, 577
# Downloading package 'disambig-ranking-cache-calima-egy-r13': 100%|█| 320M/320M [
# Extracting package 'disambig-ranking-cache-calima-egy-r13': 100%|█| 320M/320M [0

# %%
mle = MLEDisambiguator.pretrained()

def get_best_analysis(token):
    """
    Return best CAMeL analysis dictionary for a token.
    If it fails, return empty dict.
    """
    try:
        disambig = mle.disambiguate([token])
        if not disambig or not disambig[0].analyses:
            return {}
        return disambig[0].analyses[0].analysis
    except:
        return {}

def get_pos(token):
    analysis = get_best_analysis(token)
    return analysis.get("pos", "")

def get_lemma(token):
    """
    Use CAMeL lemma as a fallback lemma signal.
    In your full replication, Farasa can replace/confirm this later.
    """
    analysis = get_best_analysis(token)
    lemma = analysis.get("lex", "") or analysis.get("lemma", "")
    return str(lemma).strip()

# %%
# The paper excludes prepositions before checking complexity.
# Since automatic POS tagging is not always perfect for function words,
# we also keep a manual Arabic preposition list as a safety layer.

PREPOSITIONS = {
    "في", "من", "الى", "إلى", "عن", "على", "ب", "ل", "ك", "حتى",
    "منذ", "مذ", "خلال", "دون", "عند", "بين", "نحو", "حول", "مع",
    "لدى", "تحت", "فوق", "وراء", "أمام", "داخل", "خارج", "بعد", "قبل"
}

# We also normalize them once so comparison is consistent
PREPOSITIONS_NORM = {normalize_arabic(p) for p in PREPOSITIONS}

# %%
def is_number_token(token, pos_tag=""):
    token = str(token).strip()
    pos_tag = str(pos_tag).lower()
    return ARABIC_DIGITS_PATTERN.match(token) is not None or pos_tag.startswith("num")

def is_proper_noun(pos_tag=""):
    pos_tag = str(pos_tag).lower()
    return pos_tag.startswith("noun_prop")

def is_preposition(token, pos_tag=""):
    pos_tag = str(pos_tag).lower()
    if normalize_arabic(token) in PREPOSITIONS_NORM:
        return True
    if pos_tag.startswith("prep"):
        return True
    return False

# %%
import re
import pandas as pd

def split_variants_enhanced(text):
    """
    Splits a cell into individual words to ensure every single word 
    is captured in the lookup set.
    """
    if pd.isna(text):
        return []
    
    text = str(text).strip()
    if not text:
        return []

    # 1. Split by common separators (Arabic comma, English comma, semicolon, slash)
    parts = re.split(r'[،,;/]+', text)
    
    final_words = []
    for part in parts:
        # 2. Split each part by spaces to extract individual words
        words = part.split() 
        final_words.extend(words)

    # 3. Clean words from punctuation (like parentheses or periods)
    clean_words = [re.sub(r'[^\w\s]', '', w).strip() for w in final_words if w.strip()]
    
    return clean_words

def build_variant_set(series):
    """
    Iterates through a column and builds a unique set of all 
    individual words found in those cells.
    """
    values = set()
    for cell in series.dropna():
        # Get the list of individual words from the enhanced splitter
        for item in split_variants_enhanced(cell):
            values.add(item)
    return values


freq_raw_set = build_variant_set(list_df["Arabic"])

# Example check:
# Even if the Excel cell says "سباق السيارات", this will now return True
print("السيارات" in freq_raw_set)
# Out:
# True

# %%
def exists_in_frequency_list(token, lemma=""):
    """
    A word is considered found if ANY of these match the list:
    - raw token
    - token without diacritics
    - normalized token
    - raw lemma
    - lemma without diacritics
    - normalized lemma
    """
    candidates = set()

    token = strip_punct(token)
    lemma = strip_punct(lemma)

    if token:
        candidates.add(str(token).strip())
        candidates.add(remove_diacritics(token).strip())
        candidates.add(normalize_arabic(token).strip())

    if lemma:
        candidates.add(str(lemma).strip())
        candidates.add(remove_diacritics(lemma).strip())
        candidates.add(normalize_arabic(lemma).strip())

    # remove empty items
    candidates = {c for c in candidates if c}

    for c in candidates:
        if c in freq_raw_set or c in freq_no_diac_set or c in freq_norm_set:
            return True, sorted(candidates)

    return False, sorted(candidates)

# %%
def identify_complex_words(sentence):
    """
    For one sentence:
    - tokenize
    - clean punctuation
    - exclude proper nouns, prepositions, and numbers
    - check token and lemma against frequency list
    - if found in the frequency list -> exclude from complexity candidates
    - if not found -> treat as complex
    """
    if pd.isna(sentence):
        return []

    tokens = simple_word_tokenize(str(sentence))
    results = []

    for token in tokens:
        cleaned_token = strip_punct(token)

        # Skip empty or punctuation-only tokens
        if not cleaned_token:
            continue

        # Skip non-Arabic tokens
        if not is_arabic_word(cleaned_token):
            continue

        analysis = get_best_analysis(cleaned_token)
        pos_tag = analysis.get("pos", "")
        lemma = analysis.get("lex", "") or analysis.get("lemma", "")

        # Exclude proper nouns
        if is_proper_noun(pos_tag):
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "proper_noun",
                "lookup_candidates": [],
                "in_frequency_list": None,
                "is_complex": False
            })
            continue

        # Exclude prepositions
        if is_preposition(cleaned_token, pos_tag):
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "preposition",
                "lookup_candidates": [],
                "in_frequency_list": None,
                "is_complex": False
            })
            continue

        # Exclude numbers
        if is_number_token(cleaned_token, pos_tag):
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "number",
                "lookup_candidates": [],
                "in_frequency_list": None,
                "is_complex": False
            })
            continue

        # Check whether the word exists in the frequency list
        in_freq, lookup_candidates = exists_in_frequency_list(cleaned_token, lemma)

        # If found in the list, exclude it from complex-word candidates
        if in_freq:
            results.append({
                "token": cleaned_token,
                "lemma": lemma,
                "pos": pos_tag,
                "excluded": True,
                "exclude_reason": "in_frequency_list",
                "lookup_candidates": lookup_candidates,
                "in_frequency_list": True,
                "is_complex": False
            })
            continue

        # Otherwise, the word is treated as complex
        results.append({
            "token": cleaned_token,
            "lemma": lemma,
            "pos": pos_tag,
            "excluded": False,
            "exclude_reason": "",
            "lookup_candidates": lookup_candidates,
            "in_frequency_list": False,
            "is_complex": True
        })

    return results

# %%
# This creates:
# - cwi_details: full token-level analysis
# - complex_words: only the tokens marked as complex
final_df["cwi_details"] = final_df["Original_Sentence"].apply(identify_complex_words)
final_df["complex_words"] = final_df["cwi_details"].apply(
    lambda rows: [r["token"] for r in rows if r["is_complex"]]
)

# %%
# quick preview
for i in range(min(15, len(final_df))):
    print("=" * 80)
    print("Original_Text:", final_df.loc[i, "Original_Sentence"])
    print("Complex words:", final_df.loc[i, "complex_words"])
    print("Details:")
    for row in final_df.loc[i, "cwi_details"]:
        print(row)
# Out:
# ================================================================================
# Original_Text: •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
# Complex words: ['الانحياز', 'اصطلاح', 'سياسي', 'الحياد']
# Details:
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'اصطلاح', 'lemma': 'ٱِصْطِلاح', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['اصطلاح', 'ٱصطلاح', 'ٱِصْطِلاح'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'سياسي', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'يعنى', 'lemma': 'عَنَى', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عنى', 'عني', 'عَنَى', 'يعنى', 'يعني'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الحياد', 'lemma': 'حِياد', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الحياد', 'حياد', 'حِياد'], 'in_frequency_list': False, 'is_complex': True}
# ================================================================================
# Original_Text: حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# Complex words: ['المنحازة']
# Details:
# {'token': 'حيث', 'lemma': 'حَيْثُ', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حيث', 'حَيْثُ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تلتزم', 'lemma': 'ٱِلْتَزَم', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التزم', 'تلتزم', 'ٱلتزم', 'ٱِلْتَزَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'بعدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بعدم', 'عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الارتباط', 'lemma': 'ٱِرْتِباط', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['ارتباط', 'الارتباط', 'ٱرتباط', 'ٱِرْتِباط'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بأي', 'lemma': 'أَيّ', 'pos': 'noun_quant', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أي', 'أَيّ', 'اي', 'بأي', 'باي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'دول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أجنبية', 'lemma': 'أَجْنَبِيّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أجنبي', 'أجنبية', 'أَجْنَبِيّ', 'اجنبي', 'اجنبية'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الشرق', 'lemma': 'شَرْق', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'أو', 'lemma': 'أَو', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أو', 'أَو', 'او'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الغرب', 'lemma': 'غَرْب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الغرب', 'غرب', 'غَرْب'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Complex words: ['المنحازة', 'المتفرج', 'العالمية']
# Details:
# {'token': 'بمعنى', 'lemma': 'مَعْنَى', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بمعنى', 'بمعني', 'معنى', 'معني', 'مَعْنَى'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أن', 'lemma': 'أَنَّ', 'pos': 'conj_sub', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أن', 'أَنَّ', 'ان'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المنحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المنحازة', 'منحاز', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'لا', 'lemma': 'لا', 'pos': 'part_neg', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تقف', 'lemma': 'وَقَف', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تقف', 'وقف', 'وَقَف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'موقف', 'lemma': 'مَوْقِف', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['موقف', 'مَوْقِف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتفرج', 'lemma': 'مُتَفَرِّج', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المتفرج', 'متفرج', 'مُتَفَرِّج'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أمام', 'lemma': 'أَمام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'المشاكل', 'lemma': 'مُشْكِلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المشاكل', 'مشكلة', 'مُشْكِلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'والأحداث', 'lemma': 'حَدَث', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حدث', 'حَدَث', 'والأحداث', 'والاحداث'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'العالمية', 'lemma': 'عالَمِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العالمية', 'عالمي', 'عالَمِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'بل', 'lemma': 'بَل', 'pos': 'conj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بل', 'بَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يكون', 'lemma': 'كان', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['كان', 'يكون'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لها', 'lemma': 'لِ', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'دور', 'lemma': 'دَوْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دور', 'دَوْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يسير', 'lemma': 'سار', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سار', 'يسير'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مع', 'lemma': 'مَع', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مصالحها', 'lemma': 'مَصْلَحَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصالحها', 'مصلحة', 'مَصْلَحَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هي', 'lemma': 'هِيَ', 'pos': 'pron', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هي', 'هِيَ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لا', 'lemma': 'لا', 'pos': 'part_neg', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مصالح', 'lemma': 'مَصْلَحَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مصالح', 'مصلحة', 'مَصْلَحَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدول', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدول', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المتصارعة', 'lemma': 'متصارعه', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# ================================================================================
# Original_Text: وقد بدأ استعمال اصطلاح (عدم الانحياز) في مؤتمر بلغراد عام 1961، والذي اشتركت فيه 21 دولة غير منحازة
# Complex words: ['اصطلاح', 'الانحياز', '،', 'منحازة']
# Details:
# {'token': 'وقد', 'lemma': 'قَدْ', 'pos': 'part_verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قد', 'قَدْ', 'وقد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بدأ', 'lemma': 'بَدَأ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بدأ', 'بدا', 'بَدَأ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'استعمال', 'lemma': 'ٱِسْتِعْمال', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استعمال', 'ٱستعمال', 'ٱِسْتِعْمال'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'اصطلاح', 'lemma': 'ٱِصْطِلاح', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['اصطلاح', 'ٱصطلاح', 'ٱِصْطِلاح'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'عدم', 'lemma': 'عَدَم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عدم', 'عَدَم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الانحياز', 'lemma': 'ٱِنْحِياز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الانحياز', 'انحياز', 'ٱنحياز', 'ٱِنْحِياز'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'مؤتمر', 'lemma': 'مُؤْتَمَر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مؤتمر', 'موتمر', 'مُؤْتَمَر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بلغراد', 'lemma': 'بَلْغراد', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'عام', 'lemma': 'عام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'والذي', 'lemma': 'الَّذِي', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الذي', 'الَّذِي', 'والذي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'اشتركت', 'lemma': 'ٱِشْتَرَك', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['اشترك', 'اشتركت', 'ٱشترك', 'ٱِشْتَرَك'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'فيه', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'دولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'غير', 'lemma': 'غَيْر', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غير', 'غَيْر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'منحازة', 'lemma': 'مُنْحاز', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['منحاز', 'منحازة', 'مُنْحاز'], 'in_frequency_list': False, 'is_complex': True}
# ================================================================================
# Original_Text: ••السيارات التي يستعملها الدبلوماسيون.. أي رجال السفارات المعتمدون لدى الدولة تحمل هذه الجملة (هيئة سياسية).
# Complex words: ['سياسية']
# Details:
# {'token': 'السيارات', 'lemma': 'سَيّارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السيارات', 'سيارة', 'سَيّارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'التي', 'lemma': 'الَّذِي', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التي', 'الذي', 'الَّذِي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'يستعملها', 'lemma': 'ٱِسْتَعْمَل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['استعمل', 'يستعملها', 'ٱستعمل', 'ٱِسْتَعْمَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الدبلوماسيون', 'lemma': 'دِبلُوماسِيّ', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدبلوماسيون', 'دبلوماسي', 'دِبلُوماسِيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أي', 'lemma': 'أَيّ', 'pos': 'pron_interrog', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أي', 'أَيّ', 'اي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'رجال', 'lemma': 'رَجُل', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['رجال', 'رجل', 'رَجُل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'السفارات', 'lemma': 'سِفارَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السفارات', 'سفارة', 'سِفارَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المعتمدون', 'lemma': 'مُعْتَمَد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المعتمدون', 'معتمد', 'مُعْتَمَد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لدى', 'lemma': 'لَدَى', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الدولة', 'lemma': 'دَوْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الدولة', 'دولة', 'دَوْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تحمل', 'lemma': 'حَمَل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تحمل', 'حمل', 'حَمَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هذه', 'lemma': 'هٰذا', 'pos': 'pron_dem', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هذا', 'هذه', 'هٰذا'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الجملة', 'lemma': 'جُمْلَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الجملة', 'جملة', 'جُمْلَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'هيئة', 'lemma': 'هَيْئَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هيئة', 'هيية', 'هَيْئَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سياسية', 'lemma': 'سِياسِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['سياسي', 'سياسية', 'سِياسِيّ'], 'in_frequency_list': False, 'is_complex': True}
# ================================================================================
# Original_Text: يقصد بالتنمية.. خطة اقتصادية لزيادة الإنتاج.. ورفع مستوى المعيشة للأفراد.
# Complex words: []
# Details:
# {'token': 'يقصد', 'lemma': 'قَصَد', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قصد', 'قَصَد', 'يقصد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بالتنمية', 'lemma': 'تَنْمِيَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بالتنمية', 'تنمية', 'تَنْمِيَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'خطة', 'lemma': 'خُطَّة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['خطة', 'خُطَّة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'اقتصادية', 'lemma': 'ٱِقْتِصادِيّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['اقتصادي', 'اقتصادية', 'ٱقتصادي', 'ٱِقْتِصادِيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لزيادة', 'lemma': 'زِيادَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['زيادة', 'زِيادَة', 'لزيادة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الإنتاج', 'lemma': 'إِنْتاج', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['إنتاج', 'إِنْتاج', 'الإنتاج', 'الانتاج', 'انتاج'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'ورفع', 'lemma': 'رَفَع', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['رفع', 'رَفَع', 'ورفع'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مستوى', 'lemma': 'مُسْتَوَى', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مستوى', 'مستوي', 'مُسْتَوَى'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المعيشة', 'lemma': 'مَعِيشَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المعيشة', 'معيشة', 'مَعِيشَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'للأفراد', 'lemma': 'فَرْد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['فرد', 'فَرْد', 'للأفراد', 'للافراد'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: حضرموت – اليمن الديمقراطية
# Complex words: ['الديمقراطية']
# Details:
# {'token': 'حضرموت', 'lemma': 'حَضْرَمَوْت', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'اليمن', 'lemma': 'يَمَن', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الديمقراطية', 'lemma': 'دِيمُوقراطِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الديمقراطية', 'ديموقراطي', 'دِيمُوقراطِيّ'], 'in_frequency_list': False, 'is_complex': True}
# ================================================================================
# Original_Text: العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة
# Complex words: ['العنقاء']
# Details:
# {'token': 'العنقاء', 'lemma': 'عَنْقاء', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العنقاء', 'عنقاء', 'عَنْقاء'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'هي', 'lemma': 'هِيَ', 'pos': 'pron', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هي', 'هِيَ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'رمز', 'lemma': 'رَمْز', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['رمز', 'رَمْز'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'البعث', 'lemma': 'بَعْث', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['البعث', 'بعث', 'بَعْث'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'والخلود', 'lemma': 'خُلُود', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['خلود', 'خُلُود', 'والخلود'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'الأساطير', 'lemma': 'أُسْطُورَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أسطورة', 'أُسْطُورَة', 'اسطورة', 'الأساطير', 'الاساطير'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المصرية', 'lemma': 'مِصْرِيّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المصرية', 'مصري', 'مِصْرِيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'القديمة', 'lemma': 'قَدِيم', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['القديمة', 'قديم', 'قَدِيم'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: ويقال إنها لما بلغت 500 سنة أحرقت نفسها وبرزت من دخانها عنقاء أخرى..
# Complex words: ['أحرقت', 'عنقاء']
# Details:
# {'token': 'ويقال', 'lemma': 'قال', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قال', 'ويقال'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'إنها', 'lemma': 'إِنَّ', 'pos': 'verb_pseudo', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['إن', 'إنها', 'إِنَّ', 'ان', 'انها'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لما', 'lemma': 'ما', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لما', 'ما'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بلغت', 'lemma': 'بَلَغ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بلغ', 'بلغت', 'بَلَغ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سنة', 'lemma': 'سَنَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سنة', 'سَنَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أحرقت', 'lemma': 'أَحْرَق', 'pos': 'verb', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['أحرق', 'أحرقت', 'أَحْرَق', 'احرق', 'احرقت'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'نفسها', 'lemma': 'نَفْس', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['نفس', 'نفسها', 'نَفْس'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'وبرزت', 'lemma': 'بَرَز', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['برز', 'بَرَز', 'وبرزت'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'من', 'lemma': 'مِن', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'دخانها', 'lemma': 'دُخان', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['دخان', 'دخانها', 'دُخان'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عنقاء', 'lemma': 'عَنْقاء', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['عنقاء', 'عَنْقاء'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'أخرى', 'lemma': 'أُخْرَى', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أخرى', 'أُخْرَى', 'اخري'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: وقد اعتبرها العرب أحد المستحيلات الثلاثة، العنقاء والغول والخل الوفي.
# Complex words: ['المستحيلات', 'الثلاثة', '،', 'العنقاء', 'والخل']
# Details:
# {'token': 'وقد', 'lemma': 'قَدْ', 'pos': 'part_verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قد', 'قَدْ', 'وقد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'اعتبرها', 'lemma': 'ٱِعْتَبَر', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['اعتبر', 'اعتبرها', 'ٱعتبر', 'ٱِعْتَبَر'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'العرب', 'lemma': 'عَرَب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['العرب', 'عرب', 'عَرَب'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أحد', 'lemma': 'أَحَد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أحد', 'أَحَد', 'احد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'المستحيلات', 'lemma': 'مُسْتَحِيل', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المستحيلات', 'مستحيل', 'مُسْتَحِيل'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'الثلاثة', 'lemma': 'ثَلاث', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الثلاثة', 'ثلاث', 'ثَلاث'], 'in_frequency_list': False, 'is_complex': True}
# {'token': '،', 'lemma': '،', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['،'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'العنقاء', 'lemma': 'عَنْقاء', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العنقاء', 'عنقاء', 'عَنْقاء'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'والغول', 'lemma': 'غُول', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'والخل', 'lemma': 'خَلّ', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['خل', 'خَلّ', 'والخل'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'الوفي', 'lemma': 'وَفِيّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الوفي', 'وفي', 'وَفِيّ'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: عندما قرأنا الخبر صدقنا أن العنقاء موجودة فعلا عند البروفسور وأنها تساوي مليون دولار
# Complex words: ['العنقاء', 'دولار']
# Details:
# {'token': 'عندما', 'lemma': 'عِنْد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عند', 'عندما', 'عِنْد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'قرأنا', 'lemma': 'قَرَأ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قرأ', 'قرأنا', 'قرا', 'قرانا', 'قَرَأ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الخبر', 'lemma': 'خُبَر', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'صدقنا', 'lemma': 'صَدَّق', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['صدق', 'صدقنا', 'صَدَّق'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أن', 'lemma': 'أَنَّ', 'pos': 'conj_sub', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أن', 'أَنَّ', 'ان'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'العنقاء', 'lemma': 'عَنْقاء', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['العنقاء', 'عنقاء', 'عَنْقاء'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'موجودة', 'lemma': 'مَوْجُود', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['موجود', 'موجودة', 'مَوْجُود'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'فعلا', 'lemma': 'فِعْل', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['فعل', 'فعلا', 'فِعْل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عند', 'lemma': 'عِنْد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'البروفسور', 'lemma': 'برُوفِسُور', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['البروفسور', 'بروفسور', 'برُوفِسُور'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'وأنها', 'lemma': 'أَنَّ', 'pos': 'conj_sub', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أن', 'أَنَّ', 'ان', 'وأنها', 'وانها'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تساوي', 'lemma': 'ساوَى', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تساوي', 'ساوى', 'ساوي', 'ساوَى'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مليون', 'lemma': 'مِلْيُون', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مليون', 'مِلْيُون'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'دولار', 'lemma': 'دُولار', 'pos': 'noun', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['دولار', 'دُولار'], 'in_frequency_list': False, 'is_complex': True}
# ================================================================================
# Original_Text: الأدب الجاهلي هو أدب الفترة التي سبقت ظهور الإسلام بنحو قرن ونصف القرن..
# Complex words: ['الجاهلي']
# Details:
# {'token': 'الأدب', 'lemma': 'أَدَب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أدب', 'أَدَب', 'ادب', 'الأدب', 'الادب'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الجاهلي', 'lemma': 'جاهِلِيّ', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['الجاهلي', 'جاهلي', 'جاهِلِيّ'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'هو', 'lemma': 'هُوَ', 'pos': 'pron', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هو', 'هُوَ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أدب', 'lemma': 'أَدَب', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أدب', 'أَدَب', 'ادب'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الفترة', 'lemma': 'فَتْرَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الفترة', 'فترة', 'فَتْرَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'التي', 'lemma': 'الَّذِي', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['التي', 'الذي', 'الَّذِي'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'سبقت', 'lemma': 'سَبَق', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سبق', 'سبقت', 'سَبَق'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'ظهور', 'lemma': 'ظُهُور', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['ظهور', 'ظُهُور'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الإسلام', 'lemma': 'إِسْلام', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'بنحو', 'lemma': 'نَحْو', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بنحو', 'نحو', 'نَحْو'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'قرن', 'lemma': 'قَرْن', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قرن', 'قَرْن'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'ونصف', 'lemma': 'نِصْف', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['نصف', 'نِصْف', 'ونصف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'القرن', 'lemma': 'قَرْن', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['القرن', 'قرن', 'قَرْن'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: ردت الصغيرة بقوة: وهل كنت تخافين عندما كنت تعملين في المقاومة السرية أيام الاحتلال الألماني لفرنسا؟
# Complex words: ['؟']
# Details:
# {'token': 'ردت', 'lemma': 'رَدّ', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['رد', 'ردت', 'رَدّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الصغيرة', 'lemma': 'صَغِير', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['الصغيرة', 'صغير', 'صَغِير'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'بقوة', 'lemma': 'قُوَّة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['بقوة', 'قوة', 'قُوَّة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'وهل', 'lemma': 'هَل', 'pos': 'part_interrog', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هل', 'هَل', 'وهل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'كنت', 'lemma': 'كان', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['كان', 'كنت'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تخافين', 'lemma': 'خاف', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تخافين', 'خاف'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عندما', 'lemma': 'عِنْد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عند', 'عندما', 'عِنْد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'كنت', 'lemma': 'كان', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['كان', 'كنت'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'تعملين', 'lemma': 'عَمِل', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['تعملين', 'عمل', 'عَمِل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'في', 'lemma': 'فِي', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'المقاومة', 'lemma': 'مُقاوَمَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['المقاومة', 'مقاومة', 'مُقاوَمَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'السرية', 'lemma': 'سِرِّيّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السرية', 'سري', 'سِرِّيّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أيام', 'lemma': 'يَوْم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['أيام', 'ايام', 'يوم', 'يَوْم'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الاحتلال', 'lemma': 'ٱِحْتِلال', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['احتلال', 'الاحتلال', 'ٱحتلال', 'ٱِحْتِلال'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'الألماني', 'lemma': 'أَلْمانِيّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['ألماني', 'أَلْمانِيّ', 'الألماني', 'الالماني', 'الماني'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لفرنسا', 'lemma': 'فَرَنْسا', 'pos': 'noun_prop', 'excluded': True, 'exclude_reason': 'proper_noun', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': '؟', 'lemma': '؟', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['؟'], 'in_frequency_list': False, 'is_complex': True}
# ================================================================================
# Original_Text: وقال لمن حوله: -أنتم جميعًا مدعوون للغداء عندي اليوم.
# Complex words: ['أنتم']
# Details:
# {'token': 'وقال', 'lemma': 'قال', 'pos': 'verb', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['قال', 'وقال'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'لمن', 'lemma': 'مَن', 'pos': 'pron_rel', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['لمن', 'من', 'مَن'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'حوله', 'lemma': 'حَوْل', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['حول', 'حوله', 'حَوْل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'أنتم', 'lemma': 'أَنْتُم', 'pos': 'pron', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['أنتم', 'أَنْتُم', 'انتم'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'جميعًا', 'lemma': 'جَمِيع', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['جميع', 'جميعا', 'جميعًا', 'جَمِيع'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'مدعوون', 'lemma': 'مَدْعُوّ', 'pos': 'adj', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['مدعو', 'مدعوون', 'مَدْعُوّ'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'للغداء', 'lemma': 'غَداء', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['غداء', 'غَداء', 'للغداء'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'عندي', 'lemma': 'عِنْد', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['عند', 'عندي', 'عِنْد'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'اليوم', 'lemma': 'يَوْم', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['اليوم', 'يوم', 'يَوْم'], 'in_frequency_list': True, 'is_complex': False}
# ================================================================================
# Original_Text: •هل إلقاء السلام على المسلم سنة؟
# Complex words: ['المسلم', '؟']
# Details:
# {'token': 'هل', 'lemma': 'هَل', 'pos': 'part_interrog', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['هل', 'هَل'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'إلقاء', 'lemma': 'إِلْقاء', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['إلقاء', 'إِلْقاء', 'القاء'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'السلام', 'lemma': 'سَلام', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['السلام', 'سلام', 'سَلام'], 'in_frequency_list': True, 'is_complex': False}
# {'token': 'على', 'lemma': 'عَلَى', 'pos': 'prep', 'excluded': True, 'exclude_reason': 'preposition', 'lookup_candidates': [], 'in_frequency_list': None, 'is_complex': False}
# {'token': 'المسلم', 'lemma': 'مُسْلِم', 'pos': 'adj', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['المسلم', 'مسلم', 'مُسْلِم'], 'in_frequency_list': False, 'is_complex': True}
# {'token': 'سنة', 'lemma': 'سَنَة', 'pos': 'noun', 'excluded': True, 'exclude_reason': 'in_frequency_list', 'lookup_candidates': ['سنة', 'سَنَة'], 'in_frequency_list': True, 'is_complex': False}
# {'token': '؟', 'lemma': '؟', 'pos': 'punc', 'excluded': False, 'exclude_reason': '', 'lookup_candidates': ['؟'], 'in_frequency_list': False, 'is_complex': True}

# %%
# Stage 2: Generate substitution candidates with Arabic-BERT MLM

# %%
import re
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
# 1) Load Arabic-BERT masked language model
# ------------------------------------------------------------
# Practical Arabic-BERT choice from the asafaya family.
# This is used here as a masked language model to generate
# substitution candidates for a masked complex word.

MODEL_NAME = "asafaya/bert-base-arabic"

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForMaskedLM.from_pretrained(MODEL_NAME)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()

print("Loaded model on:", device)
print("Mask token:", tokenizer.mask_token)
# Out:
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at asafaya/bert-base-arabic were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loaded model on: cuda
# Mask token: [MASK]

# %%
def mask_first_occurrence(sentence, target_word, mask_token):
    """
    Replace only the first exact occurrence of target_word in sentence
    with [MASK]. This avoids replacing every occurrence.
    """
    if not sentence or not target_word:
        return sentence, False

    # Escape target for regex safety
    pattern = re.escape(target_word)

    # Replace only first match
    masked_sentence, n = re.subn(pattern, mask_token, sentence, count=1)
    return masked_sentence, (n > 0)

# %%
def is_valid_candidate(token):
    """
    Keep only clean substitution candidates.
    We filter out:
    - special tokens
    - subword pieces like ##...
    - empty tokens
    - punctuation-only tokens
    - obvious non-Arabic fragments
    """
    if token is None:
        return False

    token = str(token).strip()

    if not token:
        return False

    # Skip special tokens and wordpieces
    if token in tokenizer.all_special_tokens:
        return False
    if token.startswith("##"):
        return False

    # Skip punctuation-only
    if re.fullmatch(r"[^\w\u0600-\u06FF]+", token):
        return False

    # Keep tokens that contain at least one Arabic character
    if not re.search(r"[\u0600-\u06FF]", token):
        return False

    return True

# %%
def generate_top5_substitutions(sentence, complex_word, top_k=5, search_k=50):
    """
    For one sentence + one complex word:
    - replace the word with [MASK]
    - run Arabic-BERT MLM
    - return top 5 candidate substitutions with probabilities

    Notes:
    - This works best when the complex word is represented as one mask.
    - If the target word is not found in the sentence, returns empty list.
    """
    masked_sentence, replaced = mask_first_occurrence(
        sentence=sentence,
        target_word=complex_word,
        mask_token=tokenizer.mask_token
    )

    if not replaced:
        return {
            "original_sentence": sentence,
            "complex_word": complex_word,
            "masked_sentence": sentence,
            "found_and_masked": False,
            "substitutions": []
        }

    # Tokenize
    inputs = tokenizer(masked_sentence, return_tensors="pt").to(device)

    # Find [MASK] position
    mask_positions = (inputs["input_ids"][0] == tokenizer.mask_token_id).nonzero(as_tuple=True)[0]

    if len(mask_positions) == 0:
        return {
            "original_sentence": sentence,
            "complex_word": complex_word,
            "masked_sentence": masked_sentence,
            "found_and_masked": False,
            "substitutions": []
        }

    mask_index = mask_positions[0].item()

    # Run model
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits[0, mask_index]

    # Convert logits to probabilities
    probs = torch.softmax(logits, dim=-1)

    # Take a larger pool first, then filter to valid Arabic candidates
    top_ids = torch.topk(probs, k=search_k).indices.tolist()

    candidates = []
    seen = set()

    for token_id in top_ids:
        token = tokenizer.convert_ids_to_tokens(token_id)
        prob = probs[token_id].item()

        if not is_valid_candidate(token):
            continue

        # Avoid duplicates
        if token in seen:
            continue

        seen.add(token)

        candidates.append({
            "candidate": token,
            "probability": prob
        })

        if len(candidates) == top_k:
            break

    return {
        "original_sentence": sentence,
        "complex_word": complex_word,
        "masked_sentence": masked_sentence,
        "found_and_masked": True,
        "substitutions": candidates
    }

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"GPU Compute Capability: {torch.cuda.get_device_capability(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU: Tesla T4
# GPU Compute Capability: (7, 5)

# %%
from tqdm.auto import tqdm

all_results = []

for _, row in tqdm(final_df.iterrows(), total=len(final_df), desc="Processing rows"):
    sentence = row["Original_Sentence"]
    complex_words = row["complex_words"]

    if not isinstance(complex_words, list) or len(complex_words) == 0:
        all_results.append([])
        continue

    row_results = []
    for cw in complex_words:
        result = generate_top5_substitutions(sentence, cw, top_k=5, search_k=50)
        row_results.append(result)

    all_results.append(row_results)

final_df["mlm_substitutions"] = all_results
# Out:
# Processing rows:   0%|          | 0/34294 [00:00<?, ?it/s]

# %%
#Preview a few rows
for i in range(min(3, len(final_df))):
    print("=" * 100)
    print("Original_Text:", final_df.loc[i, "Original_Sentence"])
    print("Complex words:", final_df.loc[i, "complex_words"])
    print("MLM substitutions:")
    for item in final_df.loc[i, "mlm_substitutions"]:
        print("-" * 60)
        print("Complex word:", item["complex_word"])
        print("Masked sentence:", item["masked_sentence"])
        print("Candidates:")
        for cand in item["substitutions"]:
            print(cand)
# Out:
# ====================================================================================================
# Original_Text: •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
# Complex words: ['الانحياز', 'اصطلاح', 'سياسي', 'الحياد']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: الانحياز
# Masked sentence: •• "عدم [MASK]" اصطلاح سياسي يعنى الحياد..
# Candidates:
# {'candidate': 'الرضا', 'probability': 0.10982364416122437}
# {'candidate': 'الاحترام', 'probability': 0.035581521689891815}
# {'candidate': 'الالتزام', 'probability': 0.029399525374174118}
# {'candidate': 'التمييز', 'probability': 0.026299308985471725}
# {'candidate': 'التدخل', 'probability': 0.02492225542664528}
# ------------------------------------------------------------
# Complex word: اصطلاح
# Masked sentence: •• "عدم الانحياز" [MASK] سياسي يعنى الحياد..
# Candidates:
# {'candidate': 'مصطلح', 'probability': 0.3239383101463318}
# {'candidate': 'خطاب', 'probability': 0.052453987300395966}
# {'candidate': 'موقف', 'probability': 0.04369442164897919}
# {'candidate': 'مطلب', 'probability': 0.031433310359716415}
# {'candidate': 'سلوك', 'probability': 0.031135614961385727}
# ------------------------------------------------------------
# Complex word: سياسي
# Masked sentence: •• "عدم الانحياز" اصطلاح [MASK] يعنى الحياد..
# Candidates:
# {'candidate': 'عام', 'probability': 0.07070989906787872}
# {'candidate': 'لا', 'probability': 0.0424947589635849}
# {'candidate': 'انجليزي', 'probability': 0.03839872404932976}
# {'candidate': 'عربي', 'probability': 0.031740352511405945}
# {'candidate': 'علمي', 'probability': 0.02304803393781185}
# ------------------------------------------------------------
# Complex word: الحياد
# Masked sentence: •• "عدم الانحياز" اصطلاح سياسي يعنى [MASK]..
# Candidates:
# {'candidate': 'الاستقلال', 'probability': 0.003940789960324764}
# {'candidate': 'المزيد', 'probability': 0.0033347303979098797}
# {'candidate': 'المقاومة', 'probability': 0.0028108053375035524}
# {'candidate': 'السياسة', 'probability': 0.0026005718391388655}
# {'candidate': 'السلام', 'probability': 0.002492754254490137}
# ====================================================================================================
# Original_Text: حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# Complex words: ['المنحازة']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: حيث تلتزم الدول غير [MASK] بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# Candidates:
# {'candidate': 'الاجنبية', 'probability': 0.144135519862175}
# {'candidate': 'العربية', 'probability': 0.10734312981367111}
# {'candidate': 'الاخرى', 'probability': 0.04726077988743782}
# {'candidate': 'المذكورة', 'probability': 0.036283887922763824}
# {'candidate': 'الاوربية', 'probability': 0.03170667216181755}
# ====================================================================================================
# Original_Text: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Complex words: ['المنحازة', 'المتفرج', 'العالمية']
# MLM substitutions:
# ------------------------------------------------------------
# Complex word: المنحازة
# Masked sentence: بمعنى أن الدول غير [MASK] لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Candidates:
# {'candidate': 'العربية', 'probability': 0.12591615319252014}
# {'candidate': 'الشيوعية', 'probability': 0.056970905512571335}
# {'candidate': 'المسلمة', 'probability': 0.04703801870346069}
# {'candidate': 'النفطية', 'probability': 0.04291851446032524}
# {'candidate': 'العظمى', 'probability': 0.03207551687955856}
# ------------------------------------------------------------
# Complex word: المتفرج
# Masked sentence: بمعنى أن الدول غير المنحازة لا تقف موقف [MASK] أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Candidates:
# {'candidate': 'واحد', 'probability': 0.25521934032440186}
# {'candidate': 'ثابت', 'probability': 0.033390648663043976}
# {'candidate': 'ضعيف', 'probability': 0.022297928109765053}
# {'candidate': 'المعارضة', 'probability': 0.01996208354830742}
# {'candidate': 'واحدة', 'probability': 0.017863065004348755}
# ------------------------------------------------------------
# Complex word: العالمية
# Masked sentence: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث [MASK].. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Candidates:
# {'candidate': 'الخارجية', 'probability': 0.056087203323841095}
# {'candidate': 'القادمة', 'probability': 0.05179305002093315}
# {'candidate': 'المستقبلية', 'probability': 0.045931126922369}
# {'candidate': 'الداخلية', 'probability': 0.03850799426436424}
# {'candidate': 'الجارية', 'probability': 0.03835133835673332}

# %%
model.save_pretrained("/kaggle/working/substitution_model")
tokenizer.save_pretrained("/kaggle/working/substitution_model")
# Out:
# ('/kaggle/working/substitution_model/tokenizer_config.json',
#  '/kaggle/working/substitution_model/special_tokens_map.json',
#  '/kaggle/working/substitution_model/vocab.txt',
#  '/kaggle/working/substitution_model/added_tokens.json',
#  '/kaggle/working/substitution_model/tokenizer.json')

# %%
import shutil
shutil.make_archive("/kaggle/working/substitution_model", 'zip', "/kaggle/working/substitution_model")
# Out:
# '/kaggle/working/substitution_model.zip'

# %%
# Stage 3: Rule-based filtering + final candidate selection
# Based on the paper:
# 1) candidate lemma must be different from target lemma
# 2) candidate POS must be the same as target POS
# 3) candidate must exist in the frequency list
# 4) choose highest-probability surviving candidate

# %%
# safely get POS and lemma for a word
def get_token_pos_and_lemma(token):
    """
    Return (pos, lemma) using the same analysis function you already use.
    """
    analysis = get_best_analysis(token)
    pos_tag = analysis.get("pos", "")
    lemma = analysis.get("lex", "") or analysis.get("lemma", "")
    return pos_tag, lemma

# %%
def normalize_for_comparison(text):
    """
    Light normalization for comparing target lemma vs candidate lemma.
    """
    if pd.isna(text):
        return ""
    text = str(text).strip()
    text = remove_diacritics(text)
    text = normalize_arabic(text)
    return text

# %%
def filter_and_select_substitution(one_result):
    """
    Input:
      one_result = one item from mlm_substitutions
      Example:
      {
        'original_sentence': ...,
        'complex_word': ...,
        'masked_sentence': ...,
        'found_and_masked': True,
        'substitutions': [{'candidate': ..., 'probability': ...}, ...]
      }

    Output:
      dictionary containing:
      - target word info
      - all candidate analyses
      - valid candidates only
      - selected best substitution
    """
    complex_word = one_result.get("complex_word", "")
    substitutions = one_result.get("substitutions", [])


    # Analyze target word
    target_pos, target_lemma = get_token_pos_and_lemma(complex_word)
    target_lemma_norm = normalize_for_comparison(target_lemma)
    target_word_norm = normalize_for_comparison(complex_word)

    all_candidates = []
    valid_candidates = []


    for cand in substitutions:
        candidate_word = cand.get("candidate", "")
        probability = cand.get("probability", 0.0)

        cand_pos, cand_lemma = get_token_pos_and_lemma(candidate_word)
        cand_lemma_norm = normalize_for_comparison(cand_lemma)
        cand_word_norm = normalize_for_comparison(candidate_word)

        # Rule 1: lemma must be different from target lemma
        lemma_is_different = (
            cand_lemma_norm != target_lemma_norm
            and cand_word_norm != target_word_norm
        )
        # Rule 2: POS must match target POS
        same_pos = (cand_pos == target_pos)

        # Rule 3: candidate must exist in frequency list
        in_freq, lookup_candidates = exists_in_frequency_list(candidate_word, cand_lemma)

        candidate_info = {
            "candidate": candidate_word,
            "probability": probability,
            "candidate_pos": cand_pos,
            "candidate_lemma": cand_lemma,
            "candidate_lookup_candidates": lookup_candidates,
            "lemma_is_different": lemma_is_different,
            "same_pos": same_pos,
            "in_frequency_list": in_freq,
            "is_valid": lemma_is_different and same_pos and in_freq
        }
        all_candidates.append(candidate_info)

        if candidate_info["is_valid"]:
            valid_candidates.append(candidate_info)

    # Select highest-probability valid candidate
    selected = None
    if valid_candidates:
        selected = max(valid_candidates, key=lambda x: x["probability"])

    return {
        "complex_word": complex_word,
        "target_pos": target_pos,
        "target_lemma": target_lemma,
        "all_candidates": all_candidates,
        "valid_candidates": valid_candidates,
        "selected_substitution": selected
    }

# %%
# Apply to one row
def filter_substitutions_for_row(row):
    """
    For one row:
    - take mlm_substitutions
    - filter each complex word's candidates
    - choose final substitution if available
    """
    mlm_results = row["mlm_substitutions"]

    if not isinstance(mlm_results, list) or len(mlm_results) == 0:
        return []

    filtered_results = []
    for one_result in mlm_results:
        filtered_results.append(filter_and_select_substitution(one_result))

    return filtered_results

# Apply to dataframe
final_df["filtered_substitutions"] = final_df.apply(filter_substitutions_for_row, axis=1)

# %%
# Extract only final chosen substitutions
def extract_final_substitutions(filtered_results):
    """
    Return a compact list of final chosen substitutions per row.
    """
    if not isinstance(filtered_results, list):
        return []

    finals = []
    for item in filtered_results:
        selected = item.get("selected_substitution", None)
        if selected is not None:
            finals.append({
                "complex_word": item["complex_word"],
                "replacement": selected["candidate"],
                "probability": selected["probability"],
                "target_pos": item["target_pos"],
                "target_lemma": item["target_lemma"],
                "candidate_pos": selected["candidate_pos"],
                "candidate_lemma": selected["candidate_lemma"]
            })
    return finals

final_df["final_substitutions"] = final_df["filtered_substitutions"].apply(extract_final_substitutions)

# %%
# Preview
for i in range(min(3, len(final_df))):
    print("=" * 100)
    print("Original:", final_df.loc[i, "Original_Sentence"])  # change if your column is Original_Text
    print("Complex words:", final_df.loc[i, "complex_words"])
    print("\nFinal substitutions:")
    for item in final_df.loc[i, "final_substitutions"]:
        print(item)

    print("\nFiltered details:")
    for item in final_df.loc[i, "filtered_substitutions"]:
        print("-" * 60)
        print("Complex word:", item["complex_word"])
        print("Target POS:", item["target_pos"])
        print("Target lemma:", item["target_lemma"])
        print("Selected substitution:", item["selected_substitution"])
# Out:
# ====================================================================================================
# Original: •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
# Complex words: ['الانحياز', 'اصطلاح', 'سياسي', 'الحياد']
#
# Final substitutions:
# {'complex_word': 'الانحياز', 'replacement': 'الرضا', 'probability': 0.10982364416122437, 'target_pos': 'noun', 'target_lemma': 'ٱِنْحِياز', 'candidate_pos': 'noun', 'candidate_lemma': 'رِضَى'}
# {'complex_word': 'اصطلاح', 'replacement': 'مصطلح', 'probability': 0.3239383101463318, 'target_pos': 'noun', 'target_lemma': 'ٱِصْطِلاح', 'candidate_pos': 'noun', 'candidate_lemma': 'مُصْطَلَح'}
# {'complex_word': 'سياسي', 'replacement': 'عربي', 'probability': 0.031740352511405945, 'target_pos': 'adj', 'target_lemma': 'سِياسِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'عَرَبِيّ'}
# {'complex_word': 'الحياد', 'replacement': 'الاستقلال', 'probability': 0.003940789960324764, 'target_pos': 'noun', 'target_lemma': 'حِياد', 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْلال'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: الانحياز
# Target POS: noun
# Target lemma: ٱِنْحِياز
# Selected substitution: {'candidate': 'الرضا', 'probability': 0.10982364416122437, 'candidate_pos': 'noun', 'candidate_lemma': 'رِضَى', 'candidate_lookup_candidates': ['الرضا', 'رضى', 'رضي', 'رِضَى'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: اصطلاح
# Target POS: noun
# Target lemma: ٱِصْطِلاح
# Selected substitution: {'candidate': 'مصطلح', 'probability': 0.3239383101463318, 'candidate_pos': 'noun', 'candidate_lemma': 'مُصْطَلَح', 'candidate_lookup_candidates': ['مصطلح', 'مُصْطَلَح'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: سياسي
# Target POS: adj
# Target lemma: سِياسِيّ
# Selected substitution: {'candidate': 'عربي', 'probability': 0.031740352511405945, 'candidate_pos': 'adj', 'candidate_lemma': 'عَرَبِيّ', 'candidate_lookup_candidates': ['عربي', 'عَرَبِيّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: الحياد
# Target POS: noun
# Target lemma: حِياد
# Selected substitution: {'candidate': 'الاستقلال', 'probability': 0.003940789960324764, 'candidate_pos': 'noun', 'candidate_lemma': 'ٱِسْتِقْلال', 'candidate_lookup_candidates': ['استقلال', 'الاستقلال', 'ٱستقلال', 'ٱِسْتِقْلال'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ====================================================================================================
# Original: حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# Complex words: ['المنحازة']
#
# Final substitutions:
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: None
# ====================================================================================================
# Original: بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Complex words: ['المنحازة', 'المتفرج', 'العالمية']
#
# Final substitutions:
# {'complex_word': 'المنحازة', 'replacement': 'العظمى', 'probability': 0.03207551687955856, 'target_pos': 'noun', 'target_lemma': 'مُنْحاز', 'candidate_pos': 'noun', 'candidate_lemma': 'أَعْظَم'}
# {'complex_word': 'المتفرج', 'replacement': 'واحد', 'probability': 0.25521934032440186, 'target_pos': 'noun', 'target_lemma': 'مُتَفَرِّج', 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد'}
# {'complex_word': 'العالمية', 'replacement': 'الخارجية', 'probability': 0.056087203323841095, 'target_pos': 'adj', 'target_lemma': 'عالَمِيّ', 'candidate_pos': 'adj', 'candidate_lemma': 'خارِجِيّ'}
#
# Filtered details:
# ------------------------------------------------------------
# Complex word: المنحازة
# Target POS: noun
# Target lemma: مُنْحاز
# Selected substitution: {'candidate': 'العظمى', 'probability': 0.03207551687955856, 'candidate_pos': 'noun', 'candidate_lemma': 'أَعْظَم', 'candidate_lookup_candidates': ['أعظم', 'أَعْظَم', 'اعظم', 'العظمى', 'العظمي'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: المتفرج
# Target POS: noun
# Target lemma: مُتَفَرِّج
# Selected substitution: {'candidate': 'واحد', 'probability': 0.25521934032440186, 'candidate_pos': 'noun', 'candidate_lemma': 'واحِد', 'candidate_lookup_candidates': ['واحد', 'واحِد'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}
# ------------------------------------------------------------
# Complex word: العالمية
# Target POS: adj
# Target lemma: عالَمِيّ
# Selected substitution: {'candidate': 'الخارجية', 'probability': 0.056087203323841095, 'candidate_pos': 'adj', 'candidate_lemma': 'خارِجِيّ', 'candidate_lookup_candidates': ['الخارجية', 'خارجي', 'خارِجِيّ'], 'lemma_is_different': True, 'same_pos': True, 'in_frequency_list': True, 'is_valid': True}

# %%
import re
import pandas as pd

# %%
# Safe single replacement
def replace_first_exact_occurrence(sentence, old_word, new_word):
    """
    Replace only the first exact occurrence of old_word in sentence.
    Returns:
      new_sentence, replaced_flag
    """
    if pd.isna(sentence):
        return sentence, False

    sentence = str(sentence)
    old_word = str(old_word)
    new_word = str(new_word)

    if not old_word or not new_word:
        return sentence, False

    pattern = re.escape(old_word)
    new_sentence, n = re.subn(pattern, new_word, sentence, count=1)

    return new_sentence, (n > 0)

# %%
#Build final simplified sentence for one row
def build_lexical_simplified_sentence(row):
    """
    For one row:
    - start from original sentence
    - apply final selected substitutions one by one
    - return final simplified sentence
    """
    # Change this if your real text column is Original_Text
    original_sentence = row["Original_Sentence"]
    substitutions = row["final_substitutions"]

    if pd.isna(original_sentence):
        return ""

    sentence = str(original_sentence)

    if not isinstance(substitutions, list) or len(substitutions) == 0:
        return sentence

    # Optional: remove duplicate target->replacement pairs
    # while preserving order
    seen_pairs = set()
    ordered_subs = []

    for item in substitutions:
        complex_word = item.get("complex_word", "")
        replacement = item.get("replacement", "")
        key = (complex_word, replacement)
        if key not in seen_pairs:
            seen_pairs.add(key)
            ordered_subs.append(item)

    # Replace one by one
    for item in ordered_subs:
        complex_word = item.get("complex_word", "")
        replacement = item.get("replacement", "")

        if complex_word and replacement:
            sentence, _ = replace_first_exact_occurrence(
                sentence=sentence,
                old_word=complex_word,
                new_word=replacement
            )

    return sentence

# %%
#Apply to dataframe
final_df["lexical_simplified_text"] = final_df.apply(build_lexical_simplified_sentence, axis=1)

# %%
#store a compact replacement map for inspection
def build_replacement_map(substitutions):
    """
    Create a simple readable list of replacements for debugging.
    """
    if not isinstance(substitutions, list):
        return []

    return [
        f"{item.get('complex_word', '')} -> {item.get('replacement', '')}"
        for item in substitutions
    ]

final_df["replacement_map"] = final_df["final_substitutions"].apply(build_replacement_map)

# %%
for i in range(min(20, len(final_df))):
    print("=" * 120)
    print("Original:             ", final_df.loc[i, "Original_Sentence"])   # change if needed
    print("Complex words:        ", final_df.loc[i, "complex_words"])
    print("Replacement map:      ", final_df.loc[i, "replacement_map"])
    print("Lexical simplified:   ", final_df.loc[i, "lexical_simplified_text"])
# Out:
# ========================================================================================================================
# Original:              •• "عدم الانحياز" اصطلاح سياسي يعنى الحياد..
# Complex words:         ['الانحياز', 'اصطلاح', 'سياسي', 'الحياد']
# Replacement map:       ['الانحياز -> الرضا', 'اصطلاح -> مصطلح', 'سياسي -> عربي', 'الحياد -> الاستقلال']
# Lexical simplified:    •• "عدم الرضا" مصطلح عربي يعنى الاستقلال..
# ========================================================================================================================
# Original:              حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# Complex words:         ['المنحازة']
# Replacement map:       []
# Lexical simplified:    حيث تلتزم الدول غير المنحازة بعدم الارتباط بأي دول أجنبية في الشرق أو الغرب.
# ========================================================================================================================
# Original:              بمعنى أن الدول غير المنحازة لا تقف موقف المتفرج أمام المشاكل والأحداث العالمية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# Complex words:         ['المنحازة', 'المتفرج', 'العالمية']
# Replacement map:       ['المنحازة -> العظمى', 'المتفرج -> واحد', 'العالمية -> الخارجية']
# Lexical simplified:    بمعنى أن الدول غير العظمى لا تقف موقف واحد أمام المشاكل والأحداث الخارجية.. بل يكون لها دور يسير مع مصالحها هي.. لا مصالح الدول المتصارعة..
# ========================================================================================================================
# Original:              وقد بدأ استعمال اصطلاح (عدم الانحياز) في مؤتمر بلغراد عام 1961، والذي اشتركت فيه 21 دولة غير منحازة
# Complex words:         ['اصطلاح', 'الانحياز', '،', 'منحازة']
# Replacement map:       ['اصطلاح -> مصطلح', 'الانحياز -> الاستقلال', 'منحازة -> غير']
# Lexical simplified:    وقد بدأ استعمال مصطلح (عدم الاستقلال) في مؤتمر بلغراد عام 1961، والذي اشتركت فيه 21 دولة غير غير
# ========================================================================================================================
# Original:              ••السيارات التي يستعملها الدبلوماسيون.. أي رجال السفارات المعتمدون لدى الدولة تحمل هذه الجملة (هيئة سياسية).
# Complex words:         ['سياسية']
# Replacement map:       ['سياسية -> الدبلوماسية']
# Lexical simplified:    ••السيارات التي يستعملها الدبلوماسيون.. أي رجال السفارات المعتمدون لدى الدولة تحمل هذه الجملة (هيئة الدبلوماسية).
# ========================================================================================================================
# Original:              يقصد بالتنمية.. خطة اقتصادية لزيادة الإنتاج.. ورفع مستوى المعيشة للأفراد.
# Complex words:         []
# Replacement map:       []
# Lexical simplified:    يقصد بالتنمية.. خطة اقتصادية لزيادة الإنتاج.. ورفع مستوى المعيشة للأفراد.
# ========================================================================================================================
# Original:              حضرموت – اليمن الديمقراطية
# Complex words:         ['الديمقراطية']
# Replacement map:       ['الديمقراطية -> سابقا']
# Lexical simplified:    حضرموت – اليمن سابقا
# ========================================================================================================================
# Original:              العنقاء هي رمز البعث والخلود في الأساطير المصرية القديمة
# Complex words:         ['العنقاء']
# Replacement map:       ['العنقاء -> الكنيسة']
# Lexical simplified:    الكنيسة هي رمز البعث والخلود في الأساطير المصرية القديمة
# ========================================================================================================================
# Original:              ويقال إنها لما بلغت 500 سنة أحرقت نفسها وبرزت من دخانها عنقاء أخرى..
# Complex words:         ['أحرقت', 'عنقاء']
# Replacement map:       ['أحرقت -> عرفت', 'عنقاء -> مرة']
# Lexical simplified:    ويقال إنها لما بلغت 500 سنة عرفت نفسها وبرزت من دخانها مرة أخرى..
# ========================================================================================================================
# Original:              وقد اعتبرها العرب أحد المستحيلات الثلاثة، العنقاء والغول والخل الوفي.
# Complex words:         ['المستحيلات', 'الثلاثة', '،', 'العنقاء', 'والخل']
# Replacement map:       ['الثلاثة -> الاخرى', 'العنقاء -> الفيل', 'والخل -> والرجل']
# Lexical simplified:    وقد اعتبرها العرب أحد المستحيلات الاخرى، الفيل والغول والرجل الوفي.
# ========================================================================================================================
# Original:              عندما قرأنا الخبر صدقنا أن العنقاء موجودة فعلا عند البروفسور وأنها تساوي مليون دولار
# Complex words:         ['العنقاء', 'دولار']
# Replacement map:       ['العنقاء -> الصورة', 'دولار -> جنيه']
# Lexical simplified:    عندما قرأنا الخبر صدقنا أن الصورة موجودة فعلا عند البروفسور وأنها تساوي مليون جنيه
# ========================================================================================================================
# Original:              الأدب الجاهلي هو أدب الفترة التي سبقت ظهور الإسلام بنحو قرن ونصف القرن..
# Complex words:         ['الجاهلي']
# Replacement map:       ['الجاهلي -> العربي']
# Lexical simplified:    الأدب العربي هو أدب الفترة التي سبقت ظهور الإسلام بنحو قرن ونصف القرن..
# ========================================================================================================================
# Original:              ردت الصغيرة بقوة: وهل كنت تخافين عندما كنت تعملين في المقاومة السرية أيام الاحتلال الألماني لفرنسا؟
# Complex words:         ['؟']
# Replacement map:       []
# Lexical simplified:    ردت الصغيرة بقوة: وهل كنت تخافين عندما كنت تعملين في المقاومة السرية أيام الاحتلال الألماني لفرنسا؟
# ========================================================================================================================
# Original:              وقال لمن حوله: -أنتم جميعًا مدعوون للغداء عندي اليوم.
# Complex words:         ['أنتم']
# Replacement map:       ['أنتم -> نحن']
# Lexical simplified:    وقال لمن حوله: -نحن جميعًا مدعوون للغداء عندي اليوم.
# ========================================================================================================================
# Original:              •هل إلقاء السلام على المسلم سنة؟
# Complex words:         ['المسلم', '؟']
# Replacement map:       ['المسلم -> النبي']
# Lexical simplified:    •هل إلقاء السلام على النبي سنة؟
# ========================================================================================================================
# Original:              ••ابتداء السلام سنة، ورد السلام فرض،
# Complex words:         ['،', '،']
# Replacement map:       []
# Lexical simplified:    ••ابتداء السلام سنة، ورد السلام فرض،
# ========================================================================================================================
# Original:              أما المقصود بالقارعة التي وردت في بداية هذه السورة فهو: يوم القيامة،
# Complex words:         ['بالقارعة', '،']
# Replacement map:       []
# Lexical simplified:    أما المقصود بالقارعة التي وردت في بداية هذه السورة فهو: يوم القيامة،
# ========================================================================================================================
# Original:              قال تعالى: (القارعة) اسم من أسماء يوم القيامة، مثل: الحاقة، والطامة، والغاشية،
# Complex words:         ['تعالى', 'القارعة', '،', 'الحاقة', '،', 'والطامة', '،', 'والغاشية', '،']
# Replacement map:       ['القارعة -> الم', 'الحاقة -> الحجر', 'والطامة -> والقمر', 'والغاشية -> والقمر']
# Lexical simplified:    قال تعالى: (الم) اسم من أسماء يوم القيامة، مثل: الحجر، والقمر، والقمر،
# ========================================================================================================================
# Original:              بعد أن وصف الله يوم القيامة، قسم الناس فيه إلى قسمين فقال: (فأما من ثقلت موازينه) أي رجحت حسناته على سيئاته، (فهو في عيشة راضية) يعنى الجنة (وأما من خفت موازينه) أي رجحت سيئاته على حسناته (فأمه هاوية)
# Complex words:         ['،', 'ثقلت', 'رجحت', '،', 'عيشة', 'راضية', 'رجحت']
# Replacement map:       ['ثقلت -> صحت', 'رجحت -> سرت', 'عيشة -> الاخرة', 'راضية -> جهنم', 'رجحت -> سرت']
# Lexical simplified:    بعد أن وصف الله يوم القيامة، قسم الناس فيه إلى قسمين فقال: (فأما من صحت موازينه) أي سرت حسناته على سيئاته، (فهو في الاخرة جهنم) يعنى الجنة (وأما من خفت موازينه) أي رجحت سيئاته على حسناته (فأمه هاوية)
# ========================================================================================================================
# Original:              أما النبي صلى الله عليه وسلم، فقد كان حريصًا على أن يجهر بصلاته قدر استطاعته، وأن يجهر بالقرآن ما وسعه ذلك.
# Complex words:         ['،', 'يجهر', 'استطاعته', '،', 'يجهر']
# Replacement map:       ['يجهر -> يقوم', 'استطاعته -> الامكان', 'يجهر -> يقوم']
# Lexical simplified:    أما النبي صلى الله عليه وسلم، فقد كان حريصًا على أن يقوم بصلاته قدر الامكان، وأن يجهر بالقرآن ما وسعه ذلك.

# %%
final_df.to_csv("/kaggle/working/final_df_with_simplifications.csv", index=False)
print("Saved to /kaggle/working/final_df_with_simplifications.csv")
# Out:
# Saved to /kaggle/working/final_df_with_simplifications.csv

# %%
import os
print(os.listdir("/kaggle/working"))
# Out:
# ['final_df_with_simplifications.csv', '.virtual_documents', 'substitution_model.zip', 'substitution_model']

# %%
from IPython.display import FileLink, display

file_path = "/kaggle/working/final_df_with_simplifications.csv"

final_df.to_csv(file_path, index=False)
print("Saved.")

display(FileLink(file_path))
# Out:
# Saved.
# /kaggle/working/final_df_with_simplifications.csv
